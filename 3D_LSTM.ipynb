# %% [markdown]
# # Imports

# %% [markdown]
# The implementation of the project is entirely conducted in a Google Colab [57] notebook running Python 3 [58]. Colab is a web-based application that integrates live code, computational output, data visualisations, equations and explanatory text into a single document known as a notebook. Due to their flexibility and interactivity, notebook-based editors like Colab and Jupyter [59] have gained popularity with data scientists in recent years as code can be easily executed, modified and re-ran in sections while being combined with images, plots, and text to enhance explainability. For the aforementioned reasons, alongside Colab’s ability to allow written software to be stored on the cloud and executed on powerful Google GPUs free of charge, the decision was made to implement this project using Colab.

# %%
pip install yfinance plotly pandas_datareader attention
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: yfinance in /usr/local/lib/python3.7/dist-packages (0.1.74)
# Requirement already satisfied: plotly in /usr/local/lib/python3.7/dist-packages (5.5.0)
# Requirement already satisfied: pandas_datareader in /usr/local/lib/python3.7/dist-packages (0.9.0)
# Requirement already satisfied: attention in /usr/local/lib/python3.7/dist-packages (4.1)
# Requirement already satisfied: numpy>=1.15 in /usr/local/lib/python3.7/dist-packages (from yfinance) (1.21.6)
# Requirement already satisfied: lxml>=4.5.1 in /usr/local/lib/python3.7/dist-packages (from yfinance) (4.9.1)
# Requirement already satisfied: requests>=2.26 in /usr/local/lib/python3.7/dist-packages (from yfinance) (2.28.1)
# Requirement already satisfied: multitasking>=0.0.7 in /usr/local/lib/python3.7/dist-packages (from yfinance) (0.0.11)
# Requirement already satisfied: pandas>=0.24.0 in /usr/local/lib/python3.7/dist-packages (from yfinance) (1.3.5)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.24.0->yfinance) (2022.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.24.0->yfinance) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas>=0.24.0->yfinance) (1.15.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests>=2.26->yfinance) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests>=2.26->yfinance) (2022.6.15)
# Requirement already satisfied: charset-normalizer<3,>=2 in /usr/local/lib/python3.7/dist-packages (from requests>=2.26->yfinance) (2.1.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests>=2.26->yfinance) (2.10)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.7/dist-packages (from plotly) (8.0.1)
# Requirement already satisfied: tensorflow>=2.1 in /usr/local/lib/python3.7/dist-packages (from attention) (2.8.2+zzzcolab20220719082949)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.1->attention) (4.1.1)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.1->attention) (3.1.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.1->attention) (57.4.0)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.1->attention) (1.14.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.1->attention) (1.47.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.1->attention) (1.6.3)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.1->attention) (3.3.0)
# Requirement already satisfied: absl-py>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.1->attention) (1.2.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.1->attention) (1.1.0)
# Requirement already satisfied: tensorboard<2.9,>=2.8 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.1->attention) (2.8.0)
# Requirement already satisfied: keras<2.9,>=2.8.0rc0 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.1->attention) (2.8.0)
# Requirement already satisfied: gast>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.1->attention) (0.5.3)
# Requirement already satisfied: keras-preprocessing>=1.1.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.1->attention) (1.1.2)
# Requirement already satisfied: libclang>=9.0.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.1->attention) (14.0.6)
# Requirement already satisfied: protobuf<3.20,>=3.9.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.1->attention) (3.17.3)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.1->attention) (0.26.0)
# Requirement already satisfied: flatbuffers>=1.12 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.1->attention) (2.0)
# Requirement already satisfied: tensorflow-estimator<2.9,>=2.8 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.1->attention) (2.8.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.1->attention) (0.2.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.7/dist-packages (from astunparse>=1.6.0->tensorflow>=2.1->attention) (0.37.1)
# Requirement already satisfied: cached-property in /usr/local/lib/python3.7/dist-packages (from h5py>=2.9.0->tensorflow>=2.1->attention) (1.5.2)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.9,>=2.8->tensorflow>=2.1->attention) (0.4.6)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.9,>=2.8->tensorflow>=2.1->attention) (1.0.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.9,>=2.8->tensorflow>=2.1->attention) (1.8.1)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.9,>=2.8->tensorflow>=2.1->attention) (0.6.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.9,>=2.8->tensorflow>=2.1->attention) (1.35.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.9,>=2.8->tensorflow>=2.1->attention) (3.4.1)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow>=2.1->attention) (4.2.4)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow>=2.1->attention) (4.9)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow>=2.1->attention) (0.2.8)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.9,>=2.8->tensorflow>=2.1->attention) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in /usr/local/lib/python3.7/dist-packages (from markdown>=2.6.8->tensorboard<2.9,>=2.8->tensorflow>=2.1->attention) (4.12.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<2.9,>=2.8->tensorflow>=2.1->attention) (3.8.1)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.7/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow>=2.1->attention) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.9,>=2.8->tensorflow>=2.1->attention) (3.2.0)

# %% [markdown]
# Regarding project dependencies, data preparation for the project relies on the Python libraries NumPy [60] and Pandas [61]. NumPy is a library that facilitates the usage of large multi-dimensional arrays, whereas Pandas provides data manipulation and analysis techniques not included in a standard python installation. Due to their speed, effectiveness, and ease of use both libraries have become ubiquitous in data science projects, with a large percentage of ML libraries requiring both as a pre-requisite. Available functionality from both libraries will be utilised to load, analyse and edit the financial datasets, presenting them in standardised formats able to be analysed by the vast majority of ML libraries. Visualisation for these datasets is provided by Plotly [62], Seaborn [63], and MatPlotLib [64], extensions of NumPy that provides interactive and customisable figures, plots, and charts with the added benefit of enabling these plots to be embedded in notebook-based editors such as Colab. Financial datasets will be loaded into the notebook using the popular library yfinance [65] so allow users to run the code without needing to download the relevant .csv files. For data pre-processing, the Scikit-Learn data analysis library is imported to utilise its evaluation metrics and feature scaling methods which provide normalisation and standardisation upon NumPy datasets, and the open-source PyWavelets [66] software is also utilised to provide the wavelet transformations used to de-noise the volatile financial data. The deep learning LSTM networks are developed with Keras [67] on top of Google TensorFlow, one of the largest and most powerful libraries for large-scale customisable Neural Networks, and the attention layer is implemented using Philippe Remy’s ‘Attention’ library [68].

# %%
# Data pre-processing
import numpy as np
import pandas as pd

# Load in data
import yfinance as yf

# Wavelet tranformation
import pywt

# Displaying text and graphs
from IPython.display import display

# Data scaling
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler

# Visualisation
import matplotlib.dates as mdates
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
from plotly.subplots import make_subplots
import plotly.graph_objects as go

# Model construction
from tensorflow.keras import Input
from tensorflow.keras.layers import Dense, LSTM, Dropout
from tensorflow.keras.models import load_model, Model
from attention import Attention
import keras
import tensorflow as tf

# ignore warnings 
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Prediction Model

# %% [markdown]
# ## Model Parameters

# %%
HIDDEN_LAYER_NODES = 50
PARAM_EPOCHS = 100
PARAM_LEARNING_RATE = 0.0001
PARAM_BATCH_SIZE = 50
PARAM_WINDOW_SIZE = 10
PARAM_DROPOUT = 0.2

# %% [markdown]
# ## Pre-Proccesing

# %% [markdown]
# ### Load & Explore Dataset

# %% [markdown]
# The necessary information to forecast stock prices will be accessed from Yahoo! Finance. Yahoo! Finance is a media site that delivers financial news, statistics and opinions and enables users to view and download the historical stock indices data of every publicly listed company and major stock index in the world. The historical data is available for download in the widely used .csv format and consists of import financial metrics from across the stock’s lifespan, including opening and closing prices, high and low prices, adjusted close prices and daily volume of shares traded. In Section 4.1, further information about the accessible financial data and certain instances will be provided. The data will be imported from Yahoo! Finance using yfinance and read into a NumPy dataframe prior to pre-processing.

# %% [markdown]
# The data using is the same data used in the original paper alonside three new datasets with the time periods and number of samples of each detailed below:
#
#
# Stock Market Name  | Training Data Dates | Num. of Train Samples | Testing Data Dates | Num. of Test Samples |
# -------------------|------------------ | ------------ | ------------ | ------------ |
# DJIA       | 03/01/2000 - 16/05/2019 | 4873 | 17/05/2019 - 01/07/2019 | 31 |
# HSI       | 02/01/2002 – 16/05/2019 | 4273 | 17/05/2019 – 01/07/2019 | 31 |
# S&P 500       | 03/01/2000 - 16/05/2019 | 4873 | 17/05/2019 - 01/07/2019| 31 |
# NASDAQ      | 01/01/2000 - 31/12/2015 | 4024 | 01/01/2016 - 01/01/2020| 1006 |
# DAX     | 01/01/2000 - 18/12/2015 | 4057 | 19/12/2015 - 01/01/2020| 1015 |
# FTSE 100      | 01/01/2000- 01/04/2016 | 4085 | 02/04/2016 - 01/01/2020| 1021 |

# %% [markdown]
# Run each cell to load each specific stock market data.

# %%
# Load HSI Stock prices
dataset_Name = 'HSI'
yahoo_index_code = '^HSI'
start_date = '2002-01-02'
end_date = '2019-07-02'
split_index = '2019/5/17'

# %%
# Load S&P500 Stock prices
dataset_Name = 'S&P500'
yahoo_index_code = '^GSPC'
start_date = '2000-01-03'
end_date = '2019-07-02'
split_index = '2019/5/17'

# %%
# Load DJIA Stock prices
dataset_Name = 'DJIA'
yahoo_index_code = '^DJI'
start_date = '2000-01-03'
end_date = '2019-07-02'
split_index = '2019/5/17'

# %%
# Load DAX Stock prices
dataset_Name = 'DAX '
yahoo_index_code = '^GDAXI'
start_date = '2000-01-01'
end_date = '2020-01-01'
split_index = '2015/12/18'

# %%
# Load FTSE Stock prices
dataset_Name = 'FTSE'
yahoo_index_code = '^FTSE'
start_date = '2000-01-01'
end_date = '2020-01-01'
split_index = '2016/01/04'

# %%
# Load NASDAQ Stock prices
dataset_Name = 'NASDAQ '
yahoo_index_code = '^IXIC'
start_date = '2000-01-01'
end_date = '2020-01-01'
split_index = '2015/12/31'

# %% [markdown]
# The necessary information to forecast stock prices will be accessed from Yahoo! Finance using the yfinance library. Yahoo Finance is a media site that delivers financial news, statistics and opinions and enables users to view and download the historical stock indices data of every publicly listed company and major stock index in the world. The historical data is available for download in the widely used .csv format and consists of import financial metrics from across the stock’s lifespan, including opening and closing prices, high and low prices, adjusted close prices and daily volume of shares traded.

# %%
# Load dataframe from yahoo finance
df = yf.download(yahoo_index_code, period='1d', start = start_date, end = end_date)

# Sort the dataframe based on the date
df = df.sort_index()

# Display dataframe
display(df)
# Out:
# [*********************100%***********************]  1 of 1 completed
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2000-01-03  4186.189941  4192.189941  3989.709961  4131.149902  4131.149902
# 2000-01-04  4020.000000  4073.250000  3898.229980  3901.689941  3901.689941
# 2000-01-05  3854.350098  3924.209961  3734.870117  3877.540039  3877.540039
# 2000-01-06  3834.439941  3868.760010  3715.620117  3727.129883  3727.129883
# 2000-01-07  3711.090088  3882.669922  3711.090088  3882.620117  3882.620117
# ...                 ...          ...          ...          ...          ...
# 2019-12-24  8955.009766  8957.120117  8934.360352  8952.879883  8952.879883
# 2019-12-26  8970.209961  9022.459961  8968.459961  9022.389648  9022.389648
# 2019-12-27  9049.469727  9052.000000  8987.320312  9006.620117  9006.620117
# 2019-12-30  9004.450195  9006.360352  8909.190430  8945.990234  8945.990234
# 2019-12-31  8918.740234  8975.360352  8912.769531  8972.599609  8972.599609
#
#                 Volume
# Date
# 2000-01-03  1510070000
# 2000-01-04  1511840000
# 2000-01-05  1735670000
# 2000-01-06  1598320000
# 2000-01-07  1634930000
# ...                ...
# 2019-12-24  1014520000
# 2019-12-26  1634920000
# 2019-12-27  1832200000
# 2019-12-30  2042420000
# 2019-12-31  2182800000
#
# [5031 rows x 6 columns]

# %% [markdown]
# Here, the loaded stock market data is then visualised into an interactive graph using the PlotLy libary:

# %%
df_plot = df.copy()
ncols = 2
nrows = int(round(df_plot.shape[1] / ncols, 0))

fig, ax = plt.subplots(nrows=nrows, ncols=ncols, sharex=True, figsize=(14, 7))
for i, ax in enumerate(fig.axes):
        sns.lineplot(data = df_plot.iloc[:, i], ax=ax)
        ax.tick_params(axis="x", rotation=30, labelsize=10, length=0)
        ax.xaxis.set_major_locator(mdates.AutoDateLocator())
fig.tight_layout()
plt.show()

# %% [markdown]
# ### Split Dataset into Train and Testing Data

# %% [markdown]
# Add labels to dataset used to train and evaluate the model. The labels are the next days closing price.

# %%
# Add labels
df['Label'] = (df['Close']).shift(-1)
df = df.dropna()
display(df)
# Out:
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2000-01-03  4186.189941  4192.189941  3989.709961  4131.149902  4131.149902
# 2000-01-04  4020.000000  4073.250000  3898.229980  3901.689941  3901.689941
# 2000-01-05  3854.350098  3924.209961  3734.870117  3877.540039  3877.540039
# 2000-01-06  3834.439941  3868.760010  3715.620117  3727.129883  3727.129883
# 2000-01-07  3711.090088  3882.669922  3711.090088  3882.620117  3882.620117
# ...                 ...          ...          ...          ...          ...
# 2019-12-23  8950.200195  8956.639648  8934.549805  8945.650391  8945.650391
# 2019-12-24  8955.009766  8957.120117  8934.360352  8952.879883  8952.879883
# 2019-12-26  8970.209961  9022.459961  8968.459961  9022.389648  9022.389648
# 2019-12-27  9049.469727  9052.000000  8987.320312  9006.620117  9006.620117
# 2019-12-30  9004.450195  9006.360352  8909.190430  8945.990234  8945.990234
#
#                 Volume        Label
# Date
# 2000-01-03  1510070000  3901.689941
# 2000-01-04  1511840000  3877.540039
# 2000-01-05  1735670000  3727.129883
# 2000-01-06  1598320000  3882.620117
# 2000-01-07  1634930000  4049.669922
# ...                ...          ...
# 2019-12-23  2025450000  8952.879883
# 2019-12-24  1014520000  9022.389648
# 2019-12-26  1634920000  9006.620117
# 2019-12-27  1832200000  8945.990234
# 2019-12-30  2042420000  8972.599609
#
# [5030 rows x 7 columns]

# %% [markdown]
# Commonly, in order to evaluate the performance of machine learning algorithms, the dataset is divided into two subgroups. The first subset, known as the training dataset, is utilised to fit the model. The second subset, known as the testing dataset, is used to evaluate this fit by comparing the model's projected values for a particular sample with the true values. The imported dataset will be divided into these two sections in order to quantify and compare model performance

# %%
def train_test_split(df):

  # Split dataset into input and lables
  x = (df.loc[:, : 'Volume'])
  y = (df.loc[:, 'Label': ])

  # Split input into training and testing
  x_train = x[:split_index]
  x_test = x[split_index:]

  # Split output into tradining and testing
  y_train = y[:split_index]
  y_test = y[split_index:]

  # drop last row of train sets to avoid sample repetition
  x_train.drop(x_train.tail(1).index,inplace=True)
  y_train.drop(y_train.tail(1).index,inplace=True) 

  return x_train, y_train, x_test, y_test

x_train, y_train, x_test, y_test = train_test_split(df)

# %%
# Display first 5 train samples and their labels
display(x_train.head())
display(x_train.shape)
display(y_train.head())
display(y_train.shape)
# Out:
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2000-01-03  4186.189941  4192.189941  3989.709961  4131.149902  4131.149902
# 2000-01-04  4020.000000  4073.250000  3898.229980  3901.689941  3901.689941
# 2000-01-05  3854.350098  3924.209961  3734.870117  3877.540039  3877.540039
# 2000-01-06  3834.439941  3868.760010  3715.620117  3727.129883  3727.129883
# 2000-01-07  3711.090088  3882.669922  3711.090088  3882.620117  3882.620117
#
#                 Volume
# Date
# 2000-01-03  1510070000
# 2000-01-04  1511840000
# 2000-01-05  1735670000
# 2000-01-06  1598320000
# 2000-01-07  1634930000
# (4024, 6)
#                   Label
# Date
# 2000-01-03  3901.689941
# 2000-01-04  3877.540039
# 2000-01-05  3727.129883
# 2000-01-06  3882.620117
# 2000-01-07  4049.669922
# (4024, 1)

# %%
# Display first 5 test samples and their labels
display(x_test.head())
display(x_test.shape)
display(y_test.head())
display(y_test.shape)
# Out:
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2015-12-31  5047.040039  5058.060059  5007.009766  5007.410156  5007.410156
# 2016-01-04  4897.649902  4903.089844  4846.979980  4903.089844  4903.089844
# 2016-01-05  4917.839844  4926.729980  4872.740234  4891.430176  4891.430176
# 2016-01-06  4813.759766  4866.040039  4804.689941  4835.759766  4835.759766
# 2016-01-07  4736.399902  4788.020020  4688.169922  4689.430176  4689.430176
#
#                 Volume
# Date
# 2015-12-31  1437480000
# 2016-01-04  2218420000
# 2016-01-05  1927380000
# 2016-01-06  2168620000
# 2016-01-07  2552590000
# (1006, 6)
#                   Label
# Date
# 2015-12-31  4903.089844
# 2016-01-04  4891.430176
# 2016-01-05  4835.759766
# 2016-01-06  4689.430176
# 2016-01-07  4643.629883
# (1006, 1)

# %% [markdown]
# ### Wavelet Transform Testing Data

# %% [markdown]
# As discussed in Section 2.1.4, financial data is complicated and volatile resulting in random oscillations that interfere with the primary relevant signal. To combat this, a wavelet transformation will first be applied to the training and testing set using PyWavelets in order to reduce this noise and improve the accuracy of any forecasts made. The example code below demonstrates how a wavelet transformation with the haar function is applied to a given dataframe in Python, and Figure 10 shows the smoothing effect of the wavelet transformation on a given dataset. The wavelet transformation it is only applied on the training dataset, and as a consequence decreases the number of samples in the dataset by a factor of two.

# %%
# Apply wavelet transformation on given dataframe
def wavelet(data):
  df_wav = pd.DataFrame()
  for column_name, column_data in data.items():
    (cA, cD) = pywt.dwt(column_data, 'haar')
    df_wav[column_name] = cA
  return df_wav

x_train_wav = wavelet(x_train)
y_train_wav = wavelet(y_train)

# Uncomment this block of text to remove the wavelet transformation
# x_train_wav = x_train
# y_train_wav = y_train

  # Display Datasets
display(x_train.head())
display(x_train.shape)
display(x_train_wav.head())
display(x_train_wav.shape)
# Out:
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2000-01-03  4186.189941  4192.189941  3989.709961  4131.149902  4131.149902
# 2000-01-04  4020.000000  4073.250000  3898.229980  3901.689941  3901.689941
# 2000-01-05  3854.350098  3924.209961  3734.870117  3877.540039  3877.540039
# 2000-01-06  3834.439941  3868.760010  3715.620117  3727.129883  3727.129883
# 2000-01-07  3711.090088  3882.669922  3711.090088  3882.620117  3882.620117
#
#                 Volume
# Date
# 2000-01-03  1510070000
# 2000-01-04  1511840000
# 2000-01-05  1735670000
# 2000-01-06  1598320000
# 2000-01-07  1634930000
# (4024, 6)
#           Open         High          Low        Close    Adj Close  \
# 0  5802.652555  5844.548632  5577.615822  5680.075526  5680.075526
# 1  5436.795576  5510.461912  5268.292168  5377.313670  5377.313670
# 2  5454.140926  5625.055678  5423.452561  5608.976077  5608.976077
# 3  5644.359555  5669.327537  5472.546936  5495.075261  5495.075261
# 4  5629.177993  5691.799411  5588.929531  5672.042889  5672.042889
#
#          Volume
# 0  2.136813e+09
# 1  2.357487e+09
# 2  2.352290e+09
# 3  2.277138e+09
# 4  2.215790e+09
# (2012, 6)

# %% [markdown]
# Visualising the Wavelet Transformation on the opening price data for the training dataset:

# %%
num_of_samples = 100

fig, (ax1, ax2) = plt.subplots(2, 1)
fig.suptitle('Effect of wavelet transformation on ' + dataset_Name + ' dataset')
fig.set_size_inches(18, 10, forward=True)

ax1.plot(x_train.iloc[:num_of_samples*2, 0].reset_index().drop(columns=['Date']), label='Stock price without denoising', linewidth=1)
ax1.set_title('Stock price without denoising')
ax1.set(xlabel = 'Date', ylabel = 'Price')

ax2.plot(x_train_wav.iloc[:num_of_samples, 0], label='Stock price with denoising', color = 'orange', linewidth=1)
ax2.set_title('Stock price with denoising')
ax2.set(xlabel = 'Date', ylabel = 'Price')

plt.show()

# %% [markdown]
# ### Normalise Testing Data

# %% [markdown]
# Because the input data consists of two categories of data, i.e., stock price and volume, standardisation and normalisation techniques are also applied using Scikit-Learn’s scaling methods. These feature scaling techniques are used to bring all metrics down to the same scale, ensuring that larger data features do not influence the model solely due to their magnitude and creating a smoother gradient descent during training, which aids backpropagation algorithms in reaching the cost function minima more quickly.

# %%
# Load the scaler, and normalise the input training dataset
scaler_X = MinMaxScaler(feature_range=(-1,1))
X_train_norm = scaler_X.fit_transform(x_train_wav)

# Normalise the output training dataset using a different scaler
scaler_y = MinMaxScaler(feature_range=(-1,1))
y_train_norm = scaler_y.fit_transform(y_train_wav)

# %%
# Display the shape of the wavelet transformed, normalised, training input dataset
display("Un-Normalised X_Train")
display(x_train.head())
display(x_train.shape)

# Display the shape of the wavelet transformed, normalised, training input dataset
display("Normalised X_Train")
display(pd.DataFrame(X_train_norm, columns=['Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']).head())
display(X_train_norm.shape)
# Out:
# 'Un-Normalised X_Train'
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2000-01-03  4186.189941  4192.189941  3989.709961  4131.149902  4131.149902
# 2000-01-04  4020.000000  4073.250000  3898.229980  3901.689941  3901.689941
# 2000-01-05  3854.350098  3924.209961  3734.870117  3877.540039  3877.540039
# 2000-01-06  3834.439941  3868.760010  3715.620117  3727.129883  3727.129883
# 2000-01-07  3711.090088  3882.669922  3711.090088  3882.620117  3882.620117
#
#                 Volume
# Date
# 2000-01-03  1510070000
# 2000-01-04  1511840000
# 2000-01-05  1735670000
# 2000-01-06  1598320000
# 2000-01-07  1634930000
# (4024, 6)
# 'Normalised X_Train'
#        Open      High       Low     Close  Adj Close    Volume
# 0  0.459256  0.465993  0.388355  0.414169   0.414169 -0.496423
# 1  0.332836  0.350081  0.281192  0.309487   0.309487 -0.415338
# 2  0.338829  0.389839  0.334946  0.389586   0.389586 -0.417247
# 3  0.404559  0.405200  0.351955  0.350204   0.350204 -0.444861
# 4  0.399313  0.412996  0.392275  0.411392   0.411392 -0.467403
# (2012, 6)

# %%
# Display the shape of the wavelet transformed, normalised, training input dataset
display("Un-Normalised y_Train")
display(y_train.head())
display(y_train.shape)

# Display the shape of the wavelet transformed, normalised, training input dataset
display("Normalised y_Train")
display(pd.DataFrame(y_train_norm, columns=['Next']).head())
display(y_train_norm.shape)
# Out:
# 'Un-Normalised y_Train'
#                   Label
# Date
# 2000-01-03  3901.689941
# 2000-01-04  3877.540039
# 2000-01-05  3727.129883
# 2000-01-06  3882.620117
# 2000-01-07  4049.669922
# (4024, 1)
# 'Normalised y_Train'
#        Next
# 0  0.352917
# 1  0.311498
# 2  0.399749
# 3  0.359760
# 4  0.454547
# (2012, 1)

# %% [markdown]
# ### Structure Testing Data into LSTM Form

# %% [markdown]
# In order to prepare sequence data for input into any LSTM model, the data must be reformatted into a three-dimensional matrix with form [B, T, D]. B denotes the batch size, or the total number of sequences in the dataset. T stands for the time step, or the size of each sequence. D represents dimensions, or the number of features present at each timestep. Consider, for the sake of explanation, a 3D matrix with the following dimensions: (4824, 50, 6). This means that the LSTM will operate on 4824 distinct sequences, with each sequence consisting of 50 samples and each sample containing six features. Before feeding both the training and testing datasets into the LSTM-Attention model, they will both be reshaped into this 3D matrix structure.

# %%
X_train_S, y_train_S = [], []

for i in range(PARAM_WINDOW_SIZE, X_train_norm.shape[0]):
    X_train_S.append(X_train_norm[i - PARAM_WINDOW_SIZE : i])
    y_train_S.append(y_train_norm[i])
X_train_S = np.array(X_train_S)
y_train_S = np.array(y_train_S)

# X_train_S = X_train_norm
# y_train_S = y_train_norm

print('X_train shape == {}.'.format(X_train_norm.shape))
print('y_train shape == {}.'.format(y_train_norm.shape))
print('X_train_S shape == {}.'.format(X_train_S.shape))
print('y_train_S shape == {}.'.format(y_train_S.shape))
# Out:
# X_train shape == (2012, 6).
# y_train shape == (2012, 1).
# X_train_S shape == (2002, 10, 6).
# y_train_S shape == (2002, 1).

# %% [markdown]
# ## Model Establishment and Training

# %% [markdown]
# ### Model Construction

# %% [markdown]
# As stated in Section 3.1.2, the proposed LSTM-Attention model is built using Keras on top of Google TensorFlow and Philippe Remy’s ‘Attention’ package. As the first objective of this project is to try and replicate the work done by Qui et al., the model will initially consist of three layers: an input layer, a hidden layer, and an output layer. As shown in Figure 6 from Qui et al., the hidden layer consists of an LSTM and Attention layer followed by a dense layer, and the output layer will consist of a single node representing the predicted output of the network. This model is then compiled, and while the authors do not specify which optimiser they have used, I selected the Adam optimiser based on studies by Doshi and Gupta that compared the performance of several Deep Learning Optimizers, with Adam achieving the best results in both experiments.

# %%
# Optimizer
opt = tf.keras.optimizers.Adam(learning_rate=PARAM_LEARNING_RATE)

# Input Layer
model_input = Input(shape=(PARAM_WINDOW_SIZE, X_train_norm.shape[1]))

# LSTM Layer
x = LSTM(HIDDEN_LAYER_NODES, return_sequences=True)(model_input)
x = Dropout(PARAM_DROPOUT)(x)

# Attention Layer
x = Attention(HIDDEN_LAYER_NODES)(x)
x = Dropout(PARAM_DROPOUT)(x)

# Output Layer
x = Dense(1)(x)

# Complie Model
model = Model(model_input, x)
model.compile(loss='mean_squared_error', optimizer=opt)

# Print model summary
print(model.summary())
# Out:
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 10, 6)]           0
#
#  lstm_1 (LSTM)               (None, 10, 50)            11400
#
#  dropout_2 (Dropout)         (None, 10, 50)            0
#
#  attention_1 (Attention)     (None, 50)                7500
#
#  dropout_3 (Dropout)         (None, 50)                0
#
#  dense_1 (Dense)             (None, 1)                 51
#
# =================================================================
# Total params: 18,951
# Trainable params: 18,951
# Non-trainable params: 0
# _________________________________________________________________
# None

# %% [markdown]
# ### Model training

# %% [markdown]
# The complied model will then be trained by fitting the model to the reshaped 3D training dataset, and in order to gain a full understanding of model performance a validation set will be utilised during training. The validation set is a subset of the training set that is used to evaluate the model after each epoch. This validation process indicates that the model training is progressing in the right direction and can help avoid overfitting, which occurs when the model becomes very good at classifying samples in the training set but is unable to generalise and make accurate classifications on data it has never seen before. The history of the trained model will be stored to plot the decrease in training and validation loss as the number of epochs increases, which can provide a useful indication to the model’s speed of convergence (based on its slope), whether it has already converged (if the loss has plateaued), or whether the model may be overfitting (an inflection in the validation line).

# %%
# Train the model on the training dataset
history = model.fit(X_train_S, y_train_S, batch_size = PARAM_BATCH_SIZE, epochs = PARAM_EPOCHS, validation_split=.30, verbose = 1)
# Out:
# Epoch 1/100
# 29/29 [==============================] - 5s 65ms/step - loss: 0.2313 - val_loss: 0.0706
# Epoch 2/100
# 29/29 [==============================] - 1s 23ms/step - loss: 0.0411 - val_loss: 0.0195
# Epoch 3/100
# 29/29 [==============================] - 1s 24ms/step - loss: 0.0227 - val_loss: 0.0171
# Epoch 4/100
# 29/29 [==============================] - 1s 18ms/step - loss: 0.0216 - val_loss: 0.0164
# Epoch 5/100
# 29/29 [==============================] - 1s 17ms/step - loss: 0.0211 - val_loss: 0.0149
# Epoch 6/100
# 29/29 [==============================] - 1s 22ms/step - loss: 0.0213 - val_loss: 0.0125
# Epoch 7/100
# 29/29 [==============================] - 1s 24ms/step - loss: 0.0204 - val_loss: 0.0125
# Epoch 8/100
# 29/29 [==============================] - 1s 21ms/step - loss: 0.0182 - val_loss: 0.0126
# Epoch 9/100
# 29/29 [==============================] - 1s 23ms/step - loss: 0.0179 - val_loss: 0.0129
# Epoch 10/100
# 29/29 [==============================] - 1s 23ms/step - loss: 0.0181 - val_loss: 0.0122
# Epoch 11/100
# 29/29 [==============================] - 1s 23ms/step - loss: 0.0173 - val_loss: 0.0109
# Epoch 12/100
# 29/29 [==============================] - 1s 23ms/step - loss: 0.0163 - val_loss: 0.0110
# Epoch 13/100
# 29/29 [==============================] - 1s 20ms/step - loss: 0.0150 - val_loss: 0.0087
# Epoch 14/100
# 29/29 [==============================] - 1s 19ms/step - loss: 0.0142 - val_loss: 0.0104
# Epoch 15/100
# 29/29 [==============================] - 1s 22ms/step - loss: 0.0144 - val_loss: 0.0087
# Epoch 16/100
# 29/29 [==============================] - 1s 24ms/step - loss: 0.0133 - val_loss: 0.0087
# Epoch 17/100
# 29/29 [==============================] - 1s 24ms/step - loss: 0.0131 - val_loss: 0.0088
# Epoch 18/100
# 29/29 [==============================] - 1s 25ms/step - loss: 0.0136 - val_loss: 0.0090
# Epoch 19/100
# 29/29 [==============================] - 1s 19ms/step - loss: 0.0127 - val_loss: 0.0096
# Epoch 20/100
# 29/29 [==============================] - 1s 27ms/step - loss: 0.0116 - val_loss: 0.0084
# Epoch 21/100
# 29/29 [==============================] - 1s 22ms/step - loss: 0.0122 - val_loss: 0.0088
# Epoch 22/100
# 29/29 [==============================] - 1s 24ms/step - loss: 0.0116 - val_loss: 0.0086
# Epoch 23/100
# 29/29 [==============================] - 1s 24ms/step - loss: 0.0122 - val_loss: 0.0083
# Epoch 24/100
# 29/29 [==============================] - 1s 22ms/step - loss: 0.0108 - val_loss: 0.0087
# Epoch 25/100
# 29/29 [==============================] - 1s 27ms/step - loss: 0.0109 - val_loss: 0.0066
# Epoch 26/100
# 29/29 [==============================] - 1s 26ms/step - loss: 0.0108 - val_loss: 0.0048
# Epoch 27/100
# 29/29 [==============================] - 1s 24ms/step - loss: 0.0108 - val_loss: 0.0052
# Epoch 28/100
# 29/29 [==============================] - 1s 23ms/step - loss: 0.0101 - val_loss: 0.0067
# Epoch 29/100
# 29/29 [==============================] - 1s 20ms/step - loss: 0.0099 - val_loss: 0.0076
# Epoch 30/100
# 29/29 [==============================] - 1s 24ms/step - loss: 0.0095 - val_loss: 0.0073
# Epoch 31/100
# 29/29 [==============================] - 1s 20ms/step - loss: 0.0096 - val_loss: 0.0076
# Epoch 32/100
# 29/29 [==============================] - 1s 23ms/step - loss: 0.0089 - val_loss: 0.0061
# Epoch 33/100
# 29/29 [==============================] - 1s 31ms/step - loss: 0.0096 - val_loss: 0.0072
# Epoch 34/100
# 29/29 [==============================] - 1s 27ms/step - loss: 0.0091 - val_loss: 0.0087
# Epoch 35/100
# 29/29 [==============================] - 1s 20ms/step - loss: 0.0091 - val_loss: 0.0080
# Epoch 36/100
# 29/29 [==============================] - 1s 20ms/step - loss: 0.0081 - val_loss: 0.0089
# Epoch 37/100
# 29/29 [==============================] - 1s 18ms/step - loss: 0.0083 - val_loss: 0.0082
# Epoch 38/100
# 29/29 [==============================] - 1s 23ms/step - loss: 0.0075 - val_loss: 0.0071
# Epoch 39/100
# 29/29 [==============================] - 1s 21ms/step - loss: 0.0076 - val_loss: 0.0077
# Epoch 40/100
# 29/29 [==============================] - 1s 22ms/step - loss: 0.0084 - val_loss: 0.0076
# Epoch 41/100
# 29/29 [==============================] - 1s 19ms/step - loss: 0.0076 - val_loss: 0.0066
# Epoch 42/100
# 29/29 [==============================] - 1s 21ms/step - loss: 0.0079 - val_loss: 0.0062
# Epoch 43/100
# 29/29 [==============================] - 1s 25ms/step - loss: 0.0077 - val_loss: 0.0058
# Epoch 44/100
# 29/29 [==============================] - 1s 21ms/step - loss: 0.0077 - val_loss: 0.0058
# Epoch 45/100
# 29/29 [==============================] - 1s 22ms/step - loss: 0.0073 - val_loss: 0.0054
# Epoch 46/100
# 29/29 [==============================] - 1s 19ms/step - loss: 0.0074 - val_loss: 0.0055
# Epoch 47/100
# 29/29 [==============================] - 1s 20ms/step - loss: 0.0071 - val_loss: 0.0054
# Epoch 48/100
# 29/29 [==============================] - 1s 18ms/step - loss: 0.0074 - val_loss: 0.0052
# Epoch 49/100
# 29/29 [==============================] - 0s 17ms/step - loss: 0.0072 - val_loss: 0.0058
# Epoch 50/100
# 29/29 [==============================] - 0s 11ms/step - loss: 0.0076 - val_loss: 0.0044
# Epoch 51/100
# 29/29 [==============================] - 0s 11ms/step - loss: 0.0072 - val_loss: 0.0051
# Epoch 52/100
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0071 - val_loss: 0.0052
# Epoch 53/100
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0074 - val_loss: 0.0052
# Epoch 54/100
# 29/29 [==============================] - 0s 11ms/step - loss: 0.0067 - val_loss: 0.0051
# Epoch 55/100
# 29/29 [==============================] - 0s 11ms/step - loss: 0.0068 - val_loss: 0.0057
# Epoch 56/100
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0066 - val_loss: 0.0053
# Epoch 57/100
# 29/29 [==============================] - 0s 11ms/step - loss: 0.0068 - val_loss: 0.0053
# Epoch 58/100
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0061 - val_loss: 0.0049
# Epoch 59/100
# 29/29 [==============================] - 0s 11ms/step - loss: 0.0066 - val_loss: 0.0056
# Epoch 60/100
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0067 - val_loss: 0.0040
# Epoch 61/100
# 29/29 [==============================] - 0s 13ms/step - loss: 0.0068 - val_loss: 0.0047
# Epoch 62/100
# 29/29 [==============================] - 0s 11ms/step - loss: 0.0063 - val_loss: 0.0045
# Epoch 63/100
# 29/29 [==============================] - 0s 11ms/step - loss: 0.0062 - val_loss: 0.0048
# Epoch 64/100
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0063 - val_loss: 0.0044
# Epoch 65/100
# 29/29 [==============================] - 0s 11ms/step - loss: 0.0061 - val_loss: 0.0043
# Epoch 66/100
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0063 - val_loss: 0.0040
# Epoch 67/100
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0063 - val_loss: 0.0043
# Epoch 68/100
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0056 - val_loss: 0.0050
# Epoch 69/100
# 29/29 [==============================] - 0s 11ms/step - loss: 0.0066 - val_loss: 0.0045
# Epoch 70/100
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0059 - val_loss: 0.0049
# Epoch 71/100
# 29/29 [==============================] - 0s 11ms/step - loss: 0.0064 - val_loss: 0.0041
# Epoch 72/100
# 29/29 [==============================] - 0s 11ms/step - loss: 0.0062 - val_loss: 0.0054
# Epoch 73/100
# 29/29 [==============================] - 0s 13ms/step - loss: 0.0059 - val_loss: 0.0046
# Epoch 74/100
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0059 - val_loss: 0.0045
# Epoch 75/100
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0058 - val_loss: 0.0041
# Epoch 76/100
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0061 - val_loss: 0.0042
# Epoch 77/100
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0057 - val_loss: 0.0045
# Epoch 78/100
# 29/29 [==============================] - 0s 13ms/step - loss: 0.0058 - val_loss: 0.0050
# Epoch 79/100
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0061 - val_loss: 0.0042
# Epoch 80/100
# 29/29 [==============================] - 0s 11ms/step - loss: 0.0054 - val_loss: 0.0041
# Epoch 81/100
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0056 - val_loss: 0.0042
# Epoch 82/100
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0059 - val_loss: 0.0034
# Epoch 83/100
# 29/29 [==============================] - 0s 11ms/step - loss: 0.0053 - val_loss: 0.0035
# Epoch 84/100
# 29/29 [==============================] - 0s 11ms/step - loss: 0.0054 - val_loss: 0.0038
# Epoch 85/100
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0057 - val_loss: 0.0040
# Epoch 86/100
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0056 - val_loss: 0.0039
# Epoch 87/100
# 29/29 [==============================] - 0s 11ms/step - loss: 0.0059 - val_loss: 0.0041
# Epoch 88/100
# 29/29 [==============================] - 0s 11ms/step - loss: 0.0058 - val_loss: 0.0036
# Epoch 89/100
# 29/29 [==============================] - 0s 11ms/step - loss: 0.0053 - val_loss: 0.0035
# Epoch 90/100
# 29/29 [==============================] - 0s 11ms/step - loss: 0.0054 - val_loss: 0.0036
# Epoch 91/100
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0056 - val_loss: 0.0034
# Epoch 92/100
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0056 - val_loss: 0.0034
# Epoch 93/100
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0058 - val_loss: 0.0031
# Epoch 94/100
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0052 - val_loss: 0.0044
# Epoch 95/100
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0055 - val_loss: 0.0080
# Epoch 96/100
# 29/29 [==============================] - 0s 11ms/step - loss: 0.0058 - val_loss: 0.0072
# Epoch 97/100
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0057 - val_loss: 0.0052
# Epoch 98/100
# 29/29 [==============================] - 0s 11ms/step - loss: 0.0053 - val_loss: 0.0045
# Epoch 99/100
# 29/29 [==============================] - 0s 11ms/step - loss: 0.0056 - val_loss: 0.0047
# Epoch 100/100
# 29/29 [==============================] - 0s 12ms/step - loss: 0.0057 - val_loss: 0.0037

# %%
# Plot training & validation loss values
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Training', 'Validation'], loc='upper right')
plt.show()

# %% [markdown]
# ## Model Predictions

# %% [markdown]
# ### Pre-process Testing Dataset

# %% [markdown]
# After the model has been trained, its fit is assessed by feeding in the training data and comparing the model's predicted values to the actual values. Prior to this, the last T samples of the training dataset must be concatenated with the testing dataset to ensure the model has prior knowledge upon which to base its initial sample. T relates back to the time step or window size described in section 3.2.1.1.

# %%
# Add last [window_size] samples of the training dataset to the testing datset
train_last_samples=x_train.iloc[-PARAM_WINDOW_SIZE:]

# Concetenate the last 14 samples of the training set to the start of the test set
test_full = pd.concat((train_last_samples, x_test), axis=0)

# Print shape & head
display(test_full.tail())
display(test_full.shape)
# Out:
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2019-12-23  8950.200195  8956.639648  8934.549805  8945.650391  8945.650391
# 2019-12-24  8955.009766  8957.120117  8934.360352  8952.879883  8952.879883
# 2019-12-26  8970.209961  9022.459961  8968.459961  9022.389648  9022.389648
# 2019-12-27  9049.469727  9052.000000  8987.320312  9006.620117  9006.620117
# 2019-12-30  9004.450195  9006.360352  8909.190430  8945.990234  8945.990234
#
#                 Volume
# Date
# 2019-12-23  2025450000
# 2019-12-24  1014520000
# 2019-12-26  1634920000
# 2019-12-27  1832200000
# 2019-12-30  2042420000
# (1016, 6)

# %% [markdown]
# This modified testing dataset must then be normalised using the same scalar as the training dataset to prevent data leakage

# %%
# Normalise dataset
X_test_norm = scaler_X.fit_transform(test_full)
y_test_norm = scaler_y.fit_transform(y_test)

display(pd.DataFrame(X_test_norm, columns=['Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']))
display(X_test_norm.shape)
# Out:
#           Open      High       Low     Close  Adj Close    Volume
# 0    -0.662709 -0.669760 -0.672272 -0.661747  -0.661747 -0.139191
# 1    -0.640480 -0.665729 -0.668119 -0.690589  -0.690589 -0.202771
# 2    -0.683782 -0.704433 -0.702120 -0.724011  -0.724011  0.649277
# 3    -0.694154 -0.716020 -0.698938 -0.704732  -0.704732 -0.304862
# 4    -0.681257 -0.699692 -0.684224 -0.691194  -0.691194 -0.358106
# ...        ...       ...       ...       ...        ...       ...
# 1011  0.958900  0.959922  0.977909  0.967726   0.967726 -0.144281
# 1012  0.960891  0.960124  0.977830  0.970767   0.970767 -0.605397
# 1013  0.967185  0.987585  0.992105  1.000000   1.000000 -0.322414
# 1014  1.000000  1.000000  1.000000  0.993368   0.993368 -0.232428
# 1015  0.981361  0.980819  0.967293  0.967869   0.967869 -0.136540
#
# [1016 rows x 6 columns]
# (1016, 6)

# %% [markdown]
# The data is then regularised into the same [B, T, D] structure as the training set for input into the LSTM-Attention model:

# %%
X_test_S = []

for i in range(PARAM_WINDOW_SIZE, X_test_norm.shape[0]):
    X_test_S.append(X_test_norm[i - PARAM_WINDOW_SIZE : i])
X_test_S = np.array(X_test_S)

print('X_train shape == {}.'.format(X_test_S.shape))
# Out:
# X_train shape == (1006, 10, 6).

# %% [markdown]
# ### Make predictions

# %%
# Find the predicted values
predicted_stock_price = model.predict(X_test_S)

norm_values = predicted_stock_price

# Reverse normalise the values
predicted_stock_price = scaler_y.inverse_transform(predicted_stock_price)

# Convert to dataframe
predicted_stock_price = pd.DataFrame(predicted_stock_price)

# Name column
predicted_stock_price.columns=['Pred. Close']

# Set indicies of this df to the indicies of test_set
predicted_stock_price = predicted_stock_price.set_index(y_test.index)

# Display the first 10 predicted values
display(predicted_stock_price[:10])
display(predicted_stock_price.shape)
# Out:
#             Pred. Close
# Date
# 2015-12-31  5071.392090
# 2016-01-04  5058.574707
# 2016-01-05  5008.725586
# 2016-01-06  4972.401367
# 2016-01-07  4932.628906
# 2016-01-08  4870.451172
# 2016-01-11  4816.191895
# 2016-01-12  4772.571289
# 2016-01-13  4750.467285
# 2016-01-14  4703.861816
# (1006, 1)

# %% [markdown]
# ### Results and Final Measurements

# %%
# Get the real values of the stock price
real_stock_price = y_test

# Plot the real vs predicted stock price values
plt.figure(figsize=(12, 6))
plt.plot(real_stock_price, color='red', label = 'Real Stock Price')
plt.plot(predicted_stock_price, color='blue', label='Predicted Stock Price')
plt.title('Stock Price Prediction for ' + dataset_Name + " dataset")
plt.xlabel('Date')
plt.ylabel('Stock Price')
plt.legend()
plt.show()

# %% [markdown]
# Find the final performance metrics for the model predictions, discussed in Section 3.3.

# %%
def mean_directional_accuracy(actual: np.ndarray, predicted: np.ndarray):
  return np.mean((np.sign(actual[1:] - actual[:-1]) == np.sign(predicted[1:] - predicted[:-1])).astype(int))

# %%
# Calculate MSE
from sklearn.metrics import mean_squared_error
MSE = mean_squared_error(real_stock_price, predicted_stock_price)

# Calculate RMSE
RMSE = mean_squared_error(real_stock_price, predicted_stock_price, squared=False)

# Calculate MAE
from sklearn.metrics import mean_absolute_error
MAE = mean_absolute_error(real_stock_price, predicted_stock_price)

# Calculate R^2 value
from sklearn.metrics import r2_score
R2 = r2_score(real_stock_price, predicted_stock_price)

MDA = mean_directional_accuracy(real_stock_price.reset_index().drop(columns=['Date']).values, predicted_stock_price.reset_index().drop(columns=['Date']).values)

# Print results
print("MSE = ", MSE)
print("RMSE = ", RMSE)
print("MAE = ", MAE)
print("R2 = ", R2)
print("MDA = ", MDA)
# Out:
# MSE =  22108.328043503978
# RMSE =  148.68869507633718
# MAE =  117.9729979498012
# R2 =  0.9847749417975108
# MDA =  0.5482587064676617

# %% [markdown]
# # Trading Strategy

# %% [markdown]
# ## Parameters

# %%
DATES = predicted_stock_price.index.tolist()
STARTING_MONEY = 1000000 
BUY_VALUE = 100000
SELL_VALUE = 100000
CASH_LIMIT = 500000
SHORT_LIMIT = 500000
THRESH_PROFIT = 250

# %% [markdown]
# ## Naive

# %% [markdown]
# The system begins the simulation with a predetermined sum of money, in this example 1,000,000 USD, and then attempts to estimate the stock's closing price for the next day. If the stock price is anticipated to increase, the system will transmit signals to acquire 100,000 USD worth of stock, and if the price is anticipated to decrease, the model will short 100,000 USD worth of stock. The system will maintain a position for wait_time days following a purchase, and if during that period the acquired stock can be sold for a profit of threshold_profit the system will instantly sell the stock, or if during that period stock can be purchased at a price lower than the shorted price the system will immediately close the short position. If the wait_time period has expired and the stock or short position has not been sold or closed, the system will promptly terminate the position and, if required, incur a loss. At the beginning of every day, the system will calculate the percentage change in the actual stock price and increase or decrease the value of the stock or shorts it has acquired by the same amount. The duration of the simulation is proportional to the number of samples in the testing dataset used to create the model predictions. Upon completion of the simulation, all final positions are closed in order to calculate the final profitability metrics covered next in Section 3.3. Important to note, the proposed methodology is naïve and based on the assumptions that transaction costs are not considered and have no impact on profitability, and that created buy and sell orders are instantly executed and have no impact on the market.

# %%
def get_change(current, previous):
    if current == previous:
        return 0
    try:
        return ((current - previous) / previous) * 100.0
    except ZeroDivisionError:
        return 0

# %%
def naive_trading_strat(MAX_HOLD_TIME = PARAM_WINDOW_SIZE):

  available_money = STARTING_MONEY
  stock_value = 0
  short_value = 0
  days = 0
  holding_time = 0
  purchase_price = 0

  total_val_history = []

  for x in range(0, predicted_stock_price.size-1):
    
    # Print the current date
    print("\n", DATES[x])

    # Find and print the current price of the stock
    actual_price_string = "\tActual price = %.3f" % real_stock_price.iloc[x,0]
    if x == 0:
      print(actual_price_string)
    else: # If this isn't the first iteration, also print the % change from yesterday's price
      actual_price_difference = get_change(real_stock_price.iloc[x,0], real_stock_price.iloc[x-1,0])
      print(actual_price_string, "(%.3f" % actual_price_difference, "%)")

      # change investment values by change in stock
      if stock_value > 0:
        change_in_stock = stock_value * (actual_price_difference/100)
        stock_value = stock_value + change_in_stock
        print("\t\tStock changed by = ", change_in_stock, " to ", stock_value)
      if short_value > 0:
        change_in_short = short_value * (actual_price_difference/100) * -1
        short_value = short_value + change_in_short
        print("\t\tShort changed by = ", change_in_short, " to ", short_value) 

    purchase_position = True
    sell_position = False
    
    # If we are currently holding stock
    if stock_value > 0:

      # increment holding time
      holding_time = holding_time + 1
      print("\n\tCurrently holding Stock for ", holding_time, " days")

      # Has Simulation has held onto stock for MAX_HOLD_TIME days
      if holding_time == MAX_HOLD_TIME:
        sell_position = True
        print("\t\tLimit Reached")
      
      # Simulation hasn't held onto stock for MAX_HOLD_TIME days
      else:

        # Can stock be sold to make THRESH_PROFIT?
        if stock_value - purchase_price > THRESH_PROFIT:
          sell_position = True
          print("\tStock can be sold for profit of ", stock_value - purchase_price)

      # If the simulation has chosen to sell the stock
      if sell_position == True:
        
        # Sell stock
        print("\tSelling Stock")
        available_money = available_money + stock_value
        stock_value = 0

        # Reset variables as we are not holding any stocks anymore
        sell_position = False
        holding_time = 0
        purchase_price = 0

        # Print information
        print("\t\tPortfolio value = ", available_money + stock_value + short_value)
        print("\t\t\tCash = ", available_money)
        print("\t\t\tStock value = ", stock_value)
        print("\t\t\tShort value = ", short_value)

      # Sim has decided not to sell stock, so we do not purchase any more stock
      else:
        print("\t\tHolding Stock")
        purchase_position = False


    # If we are currently holding shorts
    elif short_value > 0:

      # increment holding time
      holding_time = holding_time + 1
      print("\n\tCurrently holding Short for ", holding_time, " days")

      # Has Simulation has held onto short for MAX_HOLD_TIME days
      if holding_time == MAX_HOLD_TIME:
        sell_position = True
        print("\t\tLimit Reached")
      
      # Simulation hasn't held onto short for MAX_HOLD_TIME days
      else: 

        # Can short be closed at price lower than the shorted price?
        if short_value - purchase_price > THRESH_PROFIT:
          sell_position = True
          print("\tShort can be closed for profit of ", short_value - purchase_price)

      # If the simulation has chosen to close the short
      if sell_position == True:

        # Close enitre short position
        print("\t\tClosing Short at ", real_stock_price.iloc[x,0])
        available_money = available_money + short_value
        short_value = 0

        # Reset variables as we are not holding any stocks anymore
        sell_position = False
        holding_time = 0
        purchase_price = 0

        # Print information
        print("\t\tPortfolio value = ", available_money + stock_value + short_value)
        print("\t\t\tCash = ", available_money)
        print("\t\t\tStock value = ", stock_value)
        print("\t\t\tShort value = ", short_value)

      # Sim has decided not to close short, so we do not purchase any more shorts
      else:
        purchase_position = False
        print("\t\tHolding Short")



    if purchase_position == True:
      print("\n\tPurchasing new position")

      # Find the percentage change in the market the model expects
      prediction = get_change(predicted_stock_price.iat[x+1,0], real_stock_price.iat[x,0])
      print("\t\tPred. change in price = %.3f" % prediction, "%")



      # Indicates a price rise, so purchase stock
      if prediction > 0: 


        # If we have no shorts, purchase stock normally
        if short_value == 0:

          # Check we are not at the min. amount of available money
          if available_money - BUY_VALUE > CASH_LIMIT:

            purchase_price = BUY_VALUE
            print("\t\tBuy Stock at ", real_stock_price.iloc[x,0])

            # Move money from cash to stock_value
            available_money = available_money - BUY_VALUE
            stock_value = stock_value + BUY_VALUE

          # Reached min. amount of available money, do nothing
          else:
            print("\t\tHit cash limit. No transaction excecuted.")


        elif short_value > 0: # We have shorts, so close them

          print("\t\tClosing Short at ", real_stock_price.iloc[x,0])

          # If we have less shorts than BUY_VALUE close the rest of the shorts
          if short_value < BUY_VALUE:
            available_money = available_money + short_value
            short_value = 0

          # Else just close BUY_VALUE of shorts
          else:
            available_money = available_money + BUY_VALUE
            short_value = short_value - BUY_VALUE



      elif prediction < 0: # PRICE FALL
        
        # If we have bought stock available sell it
        if stock_value > 0:

            print("\t\tSell Stock at ", real_stock_price.iloc[x,0])

            # if the value of our stock is less than the transaction volume sell it all
            if stock_value < SELL_VALUE:
              available_money = available_money + stock_value
              stock_value = 0
            else:
              available_money = available_money + SELL_VALUE
              stock_value = stock_value - SELL_VALUE

        # If we have no bought stock, short the stock
        else:

          # Check we wont go over the max short value
          if short_value < SHORT_LIMIT:

              print("\t\tShort at ", real_stock_price.iloc[x,0])
              purchase_price = SELL_VALUE

              # Move money from cash to short
              available_money = available_money - SELL_VALUE
              short_value = short_value + SELL_VALUE

          else:
            print("\t\tHit short limit. No transaction excecuted.")

    # Print information
    print("\n\tPortfolio value = ", available_money + stock_value + short_value)
    print("\t\tCash = ", available_money)
    print("\t\tStock value = ", stock_value)
    print("\t\tShort value = ", short_value)

    total_val_history.append(available_money + stock_value + short_value)

    days = days + 1

  total_profit = available_money + stock_value + short_value - STARTING_MONEY
  profitability = (((available_money + stock_value + short_value)/STARTING_MONEY)-1)*100
  profit_per_day = (available_money + stock_value + short_value - STARTING_MONEY) / days

  return total_val_history, total_profit, profitability, profit_per_day

naive_history, naive_profit, naive_profitability, naive_ppd = naive_trading_strat()

print("\nTotal profit = ", naive_profit)
print("Profitability = ", naive_profitability, "%")
print("Profit per day (PPD) = ", naive_ppd)
# Out:
# Streaming output truncated to the last 5000 lines.
# 	Portfolio value =  1008753.4236542454
# 		Cash =  909601.6377033105
# 		Stock value =  99151.78595093497
# 		Short value =  0
#
#  2018-07-31 00:00:00
# 	Actual price = 7707.290 (0.463 %)
# 		Stock changed by =  458.80927180435776  to  99610.59522273933
#
# 	Currently holding Stock for  3  days
# 		Holding Stock
#
# 	Portfolio value =  1009212.2329260497
# 		Cash =  909601.6377033105
# 		Stock value =  99610.59522273933
# 		Short value =  0
#
#  2018-08-01 00:00:00
# 	Actual price = 7802.690 (1.238 %)
# 		Stock changed by =  1232.9678795645855  to  100843.56310230392
#
# 	Currently holding Stock for  4  days
# 	Stock can be sold for profit of  843.5631023039168
# 	Selling Stock
# 		Portfolio value =  1010445.2008056144
# 			Cash =  1010445.2008056144
# 			Stock value =  0
# 			Short value =  0
#
# 	Purchasing new position
# 		Pred. change in price = -2.072 %
# 		Short at  7802.68994140625
#
# 	Portfolio value =  1010445.2008056144
# 		Cash =  910445.2008056144
# 		Stock value =  0
# 		Short value =  100000
#
#  2018-08-02 00:00:00
# 	Actual price = 7812.010 (0.119 %)
# 		Short changed by =  -119.44373400374181  to  99880.55626599626
#
# 	Currently holding Short for  1  days
# 		Holding Short
#
# 	Portfolio value =  1010325.7570716107
# 		Cash =  910445.2008056144
# 		Stock value =  0
# 		Short value =  99880.55626599626
#
#  2018-08-03 00:00:00
# 	Actual price = 7859.680 (0.610 %)
# 		Short changed by =  -609.4906722704943  to  99271.06559372577
#
# 	Currently holding Short for  2  days
# 		Holding Short
#
# 	Portfolio value =  1009716.2663993401
# 		Cash =  910445.2008056144
# 		Stock value =  0
# 		Short value =  99271.06559372577
#
#  2018-08-06 00:00:00
# 	Actual price = 7883.660 (0.305 %)
# 		Short changed by =  -302.87723683526616  to  98968.1883568905
#
# 	Currently holding Short for  3  days
# 		Holding Short
#
# 	Portfolio value =  1009413.3891625048
# 		Cash =  910445.2008056144
# 		Stock value =  0
# 		Short value =  98968.1883568905
#
#  2018-08-07 00:00:00
# 	Actual price = 7888.330 (0.059 %)
# 		Short changed by =  -58.62425555857601  to  98909.56410133193
#
# 	Currently holding Short for  4  days
# 		Holding Short
#
# 	Portfolio value =  1009354.7649069463
# 		Cash =  910445.2008056144
# 		Stock value =  0
# 		Short value =  98909.56410133193
#
#  2018-08-08 00:00:00
# 	Actual price = 7891.780 (0.044 %)
# 		Short changed by =  -43.25491141457664  to  98866.30918991735
#
# 	Currently holding Short for  5  days
# 		Holding Short
#
# 	Portfolio value =  1009311.5099955318
# 		Cash =  910445.2008056144
# 		Stock value =  0
# 		Short value =  98866.30918991735
#
#  2018-08-09 00:00:00
# 	Actual price = 7839.110 (-0.667 %)
# 		Short changed by =  659.836047490451  to  99526.14523740779
#
# 	Currently holding Short for  6  days
# 		Holding Short
#
# 	Portfolio value =  1009971.3460430221
# 		Cash =  910445.2008056144
# 		Stock value =  0
# 		Short value =  99526.14523740779
#
#  2018-08-10 00:00:00
# 	Actual price = 7819.710 (-0.247 %)
# 		Short changed by =  246.30315583399772  to  99772.4483932418
#
# 	Currently holding Short for  7  days
# 		Holding Short
#
# 	Portfolio value =  1010217.6491988562
# 		Cash =  910445.2008056144
# 		Stock value =  0
# 		Short value =  99772.4483932418
#
#  2018-08-13 00:00:00
# 	Actual price = 7870.890 (0.655 %)
# 		Short changed by =  -653.012895925824  to  99119.43549731596
#
# 	Currently holding Short for  8  days
# 		Holding Short
#
# 	Portfolio value =  1009564.6363029303
# 		Cash =  910445.2008056144
# 		Stock value =  0
# 		Short value =  99119.43549731596
#
#  2018-08-14 00:00:00
# 	Actual price = 7774.120 (-1.229 %)
# 		Short changed by =  1218.6410358156015  to  100338.07653313156
#
# 	Currently holding Short for  9  days
# 	Short can be closed for profit of  338.07653313156334
# 		Closing Short at  7774.1201171875
# 		Portfolio value =  1010783.2773387459
# 			Cash =  1010783.2773387459
# 			Stock value =  0
# 			Short value =  0
#
# 	Purchasing new position
# 		Pred. change in price = -0.356 %
# 		Short at  7774.1201171875
#
# 	Portfolio value =  1010783.2773387459
# 		Cash =  910783.2773387459
# 		Stock value =  0
# 		Short value =  100000
#
#  2018-08-15 00:00:00
# 	Actual price = 7806.520 (0.417 %)
# 		Short changed by =  -416.7661658856842  to  99583.23383411432
#
# 	Currently holding Short for  1  days
# 		Holding Short
#
# 	Portfolio value =  1010366.5111728602
# 		Cash =  910783.2773387459
# 		Stock value =  0
# 		Short value =  99583.23383411432
#
#  2018-08-16 00:00:00
# 	Actual price = 7816.330 (0.126 %)
# 		Short changed by =  -125.14120970978165  to  99458.09262440454
#
# 	Currently holding Short for  2  days
# 		Holding Short
#
# 	Portfolio value =  1010241.3699631505
# 		Cash =  910783.2773387459
# 		Stock value =  0
# 		Short value =  99458.09262440454
#
#  2018-08-17 00:00:00
# 	Actual price = 7821.010 (0.060 %)
# 		Short changed by =  -59.546204955039116  to  99398.5464194495
#
# 	Currently holding Short for  3  days
# 		Holding Short
#
# 	Portfolio value =  1010181.8237581954
# 		Cash =  910783.2773387459
# 		Stock value =  0
# 		Short value =  99398.5464194495
#
#  2018-08-20 00:00:00
# 	Actual price = 7859.170 (0.488 %)
# 		Short changed by =  -484.9839312386993  to  98913.5624882108
#
# 	Currently holding Short for  4  days
# 		Holding Short
#
# 	Portfolio value =  1009696.8398269566
# 		Cash =  910783.2773387459
# 		Stock value =  0
# 		Short value =  98913.5624882108
#
#  2018-08-21 00:00:00
# 	Actual price = 7889.100 (0.381 %)
# 		Short changed by =  -376.6937656076921  to  98536.8687226031
#
# 	Currently holding Short for  5  days
# 		Holding Short
#
# 	Portfolio value =  1009320.146061349
# 		Cash =  910783.2773387459
# 		Stock value =  0
# 		Short value =  98536.8687226031
#
#  2018-08-22 00:00:00
# 	Actual price = 7878.460 (-0.135 %)
# 		Short changed by =  132.89801651236462  to  98669.76673911547
#
# 	Currently holding Short for  6  days
# 		Holding Short
#
# 	Portfolio value =  1009453.0440778614
# 		Cash =  910783.2773387459
# 		Stock value =  0
# 		Short value =  98669.76673911547
#
#  2018-08-23 00:00:00
# 	Actual price = 7945.980 (0.857 %)
# 		Short changed by =  -845.6201605898863  to  97824.14657852559
#
# 	Currently holding Short for  7  days
# 		Holding Short
#
# 	Portfolio value =  1008607.4239172714
# 		Cash =  910783.2773387459
# 		Stock value =  0
# 		Short value =  97824.14657852559
#
#  2018-08-24 00:00:00
# 	Actual price = 8017.900 (0.905 %)
# 		Short changed by =  -885.4169022209227  to  96938.72967630466
#
# 	Currently holding Short for  8  days
# 		Holding Short
#
# 	Portfolio value =  1007722.0070150505
# 		Cash =  910783.2773387459
# 		Stock value =  0
# 		Short value =  96938.72967630466
#
#  2018-08-27 00:00:00
# 	Actual price = 8030.040 (0.151 %)
# 		Short changed by =  -146.77776549296607  to  96791.9519108117
#
# 	Currently holding Short for  9  days
# 		Holding Short
#
# 	Portfolio value =  1007575.2292495576
# 		Cash =  910783.2773387459
# 		Stock value =  0
# 		Short value =  96791.9519108117
#
#  2018-08-28 00:00:00
# 	Actual price = 8109.690 (0.992 %)
# 		Short changed by =  -960.0785898767662  to  95831.87332093493
#
# 	Currently holding Short for  10  days
# 		Limit Reached
# 		Closing Short at  8109.68994140625
# 		Portfolio value =  1006615.1506596808
# 			Cash =  1006615.1506596808
# 			Stock value =  0
# 			Short value =  0
#
# 	Purchasing new position
# 		Pred. change in price = -3.429 %
# 		Short at  8109.68994140625
#
# 	Portfolio value =  1006615.1506596808
# 		Cash =  906615.1506596808
# 		Stock value =  0
# 		Short value =  100000
#
#  2018-08-29 00:00:00
# 	Actual price = 8088.360 (-0.263 %)
# 		Short changed by =  263.01965030861936  to  100263.01965030862
#
# 	Currently holding Short for  1  days
# 	Short can be closed for profit of  263.019650308619
# 		Closing Short at  8088.35986328125
# 		Portfolio value =  1006878.1703099895
# 			Cash =  1006878.1703099895
# 			Stock value =  0
# 			Short value =  0
#
# 	Purchasing new position
# 		Pred. change in price = -2.733 %
# 		Short at  8088.35986328125
#
# 	Portfolio value =  1006878.1703099895
# 		Cash =  906878.1703099895
# 		Stock value =  0
# 		Short value =  100000
#
#  2018-08-30 00:00:00
# 	Actual price = 8109.540 (0.262 %)
# 		Short changed by =  -261.8599584991477  to  99738.14004150085
#
# 	Currently holding Short for  1  days
# 		Holding Short
#
# 	Portfolio value =  1006616.3103514903
# 		Cash =  906878.1703099895
# 		Stock value =  0
# 		Short value =  99738.14004150085
#
#  2018-08-31 00:00:00
# 	Actual price = 8091.250 (-0.226 %)
# 		Short changed by =  224.94672553476087  to  99963.08676703561
#
# 	Currently holding Short for  2  days
# 		Holding Short
#
# 	Portfolio value =  1006841.2570770251
# 		Cash =  906878.1703099895
# 		Stock value =  0
# 		Short value =  99963.08676703561
#
#  2018-09-04 00:00:00
# 	Actual price = 7995.170 (-1.187 %)
# 		Short changed by =  1187.0182216830447  to  101150.10498871865
#
# 	Currently holding Short for  3  days
# 	Short can be closed for profit of  1150.1049887186527
# 		Closing Short at  7995.169921875
# 		Portfolio value =  1008028.2752987081
# 			Cash =  1008028.2752987081
# 			Stock value =  0
# 			Short value =  0
#
# 	Purchasing new position
# 		Pred. change in price = -0.888 %
# 		Short at  7995.169921875
#
# 	Portfolio value =  1008028.2752987081
# 		Cash =  908028.2752987081
# 		Stock value =  0
# 		Short value =  100000
#
#  2018-09-05 00:00:00
# 	Actual price = 7922.730 (-0.906 %)
# 		Short changed by =  906.0463018809941  to  100906.046301881
#
# 	Currently holding Short for  1  days
# 	Short can be closed for profit of  906.0463018809969
# 		Closing Short at  7922.72998046875
# 		Portfolio value =  1008934.3216005891
# 			Cash =  1008934.3216005891
# 			Stock value =  0
# 			Short value =  0
#
# 	Purchasing new position
# 		Pred. change in price = -0.207 %
# 		Short at  7922.72998046875
#
# 	Portfolio value =  1008934.3216005891
# 		Cash =  908934.3216005891
# 		Stock value =  0
# 		Short value =  100000
#
#  2018-09-06 00:00:00
# 	Actual price = 7902.540 (-0.255 %)
# 		Short changed by =  254.83566215209393  to  100254.8356621521
#
# 	Currently holding Short for  1  days
# 	Short can be closed for profit of  254.8356621520943
# 		Closing Short at  7902.5400390625
# 		Portfolio value =  1009189.1572627411
# 			Cash =  1009189.1572627411
# 			Stock value =  0
# 			Short value =  0
#
# 	Purchasing new position
# 		Pred. change in price = -0.259 %
# 		Short at  7902.5400390625
#
# 	Portfolio value =  1009189.1572627411
# 		Cash =  909189.1572627411
# 		Stock value =  0
# 		Short value =  100000
#
#  2018-09-07 00:00:00
# 	Actual price = 7924.160 (0.274 %)
# 		Short changed by =  -273.58440552823646  to  99726.41559447176
#
# 	Currently holding Short for  1  days
# 		Holding Short
#
# 	Portfolio value =  1008915.5728572129
# 		Cash =  909189.1572627411
# 		Stock value =  0
# 		Short value =  99726.41559447176
#
#  2018-09-10 00:00:00
# 	Actual price = 7972.470 (0.610 %)
# 		Short changed by =  -607.9873306086166  to  99118.42826386314
#
# 	Currently holding Short for  2  days
# 		Holding Short
#
# 	Portfolio value =  1008307.5855266042
# 		Cash =  909189.1572627411
# 		Stock value =  0
# 		Short value =  99118.42826386314
#
#  2018-09-11 00:00:00
# 	Actual price = 7954.230 (-0.229 %)
# 		Short changed by =  226.77329782284062  to  99345.20156168599
#
# 	Currently holding Short for  3  days
# 		Holding Short
#
# 	Portfolio value =  1008534.3588244271
# 		Cash =  909189.1572627411
# 		Stock value =  0
# 		Short value =  99345.20156168599
#
#  2018-09-12 00:00:00
# 	Actual price = 8013.710 (0.748 %)
# 		Short changed by =  -742.881543915944  to  98602.32001777005
#
# 	Currently holding Short for  4  days
# 		Holding Short
#
# 	Portfolio value =  1007791.4772805112
# 		Cash =  909189.1572627411
# 		Stock value =  0
# 		Short value =  98602.32001777005
#
#  2018-09-13 00:00:00
# 	Actual price = 8010.040 (-0.046 %)
# 		Short changed by =  45.155466434753706  to  98647.4754842048
#
# 	Currently holding Short for  5  days
# 		Holding Short
#
# 	Portfolio value =  1007836.632746946
# 		Cash =  909189.1572627411
# 		Stock value =  0
# 		Short value =  98647.4754842048
#
#  2018-09-14 00:00:00
# 	Actual price = 7895.790 (-1.426 %)
# 		Short changed by =  1407.0434129052744  to  100054.51889711007
#
# 	Currently holding Short for  6  days
# 		Holding Short
#
# 	Portfolio value =  1009243.6761598513
# 		Cash =  909189.1572627411
# 		Stock value =  0
# 		Short value =  100054.51889711007
#
#  2018-09-17 00:00:00
# 	Actual price = 7956.110 (0.764 %)
# 		Short changed by =  -764.3656888426927  to  99290.15320826738
#
# 	Currently holding Short for  7  days
# 		Holding Short
#
# 	Portfolio value =  1008479.3104710085
# 		Cash =  909189.1572627411
# 		Stock value =  0
# 		Short value =  99290.15320826738
#
#  2018-09-18 00:00:00
# 	Actual price = 7950.040 (-0.076 %)
# 		Short changed by =  75.74980574468655  to  99365.90301401207
#
# 	Currently holding Short for  8  days
# 		Holding Short
#
# 	Portfolio value =  1008555.0602767532
# 		Cash =  909189.1572627411
# 		Stock value =  0
# 		Short value =  99365.90301401207
#
#  2018-09-19 00:00:00
# 	Actual price = 8028.230 (0.984 %)
# 		Short changed by =  -977.279874852168  to  98388.6231391599
#
# 	Currently holding Short for  9  days
# 		Holding Short
#
# 	Portfolio value =  1007577.780401901
# 		Cash =  909189.1572627411
# 		Stock value =  0
# 		Short value =  98388.6231391599
#
#  2018-09-20 00:00:00
# 	Actual price = 7986.960 (-0.514 %)
# 		Short changed by =  505.77778769223073  to  98894.40092685213
#
# 	Currently holding Short for  10  days
# 		Limit Reached
# 		Closing Short at  7986.9599609375
# 		Portfolio value =  1008083.5581895933
# 			Cash =  1008083.5581895933
# 			Stock value =  0
# 			Short value =  0
#
# 	Purchasing new position
# 		Pred. change in price = -1.800 %
# 		Short at  7986.9599609375
#
# 	Portfolio value =  1008083.5581895933
# 		Cash =  908083.5581895933
# 		Stock value =  0
# 		Short value =  100000
#
#  2018-09-21 00:00:00
# 	Actual price = 7993.250 (0.079 %)
# 		Short changed by =  -78.75385745343944  to  99921.24614254656
#
# 	Currently holding Short for  1  days
# 		Holding Short
#
# 	Portfolio value =  1008004.8043321398
# 		Cash =  908083.5581895933
# 		Stock value =  0
# 		Short value =  99921.24614254656
#
#  2018-09-24 00:00:00
# 	Actual price = 8007.470 (0.178 %)
# 		Short changed by =  -177.76268571635293  to  99743.4834568302
#
# 	Currently holding Short for  2  days
# 		Holding Short
#
# 	Portfolio value =  1007827.0416464235
# 		Cash =  908083.5581895933
# 		Stock value =  0
# 		Short value =  99743.4834568302
#
#  2018-09-25 00:00:00
# 	Actual price = 7990.370 (-0.214 %)
# 		Short changed by =  213.00401524123993  to  99956.48747207144
#
# 	Currently holding Short for  3  days
# 		Holding Short
#
# 	Portfolio value =  1008040.0456616647
# 		Cash =  908083.5581895933
# 		Stock value =  0
# 		Short value =  99956.48747207144
#
#  2018-09-26 00:00:00
# 	Actual price = 8041.970 (0.646 %)
# 		Short changed by =  -645.4975726143307  to  99310.98989945711
#
# 	Currently holding Short for  4  days
# 		Holding Short
#
# 	Portfolio value =  1007394.5480890503
# 		Cash =  908083.5581895933
# 		Stock value =  0
# 		Short value =  99310.98989945711
#
#  2018-09-27 00:00:00
# 	Actual price = 8046.350 (0.054 %)
# 		Short changed by =  -54.087553936736946  to  99256.90234552037
#
# 	Currently holding Short for  5  days
# 		Holding Short
#
# 	Portfolio value =  1007340.4605351136
# 		Cash =  908083.5581895933
# 		Stock value =  0
# 		Short value =  99256.90234552037
#
#  2018-09-28 00:00:00
# 	Actual price = 8037.300 (-0.112 %)
# 		Short changed by =  111.64118320668491  to  99368.54352872705
#
# 	Currently holding Short for  6  days
# 		Holding Short
#
# 	Portfolio value =  1007452.1017183203
# 		Cash =  908083.5581895933
# 		Stock value =  0
# 		Short value =  99368.54352872705
#
#  2018-10-01 00:00:00
# 	Actual price = 7999.550 (-0.470 %)
# 		Short changed by =  466.7192476783931  to  99835.26277640545
#
# 	Currently holding Short for  7  days
# 		Holding Short
#
# 	Portfolio value =  1007918.8209659987
# 		Cash =  908083.5581895933
# 		Stock value =  0
# 		Short value =  99835.26277640545
#
#  2018-10-02 00:00:00
# 	Actual price = 8025.090 (0.319 %)
# 		Short changed by =  -318.7425009380205  to  99516.52027546742
#
# 	Currently holding Short for  8  days
# 		Holding Short
#
# 	Portfolio value =  1007600.0784650607
# 		Cash =  908083.5581895933
# 		Stock value =  0
# 		Short value =  99516.52027546742
#
#  2018-10-03 00:00:00
# 	Actual price = 7879.510 (-1.814 %)
# 		Short changed by =  1805.2910407867598  to  101321.81131625418
#
# 	Currently holding Short for  9  days
# 	Short can be closed for profit of  1321.811316254185
# 		Closing Short at  7879.509765625
# 		Portfolio value =  1009405.3695058475
# 			Cash =  1009405.3695058475
# 			Stock value =  0
# 			Short value =  0
#
# 	Purchasing new position
# 		Pred. change in price = -0.036 %
# 		Short at  7879.509765625
#
# 	Portfolio value =  1009405.3695058475
# 		Cash =  909405.3695058475
# 		Stock value =  0
# 		Short value =  100000
#
#  2018-10-04 00:00:00
# 	Actual price = 7788.450 (-1.156 %)
# 		Short changed by =  1155.6501993278155  to  101155.65019932782
#
# 	Currently holding Short for  1  days
# 	Short can be closed for profit of  1155.6501993278216
# 		Closing Short at  7788.4501953125
# 		Portfolio value =  1010561.0197051753
# 			Cash =  1010561.0197051753
# 			Stock value =  0
# 			Short value =  0
#
# 	Purchasing new position
# 		Pred. change in price = 0.589 %
# 		Buy Stock at  7788.4501953125
#
# 	Portfolio value =  1010561.0197051753
# 		Cash =  910561.0197051753
# 		Stock value =  100000
# 		Short value =  0
#
#  2018-10-05 00:00:00
# 	Actual price = 7735.950 (-0.674 %)
# 		Stock changed by =  -674.0750557998981  to  99325.9249442001
#
# 	Currently holding Stock for  1  days
# 		Holding Stock
#
# 	Portfolio value =  1009886.9446493754
# 		Cash =  910561.0197051753
# 		Stock value =  99325.9249442001
# 		Short value =  0
#
#  2018-10-08 00:00:00
# 	Actual price = 7738.020 (0.027 %)
# 		Stock changed by =  26.575559538093078  to  99352.50050373819
#
# 	Currently holding Stock for  2  days
# 		Holding Stock
#
# 	Portfolio value =  1009913.5202089135
# 		Cash =  910561.0197051753
# 		Stock value =  99352.50050373819
# 		Short value =  0
#
#  2018-10-09 00:00:00
# 	Actual price = 7422.050 (-4.083 %)
# 		Stock changed by =  -4056.9074324172666  to  95295.59307132092
#
# 	Currently holding Stock for  3  days
# 		Holding Stock
#
# 	Portfolio value =  1005856.6127764962
# 		Cash =  910561.0197051753
# 		Stock value =  95295.59307132092
# 		Short value =  0
#
#  2018-10-10 00:00:00
# 	Actual price = 7329.060 (-1.253 %)
# 		Stock changed by =  -1193.944157846912  to  94101.64891347401
#
# 	Currently holding Stock for  4  days
# 		Holding Stock
#
# 	Portfolio value =  1004662.6686186494
# 		Cash =  910561.0197051753
# 		Stock value =  94101.64891347401
# 		Short value =  0
#
#  2018-10-11 00:00:00
# 	Actual price = 7496.890 (2.290 %)
# 		Stock changed by =  2154.85846241925  to  96256.50737589326
#
# 	Currently holding Stock for  5  days
# 		Holding Stock
#
# 	Portfolio value =  1006817.5270810686
# 		Cash =  910561.0197051753
# 		Stock value =  96256.50737589326
# 		Short value =  0
#
#  2018-10-12 00:00:00
# 	Actual price = 7430.740 (-0.882 %)
# 		Stock changed by =  -849.3333164480206  to  95407.17405944524
#
# 	Currently holding Stock for  6  days
# 		Holding Stock
#
# 	Portfolio value =  1005968.1937646206
# 		Cash =  910561.0197051753
# 		Stock value =  95407.17405944524
# 		Short value =  0
#
#  2018-10-15 00:00:00
# 	Actual price = 7645.490 (2.890 %)
# 		Stock changed by =  2757.2879663433923  to  98164.46202578864
#
# 	Currently holding Stock for  7  days
# 		Holding Stock
#
# 	Portfolio value =  1008725.4817309639
# 		Cash =  910561.0197051753
# 		Stock value =  98164.46202578864
# 		Short value =  0
#
#  2018-10-16 00:00:00
# 	Actual price = 7642.700 (-0.036 %)
# 		Stock changed by =  -35.822775937877765  to  98128.63924985076
#
# 	Currently holding Stock for  8  days
# 		Holding Stock
#
# 	Portfolio value =  1008689.6589550261
# 		Cash =  910561.0197051753
# 		Stock value =  98128.63924985076
# 		Short value =  0
#
#  2018-10-17 00:00:00
# 	Actual price = 7485.140 (-2.062 %)
# 		Stock changed by =  -2022.9962912079475  to  96105.64295864281
#
# 	Currently holding Stock for  9  days
# 		Holding Stock
#
# 	Portfolio value =  1006666.6626638181
# 		Cash =  910561.0197051753
# 		Stock value =  96105.64295864281
# 		Short value =  0
#
#  2018-10-18 00:00:00
# 	Actual price = 7449.030 (-0.482 %)
# 		Stock changed by =  -463.63975703706905  to  95642.00320160574
#
# 	Currently holding Stock for  10  days
# 		Limit Reached
# 	Selling Stock
# 		Portfolio value =  1006203.022906781
# 			Cash =  1006203.022906781
# 			Stock value =  0
# 			Short value =  0
#
# 	Purchasing new position
# 		Pred. change in price = 0.082 %
# 		Buy Stock at  7449.02978515625
#
# 	Portfolio value =  1006203.022906781
# 		Cash =  906203.022906781
# 		Stock value =  100000
# 		Short value =  0
#
#  2018-10-19 00:00:00
# 	Actual price = 7468.630 (0.263 %)
# 		Stock changed by =  263.12282567734246  to  100263.12282567735
#
# 	Currently holding Stock for  1  days
# 	Stock can be sold for profit of  263.12282567734655
# 	Selling Stock
# 		Portfolio value =  1006466.1457324584
# 			Cash =  1006466.1457324584
# 			Stock value =  0
# 			Short value =  0
#
# 	Purchasing new position
# 		Pred. change in price = -0.536 %
# 		Short at  7468.6298828125
#
# 	Portfolio value =  1006466.1457324584
# 		Cash =  906466.1457324584
# 		Stock value =  0
# 		Short value =  100000
#
#  2018-10-22 00:00:00
# 	Actual price = 7437.540 (-0.416 %)
# 		Short changed by =  416.27238513380905  to  100416.27238513381
#
# 	Currently holding Short for  1  days
# 	Short can be closed for profit of  416.2723851338087
# 		Closing Short at  7437.5400390625
# 		Portfolio value =  1006882.4181175922
# 			Cash =  1006882.4181175922
# 			Stock value =  0
# 			Short value =  0
#
# 	Purchasing new position
# 		Pred. change in price = -0.312 %
# 		Short at  7437.5400390625
#
# 	Portfolio value =  1006882.4181175922
# 		Cash =  906882.4181175922
# 		Stock value =  0
# 		Short value =  100000
#
#  2018-10-23 00:00:00
# 	Actual price = 7108.400 (-4.425 %)
# 		Short changed by =  4425.389779282964  to  104425.38977928297
#
# 	Currently holding Short for  1  days
# 	Short can be closed for profit of  4425.389779282967
# 		Closing Short at  7108.39990234375
# 		Portfolio value =  1011307.8078968752
# 			Cash =  1011307.8078968752
# 			Stock value =  0
# 			Short value =  0
#
# 	Purchasing new position
# 		Pred. change in price = 3.718 %
# 		Buy Stock at  7108.39990234375
#
# 	Portfolio value =  1011307.8078968752
# 		Cash =  911307.8078968752
# 		Stock value =  100000
# 		Short value =  0
#
#  2018-10-24 00:00:00
# 	Actual price = 7318.340 (2.953 %)
# 		Stock changed by =  2953.406452794384  to  102953.40645279438
#
# 	Currently holding Stock for  1  days
# 	Stock can be sold for profit of  2953.4064527943847
# 	Selling Stock
# 		Portfolio value =  1014261.2143496696
# 			Cash =  1014261.2143496696
# 			Stock value =  0
# 			Short value =  0
#
# 	Purchasing new position
# 		Pred. change in price = -0.291 %
# 		Short at  7318.33984375
#
# 	Portfolio value =  1014261.2143496696
# 		Cash =  914261.2143496696
# 		Stock value =  0
# 		Short value =  100000
#
#  2018-10-25 00:00:00
# 	Actual price = 7167.210 (-2.065 %)
# 		Short changed by =  2065.0842409507363  to  102065.08424095073
#
# 	Currently holding Short for  1  days
# 	Short can be closed for profit of  2065.0842409507313
# 		Closing Short at  7167.2099609375
# 		Portfolio value =  1016326.2985906204
# 			Cash =  1016326.2985906204
# 			Stock value =  0
# 			Short value =  0
#
# 	Purchasing new position
# 		Pred. change in price = 1.469 %
# 		Buy Stock at  7167.2099609375
#
# 	Portfolio value =  1016326.2985906204
# 		Cash =  916326.2985906204
# 		Stock value =  100000
# 		Short value =  0
#
#  2018-10-26 00:00:00
# 	Actual price = 7050.290 (-1.631 %)
# 		Stock changed by =  -1631.3171026415193  to  98368.68289735848
#
# 	Currently holding Stock for  1  days
# 		Holding Stock
#
# 	Portfolio value =  1014694.9814879788
# 		Cash =  916326.2985906204
# 		Stock value =  98368.68289735848
# 		Short value =  0
#
#  2018-10-29 00:00:00
# 	Actual price = 7161.650 (1.580 %)
# 		Stock changed by =  1553.7407706510621  to  99922.42366800953
#
# 	Currently holding Stock for  2  days
# 		Holding Stock
#
# 	Portfolio value =  1016248.72225863
# 		Cash =  916326.2985906204
# 		Stock value =  99922.42366800953
# 		Short value =  0
#
#  2018-10-30 00:00:00
# 	Actual price = 7305.900 (2.014 %)
# 		Stock changed by =  2012.6381225914513  to  101935.06179060099
#
# 	Currently holding Stock for  3  days
# 	Stock can be sold for profit of  1935.0617906009866
# 	Selling Stock
# 		Portfolio value =  1018261.3603812214
# 			Cash =  1018261.3603812214
# 			Stock value =  0
# 			Short value =  0
#
# 	Purchasing new position
# 		Pred. change in price = -2.383 %
# 		Short at  7305.89990234375
#
# 	Portfolio value =  1018261.3603812214
# 		Cash =  918261.3603812214
# 		Stock value =  0
# 		Short value =  100000
#
#  2018-10-31 00:00:00
# 	Actual price = 7434.060 (1.754 %)
# 		Short changed by =  -1754.2008234863158  to  98245.79917651368
#
# 	Currently holding Short for  1  days
# 		Holding Short
#
# 	Portfolio value =  1016507.1595577351
# 		Cash =  918261.3603812214
# 		Stock value =  0
# 		Short value =  98245.79917651368
#
#  2018-11-01 00:00:00
# 	Actual price = 7356.990 (-1.037 %)
# 		Short changed by =  1018.5264059054193  to  99264.3255824191
#
# 	Currently holding Short for  2  days
# 		Holding Short
#
# 	Portfolio value =  1017525.6859636405
# 		Cash =  918261.3603812214
# 		Stock value =  0
# 		Short value =  99264.3255824191
#
#  2018-11-02 00:00:00
# 	Actual price = 7328.850 (-0.382 %)
# 		Short changed by =  379.68131045386485  to  99644.00689287296
#
# 	Currently holding Short for  3  days
# 		Holding Short
#
# 	Portfolio value =  1017905.3672740944
# 		Cash =  918261.3603812214
# 		Stock value =  0
# 		Short value =  99644.00689287296
#
#  2018-11-05 00:00:00
# 	Actual price = 7375.960 (0.643 %)
# 		Short changed by =  -640.5118782577334  to  99003.49501461523
#
# 	Currently holding Short for  4  days
# 		Holding Short
#
# 	Portfolio value =  1017264.8553958366
# 		Cash =  918261.3603812214
# 		Stock value =  0
# 		Short value =  99003.49501461523
#
#  2018-11-06 00:00:00
# 	Actual price = 7570.750 (2.641 %)
# 		Short changed by =  -2614.5606488310946  to  96388.93436578414
#
# 	Currently holding Short for  5  days
# 		Holding Short
#
# 	Portfolio value =  1014650.2947470056
# 		Cash =  918261.3603812214
# 		Stock value =  0
# 		Short value =  96388.93436578414
#
#  2018-11-07 00:00:00
# 	Actual price = 7530.880 (-0.527 %)
# 		Short changed by =  507.616564903353  to  96896.55093068749
#
# 	Currently holding Short for  6  days
# 		Holding Short
#
# 	Portfolio value =  1015157.9113119089
# 		Cash =  918261.3603812214
# 		Stock value =  0
# 		Short value =  96896.55093068749
#
#  2018-11-08 00:00:00
# 	Actual price = 7406.900 (-1.646 %)
# 		Short changed by =  1595.1964018564831  to  98491.74733254398
#
# 	Currently holding Short for  7  days
# 		Holding Short
#
# 	Portfolio value =  1016753.1077137653
# 		Cash =  918261.3603812214
# 		Stock value =  0
# 		Short value =  98491.74733254398
#
#  2018-11-09 00:00:00
# 	Actual price = 7200.870 (-2.782 %)
# 		Short changed by =  2739.639229654861  to  101231.38656219884
#
# 	Currently holding Short for  8  days
# 	Short can be closed for profit of  1231.386562198837
# 		Closing Short at  7200.8701171875
# 		Portfolio value =  1019492.7469434203
# 			Cash =  1019492.7469434203
# 			Stock value =  0
# 			Short value =  0
#
# 	Purchasing new position
# 		Pred. change in price = 1.581 %
# 		Buy Stock at  7200.8701171875
#
# 	Portfolio value =  1019492.7469434203
# 		Cash =  919492.7469434203
# 		Stock value =  100000
# 		Short value =  0
#
#  2018-11-12 00:00:00
# 	Actual price = 7200.870 (0.000 %)
# 		Stock changed by =  0.0  to  100000.0
#
# 	Currently holding Stock for  1  days
# 		Holding Stock
#
# 	Portfolio value =  1019492.7469434203
# 		Cash =  919492.7469434203
# 		Stock value =  100000.0
# 		Short value =  0
#
#  2018-11-13 00:00:00
# 	Actual price = 7136.390 (-0.895 %)
# 		Stock changed by =  -895.4470698595859  to  99104.55293014042
#
# 	Currently holding Stock for  2  days
# 		Holding Stock
#
# 	Portfolio value =  1018597.2998735607
# 		Cash =  919492.7469434203
# 		Stock value =  99104.55293014042
# 		Short value =  0
#
#  2018-11-14 00:00:00
# 	Actual price = 7259.030 (1.719 %)
# 		Stock changed by =  1703.1226288164232  to  100807.67555895683
#
# 	Currently holding Stock for  3  days
# 	Stock can be sold for profit of  807.6755589568347
# 	Selling Stock
# 		Portfolio value =  1020300.4225023771
# 			Cash =  1020300.4225023771
# 			Stock value =  0
# 			Short value =  0
#
# 	Purchasing new position
# 		Pred. change in price = -0.593 %
# 		Short at  7259.02978515625
#
# 	Portfolio value =  1020300.4225023771
# 		Cash =  920300.4225023771
# 		Stock value =  0
# 		Short value =  100000
#
#  2018-11-15 00:00:00
# 	Actual price = 7247.870 (-0.154 %)
# 		Short changed by =  153.73497972924747  to  100153.73497972924
#
# 	Currently holding Short for  1  days
# 		Holding Short
#
# 	Portfolio value =  1020454.1574821064
# 		Cash =  920300.4225023771
# 		Stock value =  0
# 		Short value =  100153.73497972924
#
#  2018-11-16 00:00:00
# 	Actual price = 7028.480 (-3.027 %)
# 		Short changed by =  3031.613598868224  to  103185.34857859746
#
# 	Currently holding Short for  2  days
# 	Short can be closed for profit of  3185.3485785974626
# 		Closing Short at  7028.47998046875
# 		Portfolio value =  1023485.7710809745
# 			Cash =  1023485.7710809745
# 			Stock value =  0
# 			Short value =  0
#
# 	Purchasing new position
# 		Pred. change in price = 2.222 %
# 		Buy Stock at  7028.47998046875
#
# 	Portfolio value =  1023485.7710809745
# 		Cash =  923485.7710809745
# 		Stock value =  100000
# 		Short value =  0
#
#  2018-11-19 00:00:00
# 	Actual price = 6908.820 (-1.703 %)
# 		Stock changed by =  -1702.504048990967  to  98297.49595100903
#
# 	Currently holding Stock for  1  days
# 		Holding Stock
#
# 	Portfolio value =  1021783.2670319835
# 		Cash =  923485.7710809745
# 		Stock value =  98297.49595100903
# 		Short value =  0
#
#  2018-11-20 00:00:00
# 	Actual price = 6972.250 (0.918 %)
# 		Stock changed by =  902.473592547953  to  99199.96954355697
#
# 	Currently holding Stock for  2  days
# 		Holding Stock
#
# 	Portfolio value =  1022685.7406245314
# 		Cash =  923485.7710809745
# 		Stock value =  99199.96954355697
# 		Short value =  0
#
#  2018-11-21 00:00:00
# 	Actual price = 6938.980 (-0.477 %)
# 		Stock changed by =  -473.3600952653083  to  98726.60944829167
#
# 	Currently holding Stock for  3  days
# 		Holding Stock
#
# 	Portfolio value =  1022212.3805292662
# 		Cash =  923485.7710809745
# 		Stock value =  98726.60944829167
# 		Short value =  0
#
#  2018-11-23 00:00:00
# 	Actual price = 7081.850 (2.059 %)
# 		Stock changed by =  2032.7313670170197  to  100759.3408153087
#
# 	Currently holding Stock for  4  days
# 	Stock can be sold for profit of  759.340815308693
# 	Selling Stock
# 		Portfolio value =  1024245.1118962832
# 			Cash =  1024245.1118962832
# 			Stock value =  0
# 			Short value =  0
#
# 	Purchasing new position
# 		Pred. change in price = -0.967 %
# 		Short at  7081.85009765625
#
# 	Portfolio value =  1024245.1118962832
# 		Cash =  924245.1118962832
# 		Stock value =  0
# 		Short value =  100000
#
#  2018-11-26 00:00:00
# 	Actual price = 7082.700 (0.012 %)
# 		Short changed by =  -12.003892267238772  to  99987.99610773276
#
# 	Currently holding Short for  1  days
# 		Holding Short
#
# 	Portfolio value =  1024233.108004016
# 		Cash =  924245.1118962832
# 		Stock value =  0
# 		Short value =  99987.99610773276
#
#  2018-11-27 00:00:00
# 	Actual price = 7291.590 (2.949 %)
# 		Short changed by =  -2948.939921068178  to  97039.05618666459
#
# 	Currently holding Short for  2  days
# 		Holding Short
#
# 	Portfolio value =  1021284.1680829478
# 		Cash =  924245.1118962832
# 		Stock value =  0
# 		Short value =  97039.05618666459
#
#  2018-11-28 00:00:00
# 	Actual price = 7273.080 (-0.254 %)
# 		Short changed by =  246.33450659953925  to  97285.39069326413
#
# 	Currently holding Short for  3  days
# 		Holding Short
#
# 	Portfolio value =  1021530.5025895473
# 		Cash =  924245.1118962832
# 		Stock value =  0
# 		Short value =  97285.39069326413
#
#  2018-11-29 00:00:00
# 	Actual price = 7330.540 (0.790 %)
# 		Short changed by =  -768.5897431319756  to  96516.80095013215
#
# 	Currently holding Short for  4  days
# 		Holding Short
#
# 	Portfolio value =  1020761.9128464154
# 		Cash =  924245.1118962832
# 		Stock value =  0
# 		Short value =  96516.80095013215
#
#  2018-11-30 00:00:00
# 	Actual price = 7441.510 (1.514 %)
# 		Short changed by =  -1461.0714835537765  to  95055.72946657837
#
# 	Currently holding Short for  5  days
# 		Holding Short
#
# 	Portfolio value =  1019300.8413628616
# 		Cash =  924245.1118962832
# 		Stock value =  0
# 		Short value =  95055.72946657837
#
#  2018-12-03 00:00:00
# 	Actual price = 7158.430 (-3.804 %)
# 		Short changed by =  3615.9781760949527  to  98671.70764267333
#
# 	Currently holding Short for  6  days
# 		Holding Short
#
# 	Portfolio value =  1022916.8195389565
# 		Cash =  924245.1118962832
# 		Stock value =  0
# 		Short value =  98671.70764267333
#
#  2018-12-04 00:00:00
# 	Actual price = 7188.260 (0.417 %)
# 		Short changed by =  -411.17067511832374  to  98260.536967555
#
# 	Currently holding Short for  7  days
# 		Holding Short
#
# 	Portfolio value =  1022505.6488638383
# 		Cash =  924245.1118962832
# 		Stock value =  0
# 		Short value =  98260.536967555
#
#  2018-12-06 00:00:00
# 	Actual price = 6969.250 (-3.047 %)
# 		Short changed by =  2993.7728842746906  to  101254.30985182969
#
# 	Currently holding Short for  8  days
# 	Short can be closed for profit of  1254.3098518296902
# 		Closing Short at  6969.25
# 		Portfolio value =  1025499.4217481129
# 			Cash =  1025499.4217481129
# 			Stock value =  0
# 			Short value =  0
#
# 	Purchasing new position
# 		Pred. change in price = 2.078 %
# 		Buy Stock at  6969.25
#
# 	Portfolio value =  1025499.4217481129
# 		Cash =  925499.4217481129
# 		Stock value =  100000
# 		Short value =  0
#
#  2018-12-07 00:00:00
# 	Actual price = 7020.520 (0.736 %)
# 		Stock changed by =  735.6605019370808  to  100735.66050193708
#
# 	Currently holding Stock for  1  days
# 	Stock can be sold for profit of  735.6605019370763
# 	Selling Stock
# 		Portfolio value =  1026235.0822500499
# 			Cash =  1026235.0822500499
# 			Stock value =  0
# 			Short value =  0
#
# 	Purchasing new position
# 		Pred. change in price = 0.737 %
# 		Buy Stock at  7020.52001953125
#
# 	Portfolio value =  1026235.0822500499
# 		Cash =  926235.0822500499
# 		Stock value =  100000
# 		Short value =  0
#
#  2018-12-10 00:00:00
# 	Actual price = 7031.830 (0.161 %)
# 		Stock changed by =  161.1000119974753  to  100161.10001199748
#
# 	Currently holding Stock for  1  days
# 		Holding Stock
#
# 	Portfolio value =  1026396.1822620474
# 		Cash =  926235.0822500499
# 		Stock value =  100161.10001199748
# 		Short value =  0
#
#  2018-12-11 00:00:00
# 	Actual price = 7098.310 (0.945 %)
# 		Stock changed by =  946.9381225863774  to  101108.03813458385
#
# 	Currently holding Stock for  2  days
# 	Stock can be sold for profit of  1108.0381345838541
# 	Selling Stock
# 		Portfolio value =  1027343.1203846338
# 			Cash =  1027343.1203846338
# 			Stock value =  0
# 			Short value =  0
#
# 	Purchasing new position
# 		Pred. change in price = -0.830 %
# 		Short at  7098.31005859375
#
# 	Portfolio value =  1027343.1203846338
# 		Cash =  927343.1203846338
# 		Stock value =  0
# 		Short value =  100000
#
#  2018-12-12 00:00:00
# 	Actual price = 7070.330 (-0.394 %)
# 		Short changed by =  394.17805418171787  to  100394.17805418171
#
# 	Currently holding Short for  1  days
# 	Short can be closed for profit of  394.1780541817134
# 		Closing Short at  7070.330078125
# 		Portfolio value =  1027737.2984388155
# 			Cash =  1027737.2984388155
# 			Stock value =  0
# 			Short value =  0
#
# 	Purchasing new position
# 		Pred. change in price = -0.282 %
# 		Short at  7070.330078125
#
# 	Portfolio value =  1027737.2984388155
# 		Cash =  927737.2984388155
# 		Stock value =  0
# 		Short value =  100000
#
#  2018-12-13 00:00:00
# 	Actual price = 6910.660 (-2.258 %)
# 		Short changed by =  2258.309302545933  to  102258.30930254594
#
# 	Currently holding Short for  1  days
# 	Short can be closed for profit of  2258.3093025459384
# 		Closing Short at  6910.66015625
# 		Portfolio value =  1029995.6077413615
# 			Cash =  1029995.6077413615
# 			Stock value =  0
# 			Short value =  0
#
# 	Purchasing new position
# 		Pred. change in price = 2.019 %
# 		Buy Stock at  6910.66015625
#
# 	Portfolio value =  1029995.6077413615
# 		Cash =  929995.6077413615
# 		Stock value =  100000
# 		Short value =  0
#
#  2018-12-14 00:00:00
# 	Actual price = 6753.730 (-2.271 %)
# 		Stock changed by =  -2270.842035826669  to  97729.15796417333
#
# 	Currently holding Stock for  1  days
# 		Holding Stock
#
# 	Portfolio value =  1027724.7657055348
# 		Cash =  929995.6077413615
# 		Stock value =  97729.15796417333
# 		Short value =  0
#
#  2018-12-17 00:00:00
# 	Actual price = 6783.910 (0.447 %)
# 		Stock changed by =  436.71914258372334  to  98165.87710675705
#
# 	Currently holding Stock for  2  days
# 		Holding Stock
#
# 	Portfolio value =  1028161.4848481185
# 		Cash =  929995.6077413615
# 		Stock value =  98165.87710675705
# 		Short value =  0
#
#  2018-12-18 00:00:00
# 	Actual price = 6636.830 (-2.168 %)
# 		Stock changed by =  -2128.3072065406195  to  96037.56990021643
#
# 	Currently holding Stock for  3  days
# 		Holding Stock
#
# 	Portfolio value =  1026033.1776415779
# 		Cash =  929995.6077413615
# 		Stock value =  96037.56990021643
# 		Short value =  0
#
#  2018-12-19 00:00:00
# 	Actual price = 6528.410 (-1.634 %)
# 		Stock changed by =  -1568.8793751049245  to  94468.69052511151
#
# 	Currently holding Stock for  4  days
# 		Holding Stock
#
# 	Portfolio value =  1024464.298266473
# 		Cash =  929995.6077413615
# 		Stock value =  94468.69052511151
# 		Short value =  0
#
#  2018-12-20 00:00:00
# 	Actual price = 6332.990 (-2.993 %)
# 		Stock changed by =  -2827.8039645497875  to  91640.88656056172
#
# 	Currently holding Stock for  5  days
# 		Holding Stock
#
# 	Portfolio value =  1021636.4943019232
# 		Cash =  929995.6077413615
# 		Stock value =  91640.88656056172
# 		Short value =  0
#
#  2018-12-21 00:00:00
# 	Actual price = 6192.920 (-2.212 %)
# 		Stock changed by =  -2026.8731110054719  to  89614.01344955625
#
# 	Currently holding Stock for  6  days
# 		Holding Stock
#
# 	Portfolio value =  1019609.6211909177
# 		Cash =  929995.6077413615
# 		Stock value =  89614.01344955625
# 		Short value =  0
#
#  2018-12-24 00:00:00
# 	Actual price = 6554.360 (5.836 %)
# 		Stock changed by =  5230.179653377453  to  94844.1931029337
#
# 	Currently holding Stock for  7  days
# 		Holding Stock
#
# 	Portfolio value =  1024839.8008442952
# 		Cash =  929995.6077413615
# 		Stock value =  94844.1931029337
# 		Short value =  0
#
#  2018-12-26 00:00:00
# 	Actual price = 6579.490 (0.383 %)
# 		Stock changed by =  363.64646105512935  to  95207.83956398883
#
# 	Currently holding Stock for  8  days
# 		Holding Stock
#
# 	Portfolio value =  1025203.4473053503
# 		Cash =  929995.6077413615
# 		Stock value =  95207.83956398883
# 		Short value =  0
#
#  2018-12-27 00:00:00
# 	Actual price = 6584.520 (0.076 %)
# 		Stock changed by =  72.78299095204477  to  95280.62255494088
#
# 	Currently holding Stock for  9  days
# 		Holding Stock
#
# 	Portfolio value =  1025276.2302963024
# 		Cash =  929995.6077413615
# 		Stock value =  95280.62255494088
# 		Short value =  0
#
#  2018-12-28 00:00:00
# 	Actual price = 6635.280 (0.771 %)
# 		Stock changed by =  734.5139896525353  to  96015.13654459342
#
# 	Currently holding Stock for  10  days
# 		Limit Reached
# 	Selling Stock
# 		Portfolio value =  1026010.7442859549
# 			Cash =  1026010.7442859549
# 			Stock value =  0
# 			Short value =  0
#
# 	Purchasing new position
# 		Pred. change in price = -2.106 %
# 		Short at  6635.27978515625
#
# 	Portfolio value =  1026010.7442859549
# 		Cash =  926010.7442859549
# 		Stock value =  0
# 		Short value =  100000
#
#  2018-12-31 00:00:00
# 	Actual price = 6665.940 (0.462 %)
# 		Short changed by =  -462.077821022554  to  99537.92217897745
#
# 	Currently holding Short for  1  days
# 		Holding Short
#
# 	Portfolio value =  1025548.6664649323
# 		Cash =  926010.7442859549
# 		Stock value =  0
# 		Short value =  99537.92217897745
#
#  2019-01-02 00:00:00
# 	Actual price = 6463.500 (-3.037 %)
# 		Short changed by =  3022.8971924042144  to  102560.81937138166
#
# 	Currently holding Short for  2  days
# 	Short can be closed for profit of  2560.819371381658
# 		Closing Short at  6463.5
# 		Portfolio value =  1028571.5636573365
# 			Cash =  1028571.5636573365
# 			Stock value =  0
# 			Short value =  0
#
# 	Purchasing new position
# 		Pred. change in price = 0.981 %
# 		Buy Stock at  6463.5
#
# 	Portfolio value =  1028571.5636573365
# 		Cash =  928571.5636573365
# 		Stock value =  100000
# 		Short value =  0
#
#  2019-01-03 00:00:00
# 	Actual price = 6738.860 (4.260 %)
# 		Stock changed by =  4260.228410013924  to  104260.22841001392
#
# 	Currently holding Stock for  1  days
# 	Stock can be sold for profit of  4260.228410013922
# 	Selling Stock
# 		Portfolio value =  1032831.7920673505
# 			Cash =  1032831.7920673505
# 			Stock value =  0
# 			Short value =  0
#
# 	Purchasing new position
# 		Pred. change in price = -3.618 %
# 		Short at  6738.85986328125
#
# 	Portfolio value =  1032831.7920673505
# 		Cash =  932831.7920673505
# 		Stock value =  0
# 		Short value =  100000
#
#  2019-01-04 00:00:00
# 	Actual price = 6823.470 (1.256 %)
# 		Short changed by =  -1255.5588523739084  to  98744.44114762609
#
# 	Currently holding Short for  1  days
# 		Holding Short
#
# 	Portfolio value =  1031576.2332149765
# 		Cash =  932831.7920673505
# 		Stock value =  0
# 		Short value =  98744.44114762609
#
#  2019-01-07 00:00:00
# 	Actual price = 6897.000 (1.078 %)
# 		Short changed by =  -1064.071112549757  to  97680.37003507632
#
# 	Currently holding Short for  2  days
# 		Holding Short
#
# 	Portfolio value =  1030512.1621024268
# 		Cash =  932831.7920673505
# 		Stock value =  0
# 		Short value =  97680.37003507632
#
#  2019-01-08 00:00:00
# 	Actual price = 6957.080 (0.871 %)
# 		Short changed by =  -850.8981097558786  to  96829.47192532045
#
# 	Currently holding Short for  3  days
# 		Holding Short
#
# 	Portfolio value =  1029661.2639926709
# 		Cash =  932831.7920673505
# 		Stock value =  0
# 		Short value =  96829.47192532045
#
#  2019-01-09 00:00:00
# 	Actual price = 6986.070 (0.417 %)
# 		Short changed by =  -403.4827505195921  to  96425.98917480087
#
# 	Currently holding Short for  4  days
# 		Holding Short
#
# 	Portfolio value =  1029257.7812421513
# 		Cash =  932831.7920673505
# 		Stock value =  0
# 		Short value =  96425.98917480087
#
#  2019-01-10 00:00:00
# 	Actual price = 6971.480 (-0.209 %)
# 		Short changed by =  201.37790644783064  to  96627.3670812487
#
# 	Currently holding Short for  5  days
# 		Holding Short
#
# 	Portfolio value =  1029459.1591485991
# 		Cash =  932831.7920673505
# 		Stock value =  0
# 		Short value =  96627.3670812487
#
#  2019-01-11 00:00:00
# 	Actual price = 6905.920 (-0.940 %)
# 		Short changed by =  908.6873756152575  to  97536.05445686396
#
# 	Currently holding Short for  6  days
# 		Holding Short
#
# 	Portfolio value =  1030367.8465242144
# 		Cash =  932831.7920673505
# 		Stock value =  0
# 		Short value =  97536.05445686396
#
#  2019-01-14 00:00:00
# 	Actual price = 7023.830 (1.707 %)
# 		Short changed by =  -1665.3091190050875  to  95870.74533785887
#
# 	Currently holding Short for  7  days
# 		Holding Short
#
# 	Portfolio value =  1028702.5374052094
# 		Cash =  932831.7920673505
# 		Stock value =  0
# 		Short value =  95870.74533785887
#
#  2019-01-15 00:00:00
# 	Actual price = 7034.690 (0.155 %)
# 		Short changed by =  -148.23012166584397  to  95722.51521619303
#
# 	Currently holding Short for  8  days
# 		Holding Short
#
# 	Portfolio value =  1028554.3072835435
# 		Cash =  932831.7920673505
# 		Stock value =  0
# 		Short value =  95722.51521619303
#
#  2019-01-16 00:00:00
# 	Actual price = 7084.460 (0.707 %)
# 		Short changed by =  -677.2311916476515  to  95045.28402454538
#
# 	Currently holding Short for  9  days
# 		Holding Short
#
# 	Portfolio value =  1027877.0760918958
# 		Cash =  932831.7920673505
# 		Stock value =  0
# 		Short value =  95045.28402454538
#
#  2019-01-17 00:00:00
# 	Actual price = 7157.230 (1.027 %)
# 		Short changed by =  -976.2843198995375  to  94068.99970464584
#
# 	Currently holding Short for  10  days
# 		Limit Reached
# 		Closing Short at  7157.22998046875
# 		Portfolio value =  1026900.7917719963
# 			Cash =  1026900.7917719963
# 			Stock value =  0
# 			Short value =  0
#
# 	Purchasing new position
# 		Pred. change in price = -3.149 %
# 		Short at  7157.22998046875
#
# 	Portfolio value =  1026900.7917719963
# 		Cash =  926900.7917719963
# 		Stock value =  0
# 		Short value =  100000
#
#  2019-01-18 00:00:00
# 	Actual price = 7020.360 (-1.912 %)
# 		Short changed by =  1912.333648087356  to  101912.33364808735
#
# 	Currently holding Short for  1  days
# 	Short can be closed for profit of  1912.333648087355
# 		Closing Short at  7020.35986328125
# 		Portfolio value =  1028813.1254200836
# 			Cash =  1028813.1254200836
# 			Stock value =  0
# 			Short value =  0
#
# 	Purchasing new position
# 		Pred. change in price = -0.680 %
# 		Short at  7020.35986328125
#
# 	Portfolio value =  1028813.1254200836
# 		Cash =  928813.1254200836
# 		Stock value =  0
# 		Short value =  100000
#
#  2019-01-22 00:00:00
# 	Actual price = 7025.770 (0.077 %)
# 		Short changed by =  -77.06380236000244  to  99922.93619764
#
# 	Currently holding Short for  1  days
# 		Holding Short
#
# 	Portfolio value =  1028736.0616177237
# 		Cash =  928813.1254200836
# 		Stock value =  0
# 		Short value =  99922.93619764
#
#  2019-01-23 00:00:00
# 	Actual price = 7073.460 (0.679 %)
# 		Short changed by =  -678.2628749814734  to  99244.67332265852
#
# 	Currently holding Short for  2  days
# 		Holding Short
#
# 	Portfolio value =  1028057.7987427422
# 		Cash =  928813.1254200836
# 		Stock value =  0
# 		Short value =  99244.67332265852
#
#  2019-01-24 00:00:00
# 	Actual price = 7164.860 (1.292 %)
# 		Short changed by =  -1282.3927045493756  to  97962.28061810914
#
# 	Currently holding Short for  3  days
# 		Holding Short
#
# 	Portfolio value =  1026775.4060381928
# 		Cash =  928813.1254200836
# 		Stock value =  0
# 		Short value =  97962.28061810914
#
#  2019-01-25 00:00:00
# 	Actual price = 7085.680 (-1.105 %)
# 		Short changed by =  1082.592390380254  to  99044.8730084894
#
# 	Currently holding Short for  4  days
# 		Holding Short
#
# 	Portfolio value =  1027857.998428573
# 		Cash =  928813.1254200836
# 		Stock value =  0
# 		Short value =  99044.8730084894
#
#  2019-01-28 00:00:00
# 	Actual price = 7028.290 (-0.810 %)
# 		Short changed by =  802.2093380219088  to  99847.08234651132
#
# 	Currently holding Short for  5  days
# 		Holding Short
#
# 	Portfolio value =  1028660.207766595
# 		Cash =  928813.1254200836
# 		Stock value =  0
# 		Short value =  99847.08234651132
#
#  2019-01-29 00:00:00
# 	Actual price = 7183.080 (2.202 %)
# 		Short changed by =  -2199.017640250191  to  97648.06470626112
#
# 	Currently holding Short for  6  days
# 		Holding Short
#
# 	Portfolio value =  1026461.1901263448
# 		Cash =  928813.1254200836
# 		Stock value =  0
# 		Short value =  97648.06470626112
#
#  2019-01-30 00:00:00
# 	Actual price = 7281.740 (1.374 %)
# 		Short changed by =  -1341.2036642565997  to  96306.86104200453
#
# 	Currently holding Short for  7  days
# 		Holding Short
#
# 	Portfolio value =  1025119.9864620882
# 		Cash =  928813.1254200836
# 		Stock value =  0
# 		Short value =  96306.86104200453
#
#  2019-01-31 00:00:00
# 	Actual price = 7263.870 (-0.245 %)
# 		Short changed by =  236.3466475577477  to  96543.20768956227
#
# 	Currently holding Short for  8  days
# 		Holding Short
#
# 	Portfolio value =  1025356.3331096459
# 		Cash =  928813.1254200836
# 		Stock value =  0
# 		Short value =  96543.20768956227
#
#  2019-02-01 00:00:00
# 	Actual price = 7347.540 (1.152 %)
# 		Short changed by =  -1112.0466796115024  to  95431.16100995077
#
# 	Currently holding Short for  9  days
# 		Holding Short
#
# 	Portfolio value =  1024244.2864300344
# 		Cash =  928813.1254200836
# 		Stock value =  0
# 		Short value =  95431.16100995077
#
#  2019-02-04 00:00:00
# 	Actual price = 7402.080 (0.742 %)
# 		Short changed by =  -708.3757586337078  to  94722.78525131707
#
# 	Currently holding Short for  10  days
# 		Limit Reached
# 		Closing Short at  7402.080078125
# 		Portfolio value =  1023535.9106714007
# 			Cash =  1023535.9106714007
# 			Stock value =  0
# 			Short value =  0
#
# 	Purchasing new position
# 		Pred. change in price = -3.683 %
# 		Short at  7402.080078125
#
# 	Portfolio value =  1023535.9106714007
# 		Cash =  923535.9106714007
# 		Stock value =  0
# 		Short value =  100000
#
#  2019-02-05 00:00:00
# 	Actual price = 7375.280 (-0.362 %)
# 		Short changed by =  362.0643479385149  to  100362.06434793852
#
# 	Currently holding Short for  1  days
# 	Short can be closed for profit of  362.06434793851804
# 		Closing Short at  7375.27978515625
# 		Portfolio value =  1023897.9750193392
# 			Cash =  1023897.9750193392
# 			Stock value =  0
# 			Short value =  0
#
# 	Purchasing new position
# 		Pred. change in price = -2.693 %
# 		Short at  7375.27978515625
#
# 	Portfolio value =  1023897.9750193392
# 		Cash =  923897.9750193392
# 		Stock value =  0
# 		Short value =  100000
#
#  2019-02-06 00:00:00
# 	Actual price = 7288.350 (-1.179 %)
# 		Short changed by =  1178.6629122187037  to  101178.6629122187
#
# 	Currently holding Short for  1  days
# 	Short can be closed for profit of  1178.6629122187005
# 		Closing Short at  7288.35009765625
# 		Portfolio value =  1025076.637931558
# 			Cash =  1025076.637931558
# 			Stock value =  0
# 			Short value =  0
#
# 	Purchasing new position
# 		Pred. change in price = -1.037 %
# 		Short at  7288.35009765625
#
# 	Portfolio value =  1025076.637931558
# 		Cash =  925076.637931558
# 		Stock value =  0
# 		Short value =  100000
#
#  2019-02-07 00:00:00
# 	Actual price = 7298.200 (0.135 %)
# 		Short changed by =  -135.1485250333617  to  99864.85147496664
#
# 	Currently holding Short for  1  days
# 		Holding Short
#
# 	Portfolio value =  1024941.4894065246
# 		Cash =  925076.637931558
# 		Stock value =  0
# 		Short value =  99864.85147496664
#
#  2019-02-08 00:00:00
# ...
#
# 	Currently holding Short for  7  days
# 		Holding Short
#
# 	Portfolio value =  1030418.6385289482
# 		Cash =  932760.6585998202
# 		Stock value =  0
# 		Short value =  97657.9799291279
#
#  2019-10-18 00:00:00
# 	Actual price = 8162.990 (0.908 %)
# 		Short changed by =  -886.7003148487947  to  96771.2796142791
#
# 	Currently holding Short for  8  days
# 		Holding Short
#
# 	Portfolio value =  1029531.9382140993
# 		Cash =  932760.6585998202
# 		Stock value =  0
# 		Short value =  96771.2796142791
#
#  2019-10-21 00:00:00
# 	Actual price = 8104.300 (-0.719 %)
# 		Short changed by =  695.7680725935727  to  97467.04768687268
#
# 	Currently holding Short for  9  days
# 		Holding Short
#
# 	Portfolio value =  1030227.7062866929
# 		Cash =  932760.6585998202
# 		Stock value =  0
# 		Short value =  97467.04768687268
#
#  2019-10-22 00:00:00
# 	Actual price = 8119.790 (0.191 %)
# 		Short changed by =  -186.2946150678808  to  97280.75307180481
#
# 	Currently holding Short for  10  days
# 		Limit Reached
# 		Closing Short at  8119.7900390625
# 		Portfolio value =  1030041.411671625
# 			Cash =  1030041.411671625
# 			Stock value =  0
# 			Short value =  0
#
# 	Purchasing new position
# 		Pred. change in price = -1.586 %
# 		Short at  8119.7900390625
#
# 	Portfolio value =  1030041.411671625
# 		Cash =  930041.411671625
# 		Stock value =  0
# 		Short value =  100000
#
#  2019-10-23 00:00:00
# 	Actual price = 8185.800 (0.813 %)
# 		Short changed by =  -812.949168727784  to  99187.05083127222
#
# 	Currently holding Short for  1  days
# 		Holding Short
#
# 	Portfolio value =  1029228.4625028973
# 		Cash =  930041.411671625
# 		Stock value =  0
# 		Short value =  99187.05083127222
#
#  2019-10-24 00:00:00
# 	Actual price = 8243.120 (0.700 %)
# 		Short changed by =  -694.5482280602824  to  98492.50260321193
#
# 	Currently holding Short for  2  days
# 		Holding Short
#
# 	Portfolio value =  1028533.9142748369
# 		Cash =  930041.411671625
# 		Stock value =  0
# 		Short value =  98492.50260321193
#
#  2019-10-25 00:00:00
# 	Actual price = 8325.990 (1.005 %)
# 		Short changed by =  -990.1693917816124  to  97502.33321143032
#
# 	Currently holding Short for  3  days
# 		Holding Short
#
# 	Portfolio value =  1027543.7448830553
# 		Cash =  930041.411671625
# 		Stock value =  0
# 		Short value =  97502.33321143032
#
#  2019-10-28 00:00:00
# 	Actual price = 8276.850 (-0.590 %)
# 		Short changed by =  575.4661557476123  to  98077.79936717793
#
# 	Currently holding Short for  4  days
# 		Holding Short
#
# 	Portfolio value =  1028119.2110388029
# 		Cash =  930041.411671625
# 		Stock value =  0
# 		Short value =  98077.79936717793
#
#  2019-10-29 00:00:00
# 	Actual price = 8303.980 (0.328 %)
# 		Short changed by =  -321.49128086444716  to  97756.30808631348
#
# 	Currently holding Short for  5  days
# 		Holding Short
#
# 	Portfolio value =  1027797.7197579385
# 		Cash =  930041.411671625
# 		Stock value =  0
# 		Short value =  97756.30808631348
#
#  2019-10-30 00:00:00
# 	Actual price = 8292.360 (-0.140 %)
# 		Short changed by =  136.7946083273134  to  97893.1026946408
#
# 	Currently holding Short for  6  days
# 		Holding Short
#
# 	Portfolio value =  1027934.5143662657
# 		Cash =  930041.411671625
# 		Stock value =  0
# 		Short value =  97893.1026946408
#
#  2019-10-31 00:00:00
# 	Actual price = 8386.400 (1.134 %)
# 		Short changed by =  -1110.1629465027668  to  96782.93974813803
#
# 	Currently holding Short for  7  days
# 		Holding Short
#
# 	Portfolio value =  1026824.351419763
# 		Cash =  930041.411671625
# 		Stock value =  0
# 		Short value =  96782.93974813803
#
#  2019-11-01 00:00:00
# 	Actual price = 8433.200 (0.558 %)
# 		Short changed by =  -540.0913939618596  to  96242.84835417617
#
# 	Currently holding Short for  8  days
# 		Holding Short
#
# 	Portfolio value =  1026284.2600258011
# 		Cash =  930041.411671625
# 		Stock value =  0
# 		Short value =  96242.84835417617
#
#  2019-11-04 00:00:00
# 	Actual price = 8434.680 (0.018 %)
# 		Short changed by =  -16.884520578783018  to  96225.96383359739
#
# 	Currently holding Short for  9  days
# 		Holding Short
#
# 	Portfolio value =  1026267.3755052224
# 		Cash =  930041.411671625
# 		Stock value =  0
# 		Short value =  96225.96383359739
#
#  2019-11-05 00:00:00
# 	Actual price = 8410.630 (-0.285 %)
# 		Short changed by =  274.3691191372768  to  96500.33295273467
#
# 	Currently holding Short for  10  days
# 		Limit Reached
# 		Closing Short at  8410.6298828125
# 		Portfolio value =  1026541.7446243596
# 			Cash =  1026541.7446243596
# 			Stock value =  0
# 			Short value =  0
#
# 	Purchasing new position
# 		Pred. change in price = -2.632 %
# 		Short at  8410.6298828125
#
# 	Portfolio value =  1026541.7446243596
# 		Cash =  926541.7446243596
# 		Stock value =  0
# 		Short value =  100000
#
#  2019-11-06 00:00:00
# 	Actual price = 8434.520 (0.284 %)
# 		Short changed by =  -284.04113330821474  to  99715.95886669178
#
# 	Currently holding Short for  1  days
# 		Holding Short
#
# 	Portfolio value =  1026257.7034910514
# 		Cash =  926541.7446243596
# 		Stock value =  0
# 		Short value =  99715.95886669178
#
#  2019-11-07 00:00:00
# 	Actual price = 8475.310 (0.484 %)
# 		Short changed by =  -482.2346835830028  to  99233.72418310879
#
# 	Currently holding Short for  2  days
# 		Holding Short
#
# 	Portfolio value =  1025775.4688074684
# 		Cash =  926541.7446243596
# 		Stock value =  0
# 		Short value =  99233.72418310879
#
#  2019-11-08 00:00:00
# 	Actual price = 8464.280 (-0.130 %)
# 		Short changed by =  129.13725391944809  to  99362.86143702823
#
# 	Currently holding Short for  3  days
# 		Holding Short
#
# 	Portfolio value =  1025904.6060613879
# 		Cash =  926541.7446243596
# 		Stock value =  0
# 		Short value =  99362.86143702823
#
#  2019-11-11 00:00:00
# 	Actual price = 8486.090 (0.258 %)
# 		Short changed by =  -256.02428593517953  to  99106.83715109304
#
# 	Currently holding Short for  4  days
# 		Holding Short
#
# 	Portfolio value =  1025648.5817754527
# 		Cash =  926541.7446243596
# 		Stock value =  0
# 		Short value =  99106.83715109304
#
#  2019-11-12 00:00:00
# 	Actual price = 8482.100 (-0.047 %)
# 		Short changed by =  46.60090992190876  to  99153.43806101495
#
# 	Currently holding Short for  5  days
# 		Holding Short
#
# 	Portfolio value =  1025695.1826853746
# 		Cash =  926541.7446243596
# 		Stock value =  0
# 		Short value =  99153.43806101495
#
#  2019-11-13 00:00:00
# 	Actual price = 8479.020 (-0.036 %)
# 		Short changed by =  36.00527577543715  to  99189.44333679038
#
# 	Currently holding Short for  6  days
# 		Holding Short
#
# 	Portfolio value =  1025731.1879611501
# 		Cash =  926541.7446243596
# 		Stock value =  0
# 		Short value =  99189.44333679038
#
#  2019-11-14 00:00:00
# 	Actual price = 8540.830 (0.729 %)
# 		Short changed by =  -723.0734301622722  to  98466.36990662811
#
# 	Currently holding Short for  7  days
# 		Holding Short
#
# 	Portfolio value =  1025008.1145309878
# 		Cash =  926541.7446243596
# 		Stock value =  0
# 		Short value =  98466.36990662811
#
#  2019-11-15 00:00:00
# 	Actual price = 8549.940 (0.107 %)
# 		Short changed by =  -105.03232574900822  to  98361.3375808791
#
# 	Currently holding Short for  8  days
# 		Holding Short
#
# 	Portfolio value =  1024903.0822052388
# 		Cash =  926541.7446243596
# 		Stock value =  0
# 		Short value =  98361.3375808791
#
#  2019-11-18 00:00:00
# 	Actual price = 8570.660 (0.242 %)
# 		Short changed by =  -238.36657527122208  to  98122.97100560788
#
# 	Currently holding Short for  9  days
# 		Holding Short
#
# 	Portfolio value =  1024664.7156299675
# 		Cash =  926541.7446243596
# 		Stock value =  0
# 		Short value =  98122.97100560788
#
#  2019-11-19 00:00:00
# 	Actual price = 8526.730 (-0.513 %)
# 		Short changed by =  502.93809044622446  to  98625.9090960541
#
# 	Currently holding Short for  10  days
# 		Limit Reached
# 		Closing Short at  8526.73046875
# 		Portfolio value =  1025167.6537204138
# 			Cash =  1025167.6537204138
# 			Stock value =  0
# 			Short value =  0
#
# 	Purchasing new position
# 		Pred. change in price = -2.273 %
# 		Short at  8526.73046875
#
# 	Portfolio value =  1025167.6537204138
# 		Cash =  925167.6537204138
# 		Stock value =  0
# 		Short value =  100000
#
#  2019-11-20 00:00:00
# 	Actual price = 8506.210 (-0.241 %)
# 		Short changed by =  240.66091789469056  to  100240.6609178947
#
# 	Currently holding Short for  1  days
# 		Holding Short
#
# 	Portfolio value =  1025408.3146383085
# 		Cash =  925167.6537204138
# 		Stock value =  0
# 		Short value =  100240.6609178947
#
#  2019-11-21 00:00:00
# 	Actual price = 8519.880 (0.161 %)
# 		Short changed by =  -161.09195631646065  to  100079.56896157823
#
# 	Currently holding Short for  2  days
# 		Holding Short
#
# 	Portfolio value =  1025247.222681992
# 		Cash =  925167.6537204138
# 		Stock value =  0
# 		Short value =  100079.56896157823
#
#  2019-11-22 00:00:00
# 	Actual price = 8632.490 (1.322 %)
# 		Short changed by =  -1322.7880674376888  to  98756.78089414054
#
# 	Currently holding Short for  3  days
# 		Holding Short
#
# 	Portfolio value =  1023924.4346145543
# 		Cash =  925167.6537204138
# 		Stock value =  0
# 		Short value =  98756.78089414054
#
#  2019-11-25 00:00:00
# 	Actual price = 8647.930 (0.179 %)
# 		Short changed by =  -176.62929791908093  to  98580.15159622146
#
# 	Currently holding Short for  4  days
# 		Holding Short
#
# 	Portfolio value =  1023747.8053166353
# 		Cash =  925167.6537204138
# 		Stock value =  0
# 		Short value =  98580.15159622146
#
#  2019-11-26 00:00:00
# 	Actual price = 8705.180 (0.662 %)
# 		Short changed by =  -652.60864540114  to  97927.54295082032
#
# 	Currently holding Short for  5  days
# 		Holding Short
#
# 	Portfolio value =  1023095.1966712341
# 		Cash =  925167.6537204138
# 		Stock value =  0
# 		Short value =  97927.54295082032
#
#  2019-11-27 00:00:00
# 	Actual price = 8665.470 (-0.456 %)
# 		Short changed by =  446.71092899625205  to  98374.25387981658
#
# 	Currently holding Short for  6  days
# 		Holding Short
#
# 	Portfolio value =  1023541.9076002304
# 		Cash =  925167.6537204138
# 		Stock value =  0
# 		Short value =  98374.25387981658
#
#  2019-11-29 00:00:00
# 	Actual price = 8567.990 (-1.125 %)
# 		Short changed by =  1106.6304095592016  to  99480.88428937578
#
# 	Currently holding Short for  7  days
# 		Holding Short
#
# 	Portfolio value =  1024648.5380097895
# 		Cash =  925167.6537204138
# 		Stock value =  0
# 		Short value =  99480.88428937578
#
#  2019-12-02 00:00:00
# 	Actual price = 8520.640 (-0.553 %)
# 		Short changed by =  549.7763223146568  to  100030.66061169044
#
# 	Currently holding Short for  8  days
# 		Holding Short
#
# 	Portfolio value =  1025198.3143321043
# 		Cash =  925167.6537204138
# 		Stock value =  0
# 		Short value =  100030.66061169044
#
#  2019-12-03 00:00:00
# 	Actual price = 8566.670 (0.540 %)
# 		Short changed by =  -540.3865026652343  to  99490.27410902521
#
# 	Currently holding Short for  9  days
# 		Holding Short
#
# 	Portfolio value =  1024657.927829439
# 		Cash =  925167.6537204138
# 		Stock value =  0
# 		Short value =  99490.27410902521
#
#  2019-12-04 00:00:00
# 	Actual price = 8570.700 (0.047 %)
# 		Short changed by =  -46.806170038991844  to  99443.46793898621
#
# 	Currently holding Short for  10  days
# 		Limit Reached
# 		Closing Short at  8570.7001953125
# 		Portfolio value =  1024611.1216594
# 			Cash =  1024611.1216594
# 			Stock value =  0
# 			Short value =  0
#
# 	Purchasing new position
# 		Pred. change in price = -2.116 %
# 		Short at  8570.7001953125
#
# 	Portfolio value =  1024611.1216594
# 		Cash =  924611.1216594
# 		Stock value =  0
# 		Short value =  100000
#
#  2019-12-05 00:00:00
# 	Actual price = 8656.530 (1.001 %)
# 		Short changed by =  -1001.4360107000629  to  98998.56398929993
#
# 	Currently holding Short for  1  days
# 		Holding Short
#
# 	Portfolio value =  1023609.6856487
# 		Cash =  924611.1216594
# 		Stock value =  0
# 		Short value =  98998.56398929993
#
#  2019-12-06 00:00:00
# 	Actual price = 8621.830 (-0.401 %)
# 		Short changed by =  396.8413899766325  to  99395.40537927656
#
# 	Currently holding Short for  2  days
# 		Holding Short
#
# 	Portfolio value =  1024006.5270386767
# 		Cash =  924611.1216594
# 		Stock value =  0
# 		Short value =  99395.40537927656
#
#  2019-12-09 00:00:00
# 	Actual price = 8616.180 (-0.066 %)
# 		Short changed by =  65.13963527860152  to  99460.54501455516
#
# 	Currently holding Short for  3  days
# 		Holding Short
#
# 	Portfolio value =  1024071.6666739553
# 		Cash =  924611.1216594
# 		Stock value =  0
# 		Short value =  99460.54501455516
#
#  2019-12-10 00:00:00
# 	Actual price = 8654.050 (0.440 %)
# 		Short changed by =  -437.15226838853255  to  99023.39274616663
#
# 	Currently holding Short for  4  days
# 		Holding Short
#
# 	Portfolio value =  1023634.5144055667
# 		Cash =  924611.1216594
# 		Stock value =  0
# 		Short value =  99023.39274616663
#
#  2019-12-11 00:00:00
# 	Actual price = 8717.320 (0.731 %)
# 		Short changed by =  -723.9686026504017  to  98299.42414351623
#
# 	Currently holding Short for  5  days
# 		Holding Short
#
# 	Portfolio value =  1022910.5458029163
# 		Cash =  924611.1216594
# 		Stock value =  0
# 		Short value =  98299.42414351623
#
#  2019-12-12 00:00:00
# 	Actual price = 8734.880 (0.201 %)
# 		Short changed by =  -198.0075972946914  to  98101.41654622153
#
# 	Currently holding Short for  6  days
# 		Holding Short
#
# 	Portfolio value =  1022712.5382056215
# 		Cash =  924611.1216594
# 		Stock value =  0
# 		Short value =  98101.41654622153
#
#  2019-12-13 00:00:00
# 	Actual price = 8814.230 (0.908 %)
# 		Short changed by =  -891.1862542676403  to  97210.23029195389
#
# 	Currently holding Short for  7  days
# 		Holding Short
#
# 	Portfolio value =  1021821.351951354
# 		Cash =  924611.1216594
# 		Stock value =  0
# 		Short value =  97210.23029195389
#
#  2019-12-16 00:00:00
# 	Actual price = 8823.360 (0.104 %)
# 		Short changed by =  -100.69149132057368  to  97109.53880063332
#
# 	Currently holding Short for  8  days
# 		Holding Short
#
# 	Portfolio value =  1021720.6604600333
# 		Cash =  924611.1216594
# 		Stock value =  0
# 		Short value =  97109.53880063332
#
#  2019-12-17 00:00:00
# 	Actual price = 8827.740 (0.050 %)
# 		Short changed by =  -48.2048089362434  to  97061.33399169707
#
# 	Currently holding Short for  9  days
# 		Holding Short
#
# 	Portfolio value =  1021672.4556510971
# 		Cash =  924611.1216594
# 		Stock value =  0
# 		Short value =  97061.33399169707
#
#  2019-12-18 00:00:00
# 	Actual price = 8887.220 (0.674 %)
# 		Short changed by =  -653.9792408465916  to  96407.35475085049
#
# 	Currently holding Short for  10  days
# 		Limit Reached
# 		Closing Short at  8887.2197265625
# 		Portfolio value =  1021018.4764102505
# 			Cash =  1021018.4764102505
# 			Stock value =  0
# 			Short value =  0
#
# 	Purchasing new position
# 		Pred. change in price = -4.134 %
# 		Short at  8887.2197265625
#
# 	Portfolio value =  1021018.4764102505
# 		Cash =  921018.4764102505
# 		Stock value =  0
# 		Short value =  100000
#
#  2019-12-19 00:00:00
# 	Actual price = 8924.960 (0.425 %)
# 		Short changed by =  -424.6573792048866  to  99575.34262079511
#
# 	Currently holding Short for  1  days
# 		Holding Short
#
# 	Portfolio value =  1020593.8190310457
# 		Cash =  921018.4764102505
# 		Stock value =  0
# 		Short value =  99575.34262079511
#
#  2019-12-20 00:00:00
# 	Actual price = 8945.650 (0.232 %)
# 		Short changed by =  -230.84211403990085  to  99344.50050675521
#
# 	Currently holding Short for  2  days
# 		Holding Short
#
# 	Portfolio value =  1020362.9769170057
# 		Cash =  921018.4764102505
# 		Stock value =  0
# 		Short value =  99344.50050675521
#
#  2019-12-23 00:00:00
# 	Actual price = 8952.880 (0.081 %)
# 		Short changed by =  -80.28597798069077  to  99264.21452877452
#
# 	Currently holding Short for  3  days
# 		Holding Short
#
# 	Portfolio value =  1020282.690939025
# 		Cash =  921018.4764102505
# 		Stock value =  0
# 		Short value =  99264.21452877452
#
#  2019-12-24 00:00:00
# 	Actual price = 9022.390 (0.776 %)
# 		Short changed by =  -770.6829955454838  to  98493.53153322903
#
# 	Currently holding Short for  4  days
# 		Holding Short
#
# 	Portfolio value =  1019512.0079434796
# 		Cash =  921018.4764102505
# 		Stock value =  0
# 		Short value =  98493.53153322903
#
#  2019-12-26 00:00:00
# 	Actual price = 9006.620 (-0.175 %)
# 		Short changed by =  172.14916268941  to  98665.68069591845
#
# 	Currently holding Short for  5  days
# 		Holding Short
#
# 	Portfolio value =  1019684.157106169
# 		Cash =  921018.4764102505
# 		Stock value =  0
# 		Short value =  98665.68069591845
#
#  2019-12-27 00:00:00
# 	Actual price = 8945.990 (-0.673 %)
# 		Short changed by =  664.1879617852815  to  99329.86865770373
#
# 	Currently holding Short for  6  days
# 		Holding Short
#
# 	Portfolio value =  1020348.3450679543
# 		Cash =  921018.4764102505
# 		Stock value =  0
# 		Short value =  99329.86865770373
#
# Total profit =  20348.345067954273
# Profitability =  2.0348345067954243 %
# Profit per day (PPD) =  20.24710952035251

# %% [markdown]
# ## Random

# %% [markdown]
# The random strategy functions similarly to the naive strategy, except that instead of forecasting the value for the following day the system creates a random number that determines whether the model will buy, sell, or hold on a particular day.

# %%
def random_trading_strat():

  available_money = STARTING_MONEY
  stock_value = 0
  short_value = 0
  days = 0
  porfolio_history = []

  for x in range(0, predicted_stock_price.size):
    
    # Print the current date
    print("\n", DATES[x])

    # Find and print the current price of the stock
    actual_price_string = "\tActual price = %.3f" % real_stock_price.iloc[x,0]
    if x == 0:
      print(actual_price_string)
    else: # If this isn't the first iteration, also print the % change from yesterday's price
      actual_price_difference = get_change(real_stock_price.iloc[x,0], real_stock_price.iloc[x-1,0])
      print(actual_price_string, "(%.3f" % actual_price_difference, "%)")

      # change investment values by change in stock
      if stock_value > 0:
        change_in_stock = stock_value * (actual_price_difference/100)
        stock_value = stock_value + change_in_stock
        # print("\t\tStock changed by = ", change_in_stock, " to ", stock_value)
      if short_value > 0:
        change_in_short = short_value * (actual_price_difference/100) * -1
        short_value = short_value + change_in_short
        # print("\t\tShort changed by = ", change_in_short, " to ", short_value) 

      # Print information
      print("\t\tPortfolio value = ", available_money + stock_value + short_value)
      print("\t\t\tCash = ", available_money)
      print("\t\t\tStock value = ", stock_value)
      print("\t\t\tShort value = ", short_value)

    from random import randrange
    choice = randrange(3)

    if choice == 0: # buy

      print("\tDecision: Buy")

      # Close short (if we have short)
      if short_value > 0:

        print("\t\tClosing Short at ", real_stock_price.iloc[x,0])

        # If we have less shorts than BUY_VALUE close the rest of the shorts
        if short_value < BUY_VALUE:
          available_money = available_money + short_value
          short_value = 0

        # Else just close BUY_VALUE of shorts
        else:
          available_money = available_money + BUY_VALUE
          short_value = short_value - BUY_VALUE

      # Buy stock
      else:

          # Check we dont hit min cash limit
          if available_money - BUY_VALUE > CASH_LIMIT:

            print("\t\tBuying Stock at ", real_stock_price.iloc[x,0])

            # Move money from cash to stock_value
            available_money = available_money - BUY_VALUE
            stock_value = stock_value + BUY_VALUE

          # Reached min cash limit - do nothing
          else:
            print("\t\tHit cash limit. No transaction excecuted.")


    elif choice == 1: # sell

      print("\tDecision: Sell")

      if stock_value > 0: # sell stock if we are holding stock

        print("\t\tSell Stock at ", real_stock_price.iloc[x,0])

        # If we have less stock than SELL_VALUE sell the rest of the stock
        if stock_value < SELL_VALUE:
          available_money = available_money + stock_value
          stock_value = 0
        else:
          available_money = available_money + SELL_VALUE
          stock_value = stock_value - SELL_VALUE

      # Open short
      else: 

        # Check we wont go over the max short value
          if short_value + SELL_VALUE < SHORT_LIMIT:

              print("\t\tShort at ", real_stock_price.iloc[x,0])
            
              # Move money from cash to short
              available_money = available_money - SELL_VALUE
              short_value = short_value + SELL_VALUE

          else:
            print("\t\tHit short limit. No transaction excecuted.")


    elif choice == 2: # hold
      print("\tHolding Stock...")

    # Print information
    print("\n\tPortfolio value = ", available_money + stock_value + short_value)
    print("\t\tCash = ", available_money)
    print("\t\tStock value = ", stock_value)
    print("\t\tShort value = ", short_value)

    porfolio_history.append(available_money + stock_value + short_value)

    days = days + 1
  

  total_profit = available_money + stock_value + short_value - STARTING_MONEY
  profitability = (((available_money + stock_value + short_value)/STARTING_MONEY)-1)*100
  profit_per_day = (available_money + stock_value + short_value - STARTING_MONEY) / days

  return porfolio_history, total_profit, profitability, profit_per_day

random_history, rand_profit, rand_profitability, rand_ppd = random_trading_strat()

print("\nTotal profit = ", rand_profit)
print("Profitability = ", rand_profitability, "%")
print("Profit per day (PPD) = ", rand_ppd)
# Out:
# Streaming output truncated to the last 5000 lines.
# 	Decision: Sell
# 		Short at  7825.2998046875
#
# 	Portfolio value =  1014654.1686393038
# 		Cash =  551820.7325114713
# 		Stock value =  0
# 		Short value =  462833.4361278325
#
#  2018-07-19 00:00:00
# 	Actual price = 7820.200 (-0.065 %)
# 		Portfolio value =  1014955.7889974818
# 			Cash =  551820.7325114713
# 			Stock value =  0
# 			Short value =  463135.0564860106
# 	Decision: Buy
# 		Closing Short at  7820.2001953125
#
# 	Portfolio value =  1014955.7889974818
# 		Cash =  651820.7325114713
# 		Stock value =  0
# 		Short value =  363135.0564860106
#
#  2018-07-20 00:00:00
# 	Actual price = 7841.870 (0.277 %)
# 		Portfolio value =  1013949.5349237253
# 			Cash =  651820.7325114713
# 			Stock value =  0
# 			Short value =  362128.802412254
# 	Holding Stock...
#
# 	Portfolio value =  1013949.5349237253
# 		Cash =  651820.7325114713
# 		Stock value =  0
# 		Short value =  362128.802412254
#
#  2018-07-23 00:00:00
# 	Actual price = 7840.770 (-0.014 %)
# 		Portfolio value =  1014000.3362046494
# 			Cash =  651820.7325114713
# 			Stock value =  0
# 			Short value =  362179.60369317816
# 	Decision: Buy
# 		Closing Short at  7840.77001953125
#
# 	Portfolio value =  1014000.3362046494
# 		Cash =  751820.7325114713
# 		Stock value =  0
# 		Short value =  262179.60369317816
#
#  2018-07-24 00:00:00
# 	Actual price = 7932.240 (1.167 %)
# 		Portfolio value =  1010941.7559098918
# 			Cash =  751820.7325114713
# 			Stock value =  0
# 			Short value =  259121.02339842057
# 	Decision: Buy
# 		Closing Short at  7932.240234375
#
# 	Portfolio value =  1010941.7559098918
# 		Cash =  851820.7325114713
# 		Stock value =  0
# 		Short value =  159121.02339842057
#
#  2018-07-25 00:00:00
# 	Actual price = 7852.180 (-1.009 %)
# 		Portfolio value =  1012547.7635546891
# 			Cash =  851820.7325114713
# 			Stock value =  0
# 			Short value =  160727.03104321787
# 	Holding Stock...
#
# 	Portfolio value =  1012547.7635546891
# 		Cash =  851820.7325114713
# 		Stock value =  0
# 		Short value =  160727.03104321787
#
#  2018-07-26 00:00:00
# 	Actual price = 7737.420 (-1.462 %)
# 		Portfolio value =  1014896.8022266503
# 			Cash =  851820.7325114713
# 			Stock value =  0
# 			Short value =  163076.0697151791
# 	Decision: Buy
# 		Closing Short at  7737.419921875
#
# 	Portfolio value =  1014896.8022266503
# 		Cash =  951820.7325114713
# 		Stock value =  0
# 		Short value =  63076.069715179096
#
#  2018-07-27 00:00:00
# 	Actual price = 7630.000 (-1.388 %)
# 		Portfolio value =  1015772.4980722165
# 			Cash =  951820.7325114713
# 			Stock value =  0
# 			Short value =  63951.76556074523
# 	Decision: Sell
# 		Short at  7630.0
#
# 	Portfolio value =  1015772.4980722165
# 		Cash =  851820.7325114713
# 		Stock value =  0
# 		Short value =  163951.76556074523
#
#  2018-07-30 00:00:00
# 	Actual price = 7671.790 (0.548 %)
# 		Portfolio value =  1014874.5228838613
# 			Cash =  851820.7325114713
# 			Stock value =  0
# 			Short value =  163053.79037239013
# 	Decision: Buy
# 		Closing Short at  7671.7900390625
#
# 	Portfolio value =  1014874.5228838613
# 		Cash =  951820.7325114713
# 		Stock value =  0
# 		Short value =  63053.790372390125
#
#  2018-07-31 00:00:00
# 	Actual price = 7707.290 (0.463 %)
# 		Portfolio value =  1014582.7514006974
# 			Cash =  951820.7325114713
# 			Stock value =  0
# 			Short value =  62762.01888922615
# 	Decision: Buy
# 		Closing Short at  7707.2900390625
#
# 	Portfolio value =  1014582.7514006974
# 		Cash =  1014582.7514006974
# 		Stock value =  0
# 		Short value =  0
#
#  2018-08-01 00:00:00
# 	Actual price = 7802.690 (1.238 %)
# 		Portfolio value =  1014582.7514006974
# 			Cash =  1014582.7514006974
# 			Stock value =  0
# 			Short value =  0
# 	Holding Stock...
#
# 	Portfolio value =  1014582.7514006974
# 		Cash =  1014582.7514006974
# 		Stock value =  0
# 		Short value =  0
#
#  2018-08-02 00:00:00
# 	Actual price = 7812.010 (0.119 %)
# 		Portfolio value =  1014582.7514006974
# 			Cash =  1014582.7514006974
# 			Stock value =  0
# 			Short value =  0
# 	Holding Stock...
#
# 	Portfolio value =  1014582.7514006974
# 		Cash =  1014582.7514006974
# 		Stock value =  0
# 		Short value =  0
#
#  2018-08-03 00:00:00
# 	Actual price = 7859.680 (0.610 %)
# 		Portfolio value =  1014582.7514006974
# 			Cash =  1014582.7514006974
# 			Stock value =  0
# 			Short value =  0
# 	Holding Stock...
#
# 	Portfolio value =  1014582.7514006974
# 		Cash =  1014582.7514006974
# 		Stock value =  0
# 		Short value =  0
#
#  2018-08-06 00:00:00
# 	Actual price = 7883.660 (0.305 %)
# 		Portfolio value =  1014582.7514006974
# 			Cash =  1014582.7514006974
# 			Stock value =  0
# 			Short value =  0
# 	Decision: Sell
# 		Short at  7883.66015625
#
# 	Portfolio value =  1014582.7514006974
# 		Cash =  914582.7514006974
# 		Stock value =  0
# 		Short value =  100000
#
#  2018-08-07 00:00:00
# 	Actual price = 7888.330 (0.059 %)
# 		Portfolio value =  1014523.515946829
# 			Cash =  914582.7514006974
# 			Stock value =  0
# 			Short value =  99940.76454613156
# 	Holding Stock...
#
# 	Portfolio value =  1014523.515946829
# 		Cash =  914582.7514006974
# 		Stock value =  0
# 		Short value =  99940.76454613156
#
#  2018-08-08 00:00:00
# 	Actual price = 7891.780 (0.044 %)
# 		Portfolio value =  1014479.8100731208
# 			Cash =  914582.7514006974
# 			Stock value =  0
# 			Short value =  99897.05867242333
# 	Decision: Sell
# 		Short at  7891.77978515625
#
# 	Portfolio value =  1014479.8100731208
# 		Cash =  814582.7514006974
# 		Stock value =  0
# 		Short value =  199897.05867242333
#
#  2018-08-09 00:00:00
# 	Actual price = 7839.110 (-0.667 %)
# 		Portfolio value =  1015813.9276929664
# 			Cash =  814582.7514006974
# 			Stock value =  0
# 			Short value =  201231.176292269
# 	Holding Stock...
#
# 	Portfolio value =  1015813.9276929664
# 		Cash =  814582.7514006974
# 		Stock value =  0
# 		Short value =  201231.176292269
#
#  2018-08-10 00:00:00
# 	Actual price = 7819.710 (-0.247 %)
# 		Portfolio value =  1016311.9262204361
# 			Cash =  814582.7514006974
# 			Stock value =  0
# 			Short value =  201729.17481973878
# 	Holding Stock...
#
# 	Portfolio value =  1016311.9262204361
# 		Cash =  814582.7514006974
# 		Stock value =  0
# 		Short value =  201729.17481973878
#
#  2018-08-13 00:00:00
# 	Actual price = 7870.890 (0.655 %)
# 		Portfolio value =  1014991.6042802292
# 			Cash =  814582.7514006974
# 			Stock value =  0
# 			Short value =  200408.8528795318
# 	Decision: Buy
# 		Closing Short at  7870.89013671875
#
# 	Portfolio value =  1014991.6042802292
# 		Cash =  914582.7514006974
# 		Stock value =  0
# 		Short value =  100408.8528795318
#
#  2018-08-14 00:00:00
# 	Actual price = 7774.120 (-1.229 %)
# 		Portfolio value =  1016226.0982809692
# 			Cash =  914582.7514006974
# 			Stock value =  0
# 			Short value =  101643.34688027177
# 	Decision: Buy
# 		Closing Short at  7774.1201171875
#
# 	Portfolio value =  1016226.0982809692
# 		Cash =  1014582.7514006974
# 		Stock value =  0
# 		Short value =  1643.346880271769
#
#  2018-08-15 00:00:00
# 	Actual price = 7806.520 (0.417 %)
# 		Portfolio value =  1016219.249367184
# 			Cash =  1014582.7514006974
# 			Stock value =  0
# 			Short value =  1636.4979664866582
# 	Holding Stock...
#
# 	Portfolio value =  1016219.249367184
# 		Cash =  1014582.7514006974
# 		Stock value =  0
# 		Short value =  1636.4979664866582
#
#  2018-08-16 00:00:00
# 	Actual price = 7816.330 (0.126 %)
# 		Portfolio value =  1016217.1928630184
# 			Cash =  1014582.7514006974
# 			Stock value =  0
# 			Short value =  1634.4414623209582
# 	Holding Stock...
#
# 	Portfolio value =  1016217.1928630184
# 		Cash =  1014582.7514006974
# 		Stock value =  0
# 		Short value =  1634.4414623209582
#
#  2018-08-17 00:00:00
# 	Actual price = 7821.010 (0.060 %)
# 		Portfolio value =  1016216.2143123168
# 			Cash =  1014582.7514006974
# 			Stock value =  0
# 			Short value =  1633.4629116195092
# 	Decision: Sell
# 		Short at  7821.009765625
#
# 	Portfolio value =  1016216.2143123168
# 		Cash =  914582.7514006974
# 		Stock value =  0
# 		Short value =  101633.46291161951
#
#  2018-08-20 00:00:00
# 	Actual price = 7859.170 (0.488 %)
# 		Portfolio value =  1015720.325809277
# 			Cash =  914582.7514006974
# 			Stock value =  0
# 			Short value =  101137.57440857965
# 	Decision: Sell
# 		Short at  7859.169921875
#
# 	Portfolio value =  1015720.325809277
# 		Cash =  814582.7514006974
# 		Stock value =  0
# 		Short value =  201137.57440857965
#
#  2018-08-21 00:00:00
# 	Actual price = 7889.100 (0.381 %)
# 		Portfolio value =  1014954.3310518018
# 			Cash =  814582.7514006974
# 			Stock value =  0
# 			Short value =  200371.57965110443
# 	Decision: Buy
# 		Closing Short at  7889.10009765625
#
# 	Portfolio value =  1014954.3310518018
# 		Cash =  914582.7514006974
# 		Stock value =  0
# 		Short value =  100371.57965110443
#
#  2018-08-22 00:00:00
# 	Actual price = 7878.460 (-0.135 %)
# 		Portfolio value =  1015089.7035679247
# 			Cash =  914582.7514006974
# 			Stock value =  0
# 			Short value =  100506.95216722727
# 	Holding Stock...
#
# 	Portfolio value =  1015089.7035679247
# 		Cash =  914582.7514006974
# 		Stock value =  0
# 		Short value =  100506.95216722727
#
#  2018-08-23 00:00:00
# 	Actual price = 7945.980 (0.857 %)
# 		Portfolio value =  1014228.3383509908
# 			Cash =  914582.7514006974
# 			Stock value =  0
# 			Short value =  99645.58695029342
# 	Decision: Sell
# 		Short at  7945.97998046875
#
# 	Portfolio value =  1014228.3383509908
# 		Cash =  814582.7514006974
# 		Stock value =  0
# 		Short value =  199645.58695029342
#
#  2018-08-24 00:00:00
# 	Actual price = 8017.900 (0.905 %)
# 		Portfolio value =  1012421.3246092689
# 			Cash =  814582.7514006974
# 			Stock value =  0
# 			Short value =  197838.5732085716
# 	Decision: Sell
# 		Short at  8017.89990234375
#
# 	Portfolio value =  1012421.3246092689
# 		Cash =  714582.7514006974
# 		Stock value =  0
# 		Short value =  297838.5732085716
#
#  2018-08-27 00:00:00
# 	Actual price = 8030.040 (0.151 %)
# 		Portfolio value =  1011970.3585155401
# 			Cash =  714582.7514006974
# 			Stock value =  0
# 			Short value =  297387.6071148427
# 	Decision: Sell
# 		Short at  8030.0400390625
#
# 	Portfolio value =  1011970.3585155401
# 		Cash =  614582.7514006974
# 		Stock value =  0
# 		Short value =  397387.6071148427
#
#  2018-08-28 00:00:00
# 	Actual price = 8109.690 (0.992 %)
# 		Portfolio value =  1008028.6740475497
# 			Cash =  614582.7514006974
# 			Stock value =  0
# 			Short value =  393445.92264685227
# 	Holding Stock...
#
# 	Portfolio value =  1008028.6740475497
# 		Cash =  614582.7514006974
# 		Stock value =  0
# 		Short value =  393445.92264685227
#
#  2018-08-29 00:00:00
# 	Actual price = 8088.360 (-0.263 %)
# 		Portfolio value =  1009063.514137449
# 			Cash =  614582.7514006974
# 			Stock value =  0
# 			Short value =  394480.7627367515
# 	Holding Stock...
#
# 	Portfolio value =  1009063.514137449
# 		Cash =  614582.7514006974
# 		Stock value =  0
# 		Short value =  394480.7627367515
#
#  2018-08-30 00:00:00
# 	Actual price = 8109.540 (0.262 %)
# 		Portfolio value =  1008030.5269758594
# 			Cash =  614582.7514006974
# 			Stock value =  0
# 			Short value =  393447.77557516197
# 	Decision: Sell
# 		Short at  8109.5400390625
#
# 	Portfolio value =  1008030.5269758594
# 		Cash =  514582.7514006974
# 		Stock value =  0
# 		Short value =  493447.77557516197
#
#  2018-08-31 00:00:00
# 	Actual price = 8091.250 (-0.226 %)
# 		Portfolio value =  1009143.4358519609
# 			Cash =  514582.7514006974
# 			Stock value =  0
# 			Short value =  494560.6844512635
# 	Decision: Sell
# 		Hit short limit. No transaction excecuted.
#
# 	Portfolio value =  1009143.4358519609
# 		Cash =  514582.7514006974
# 		Stock value =  0
# 		Short value =  494560.6844512635
#
#  2018-09-04 00:00:00
# 	Actual price = 7995.170 (-1.187 %)
# 		Portfolio value =  1015016.1290946158
# 			Cash =  514582.7514006974
# 			Stock value =  0
# 			Short value =  500433.37769391836
# 	Holding Stock...
#
# 	Portfolio value =  1015016.1290946158
# 		Cash =  514582.7514006974
# 		Stock value =  0
# 		Short value =  500433.37769391836
#
#  2018-09-05 00:00:00
# 	Actual price = 7922.730 (-0.906 %)
# 		Portfolio value =  1019550.2872065897
# 			Cash =  514582.7514006974
# 			Stock value =  0
# 			Short value =  504967.53580589226
# 	Decision: Buy
# 		Closing Short at  7922.72998046875
#
# 	Portfolio value =  1019550.2872065897
# 		Cash =  614582.7514006974
# 		Stock value =  0
# 		Short value =  404967.53580589226
#
#  2018-09-06 00:00:00
# 	Actual price = 7902.540 (-0.255 %)
# 		Portfolio value =  1020582.2889079617
# 			Cash =  614582.7514006974
# 			Stock value =  0
# 			Short value =  405999.53750726423
# 	Decision: Buy
# 		Closing Short at  7902.5400390625
#
# 	Portfolio value =  1020582.2889079617
# 		Cash =  714582.7514006974
# 		Stock value =  0
# 		Short value =  305999.53750726423
#
#  2018-09-07 00:00:00
# 	Actual price = 7924.160 (0.274 %)
# 		Portfolio value =  1019745.1218923533
# 			Cash =  714582.7514006974
# 			Stock value =  0
# 			Short value =  305162.37049165583
# 	Decision: Buy
# 		Closing Short at  7924.16015625
#
# 	Portfolio value =  1019745.1218923533
# 		Cash =  814582.7514006974
# 		Stock value =  0
# 		Short value =  205162.37049165583
#
#  2018-09-10 00:00:00
# 	Actual price = 7972.470 (0.610 %)
# 		Portfolio value =  1018494.3387248944
# 			Cash =  814582.7514006974
# 			Stock value =  0
# 			Short value =  203911.5873241971
# 	Holding Stock...
#
# 	Portfolio value =  1018494.3387248944
# 		Cash =  814582.7514006974
# 		Stock value =  0
# 		Short value =  203911.5873241971
#
#  2018-09-11 00:00:00
# 	Actual price = 7954.230 (-0.229 %)
# 		Portfolio value =  1018960.8685512019
# 			Cash =  814582.7514006974
# 			Stock value =  0
# 			Short value =  204378.11715050446
# 	Decision: Buy
# 		Closing Short at  7954.22998046875
#
# 	Portfolio value =  1018960.8685512019
# 		Cash =  914582.7514006974
# 		Stock value =  0
# 		Short value =  104378.11715050446
#
#  2018-09-12 00:00:00
# 	Actual price = 8013.710 (0.748 %)
# 		Portfolio value =  1018180.3519726365
# 			Cash =  914582.7514006974
# 			Stock value =  0
# 			Short value =  103597.60057193917
# 	Decision: Sell
# 		Short at  8013.7099609375
#
# 	Portfolio value =  1018180.3519726365
# 		Cash =  814582.7514006974
# 		Stock value =  0
# 		Short value =  203597.60057193917
#
#  2018-09-13 00:00:00
# 	Actual price = 8010.040 (-0.046 %)
# 		Portfolio value =  1018273.5905964049
# 			Cash =  814582.7514006974
# 			Stock value =  0
# 			Short value =  203690.83919570752
# 	Decision: Buy
# 		Closing Short at  8010.0400390625
#
# 	Portfolio value =  1018273.5905964049
# 		Cash =  914582.7514006974
# 		Stock value =  0
# 		Short value =  103690.83919570752
#
#  2018-09-14 00:00:00
# 	Actual price = 7895.790 (-1.426 %)
# 		Portfolio value =  1019752.5692682139
# 			Cash =  914582.7514006974
# 			Stock value =  0
# 			Short value =  105169.81786751653
# 	Holding Stock...
#
# 	Portfolio value =  1019752.5692682139
# 		Cash =  914582.7514006974
# 		Stock value =  0
# 		Short value =  105169.81786751653
#
#  2018-09-17 00:00:00
# 	Actual price = 7956.110 (0.764 %)
# 		Portfolio value =  1018949.1252942098
# 			Cash =  914582.7514006974
# 			Stock value =  0
# 			Short value =  104366.3738935124
# 	Decision: Sell
# 		Short at  7956.10986328125
#
# 	Portfolio value =  1018949.1252942098
# 		Cash =  814582.7514006974
# 		Stock value =  0
# 		Short value =  204366.3738935124
#
#  2018-09-18 00:00:00
# 	Actual price = 7950.040 (-0.076 %)
# 		Portfolio value =  1019105.0391751231
# 			Cash =  814582.7514006974
# 			Stock value =  0
# 			Short value =  204522.28777442573
# 	Decision: Sell
# 		Short at  7950.0400390625
#
# 	Portfolio value =  1019105.0391751231
# 		Cash =  714582.7514006974
# 		Stock value =  0
# 		Short value =  304522.2877744257
#
#  2018-09-19 00:00:00
# 	Actual price = 8028.230 (0.984 %)
# 		Portfolio value =  1016110.0127701005
# 			Cash =  714582.7514006974
# 			Stock value =  0
# 			Short value =  301527.26136940304
# 	Decision: Buy
# 		Closing Short at  8028.22998046875
#
# 	Portfolio value =  1016110.0127701005
# 		Cash =  814582.7514006974
# 		Stock value =  0
# 		Short value =  201527.26136940304
#
#  2018-09-20 00:00:00
# 	Actual price = 7986.960 (-0.514 %)
# 		Portfolio value =  1017145.9863325206
# 			Cash =  814582.7514006974
# 			Stock value =  0
# 			Short value =  202563.23493182322
# 	Decision: Sell
# 		Short at  7986.9599609375
#
# 	Portfolio value =  1017145.9863325206
# 		Cash =  714582.7514006974
# 		Stock value =  0
# 		Short value =  302563.2349318232
#
#  2018-09-21 00:00:00
# 	Actual price = 7993.250 (0.079 %)
# 		Portfolio value =  1016907.706113776
# 			Cash =  714582.7514006974
# 			Stock value =  0
# 			Short value =  302324.9547130785
# 	Decision: Sell
# 		Short at  7993.25
#
# 	Portfolio value =  1016907.706113776
# 		Cash =  614582.7514006974
# 		Stock value =  0
# 		Short value =  402324.9547130785
#
#  2018-09-24 00:00:00
# 	Actual price = 8007.470 (0.178 %)
# 		Portfolio value =  1016191.958790344
# 			Cash =  614582.7514006974
# 			Stock value =  0
# 			Short value =  401609.2073896466
# 	Decision: Sell
# 		Hit short limit. No transaction excecuted.
#
# 	Portfolio value =  1016191.958790344
# 		Cash =  614582.7514006974
# 		Stock value =  0
# 		Short value =  401609.2073896466
#
#  2018-09-25 00:00:00
# 	Actual price = 7990.370 (-0.214 %)
# 		Portfolio value =  1017049.6025257253
# 			Cash =  614582.7514006974
# 			Stock value =  0
# 			Short value =  402466.8511250278
# 	Holding Stock...
#
# 	Portfolio value =  1017049.6025257253
# 		Cash =  614582.7514006974
# 		Stock value =  0
# 		Short value =  402466.8511250278
#
#  2018-09-26 00:00:00
# 	Actual price = 8041.970 (0.646 %)
# 		Portfolio value =  1014450.5578611002
# 			Cash =  614582.7514006974
# 			Stock value =  0
# 			Short value =  399867.80646040285
# 	Decision: Buy
# 		Closing Short at  8041.97021484375
#
# 	Portfolio value =  1014450.5578611002
# 		Cash =  714582.7514006974
# 		Stock value =  0
# 		Short value =  299867.80646040285
#
#  2018-09-27 00:00:00
# 	Actual price = 8046.350 (0.054 %)
# 		Portfolio value =  1014287.2414328556
# 			Cash =  714582.7514006974
# 			Stock value =  0
# 			Short value =  299704.4900321582
# 	Holding Stock...
#
# 	Portfolio value =  1014287.2414328556
# 		Cash =  714582.7514006974
# 		Stock value =  0
# 		Short value =  299704.4900321582
#
#  2018-09-28 00:00:00
# 	Actual price = 8037.300 (-0.112 %)
# 		Portfolio value =  1014624.3400435202
# 			Cash =  714582.7514006974
# 			Stock value =  0
# 			Short value =  300041.5886428228
# 	Decision: Buy
# 		Closing Short at  8037.2998046875
#
# 	Portfolio value =  1014624.3400435202
# 		Cash =  814582.7514006974
# 		Stock value =  0
# 		Short value =  200041.5886428228
#
#  2018-10-01 00:00:00
# 	Actual price = 7999.550 (-0.470 %)
# 		Portfolio value =  1015563.9055885136
# 			Cash =  814582.7514006974
# 			Stock value =  0
# 			Short value =  200981.15418781622
# 	Holding Stock...
#
# 	Portfolio value =  1015563.9055885136
# 		Cash =  814582.7514006974
# 		Stock value =  0
# 		Short value =  200981.15418781622
#
#  2018-10-02 00:00:00
# 	Actual price = 8025.090 (0.319 %)
# 		Portfolio value =  1014922.2361628448
# 			Cash =  814582.7514006974
# 			Stock value =  0
# 			Short value =  200339.4847621474
# 	Decision: Sell
# 		Short at  8025.08984375
#
# 	Portfolio value =  1014922.2361628448
# 		Cash =  714582.7514006974
# 		Stock value =  0
# 		Short value =  300339.4847621474
#
#  2018-10-03 00:00:00
# 	Actual price = 7879.510 (-1.814 %)
# 		Portfolio value =  1020370.5796090865
# 			Cash =  714582.7514006974
# 			Stock value =  0
# 			Short value =  305787.82820838905
# 	Decision: Buy
# 		Closing Short at  7879.509765625
#
# 	Portfolio value =  1020370.5796090865
# 		Cash =  814582.7514006974
# 		Stock value =  0
# 		Short value =  205787.82820838905
#
#  2018-10-04 00:00:00
# 	Actual price = 7788.450 (-1.156 %)
# 		Portfolio value =  1022748.7670559691
# 			Cash =  814582.7514006974
# 			Stock value =  0
# 			Short value =  208166.01565527168
# 	Decision: Sell
# 		Short at  7788.4501953125
#
# 	Portfolio value =  1022748.7670559691
# 		Cash =  714582.7514006974
# 		Stock value =  0
# 		Short value =  308166.0156552717
#
#  2018-10-05 00:00:00
# 	Actual price = 7735.950 (-0.674 %)
# 		Portfolio value =  1024826.0372979536
# 			Cash =  714582.7514006974
# 			Stock value =  0
# 			Short value =  310243.2858972563
# 	Decision: Sell
# 		Short at  7735.9501953125
#
# 	Portfolio value =  1024826.0372979536
# 		Cash =  614582.7514006974
# 		Stock value =  0
# 		Short value =  410243.2858972563
#
#  2018-10-08 00:00:00
# 	Actual price = 7738.020 (0.027 %)
# 		Portfolio value =  1024716.2729552044
# 			Cash =  614582.7514006974
# 			Stock value =  0
# 			Short value =  410133.52155450697
# 	Decision: Sell
# 		Hit short limit. No transaction excecuted.
#
# 	Portfolio value =  1024716.2729552044
# 		Cash =  614582.7514006974
# 		Stock value =  0
# 		Short value =  410133.52155450697
#
#  2018-10-09 00:00:00
# 	Actual price = 7422.050 (-4.083 %)
# 		Portfolio value =  1041463.4481490017
# 			Cash =  614582.7514006974
# 			Stock value =  0
# 			Short value =  426880.69674830436
# 	Holding Stock...
#
# 	Portfolio value =  1041463.4481490017
# 		Cash =  614582.7514006974
# 		Stock value =  0
# 		Short value =  426880.69674830436
#
#  2018-10-10 00:00:00
# 	Actual price = 7329.060 (-1.253 %)
# 		Portfolio value =  1046811.772216819
# 			Cash =  614582.7514006974
# 			Stock value =  0
# 			Short value =  432229.02081612154
# 	Holding Stock...
#
# 	Portfolio value =  1046811.772216819
# 		Cash =  614582.7514006974
# 		Stock value =  0
# 		Short value =  432229.02081612154
#
#  2018-10-11 00:00:00
# 	Actual price = 7496.890 (2.290 %)
# 		Portfolio value =  1036914.0459392995
# 			Cash =  614582.7514006974
# 			Stock value =  0
# 			Short value =  422331.29453860206
# 	Decision: Buy
# 		Closing Short at  7496.89013671875
#
# 	Portfolio value =  1036914.0459392995
# 		Cash =  714582.7514006974
# 		Stock value =  0
# 		Short value =  322331.29453860206
#
#  2018-10-12 00:00:00
# 	Actual price = 7430.740 (-0.882 %)
# 		Portfolio value =  1039758.1830771281
# 			Cash =  714582.7514006974
# 			Stock value =  0
# 			Short value =  325175.4316764307
# 	Holding Stock...
#
# 	Portfolio value =  1039758.1830771281
# 		Cash =  714582.7514006974
# 		Stock value =  0
# 		Short value =  325175.4316764307
#
#  2018-10-15 00:00:00
# 	Actual price = 7645.490 (2.890 %)
# 		Portfolio value =  1030360.5427680954
# 			Cash =  714582.7514006974
# 			Stock value =  0
# 			Short value =  315777.791367398
# 	Decision: Buy
# 		Closing Short at  7645.490234375
#
# 	Portfolio value =  1030360.5427680954
# 		Cash =  814582.7514006974
# 		Stock value =  0
# 		Short value =  215777.791367398
#
#  2018-10-16 00:00:00
# 	Actual price = 7642.700 (-0.036 %)
# 		Portfolio value =  1030439.2857195975
# 			Cash =  814582.7514006974
# 			Stock value =  0
# 			Short value =  215856.53431890009
# 	Decision: Sell
# 		Short at  7642.7001953125
#
# 	Portfolio value =  1030439.2857195975
# 		Cash =  714582.7514006974
# 		Stock value =  0
# 		Short value =  315856.5343189001
#
#  2018-10-17 00:00:00
# 	Actual price = 7485.140 (-2.062 %)
# 		Portfolio value =  1036950.9076310559
# 			Cash =  714582.7514006974
# 			Stock value =  0
# 			Short value =  322368.1562303585
# 	Decision: Buy
# 		Closing Short at  7485.14013671875
#
# 	Portfolio value =  1036950.9076310559
# 		Cash =  814582.7514006974
# 		Stock value =  0
# 		Short value =  222368.15623035852
#
#  2018-10-18 00:00:00
# 	Actual price = 7449.030 (-0.482 %)
# 		Portfolio value =  1038023.6720885164
# 			Cash =  814582.7514006974
# 			Stock value =  0
# 			Short value =  223440.92068781905
# 	Holding Stock...
#
# 	Portfolio value =  1038023.6720885164
# 		Cash =  814582.7514006974
# 		Stock value =  0
# 		Short value =  223440.92068781905
#
#  2018-10-19 00:00:00
# 	Actual price = 7468.630 (0.263 %)
# 		Portfolio value =  1037435.7480242832
# 			Cash =  814582.7514006974
# 			Stock value =  0
# 			Short value =  222852.9966235858
# 	Decision: Buy
# 		Closing Short at  7468.6298828125
#
# 	Portfolio value =  1037435.7480242832
# 		Cash =  914582.7514006974
# 		Stock value =  0
# 		Short value =  122852.99662358579
#
#  2018-10-22 00:00:00
# 	Actual price = 7437.540 (-0.416 %)
# 		Portfolio value =  1037947.1511235365
# 			Cash =  914582.7514006974
# 			Stock value =  0
# 			Short value =  123364.39972283914
# 	Decision: Sell
# 		Short at  7437.5400390625
#
# 	Portfolio value =  1037947.1511235365
# 		Cash =  814582.7514006974
# 		Stock value =  0
# 		Short value =  223364.39972283912
#
#  2018-10-23 00:00:00
# 	Actual price = 7108.400 (-4.425 %)
# 		Portfolio value =  1047831.8964394277
# 			Cash =  814582.7514006974
# 			Stock value =  0
# 			Short value =  233249.14503873038
# 	Decision: Buy
# 		Closing Short at  7108.39990234375
#
# 	Portfolio value =  1047831.8964394277
# 		Cash =  914582.7514006974
# 		Stock value =  0
# 		Short value =  133249.14503873038
#
#  2018-10-24 00:00:00
# 	Actual price = 7318.340 (2.953 %)
# 		Portfolio value =  1043896.5075915606
# 			Cash =  914582.7514006974
# 			Stock value =  0
# 			Short value =  129313.75619086316
# 	Decision: Sell
# 		Short at  7318.33984375
#
# 	Portfolio value =  1043896.5075915605
# 		Cash =  814582.7514006974
# 		Stock value =  0
# 		Short value =  229313.75619086315
#
#  2018-10-25 00:00:00
# 	Actual price = 7167.210 (-2.065 %)
# 		Portfolio value =  1048632.0298329904
# 			Cash =  814582.7514006974
# 			Stock value =  0
# 			Short value =  234049.27843229286
# 	Holding Stock...
#
# 	Portfolio value =  1048632.0298329904
# 		Cash =  814582.7514006974
# 		Stock value =  0
# 		Short value =  234049.27843229286
#
#  2018-10-26 00:00:00
# 	Actual price = 7050.290 (-1.631 %)
# 		Portfolio value =  1052450.1157406652
# 			Cash =  814582.7514006974
# 			Stock value =  0
# 			Short value =  237867.36433996793
# 	Holding Stock...
#
# 	Portfolio value =  1052450.1157406652
# 		Cash =  814582.7514006974
# 		Stock value =  0
# 		Short value =  237867.36433996793
#
#  2018-10-29 00:00:00
# 	Actual price = 7161.650 (1.580 %)
# 		Portfolio value =  1048692.9827680916
# 			Cash =  814582.7514006974
# 			Stock value =  0
# 			Short value =  234110.23136739415
# 	Holding Stock...
#
# 	Portfolio value =  1048692.9827680916
# 		Cash =  814582.7514006974
# 		Stock value =  0
# 		Short value =  234110.23136739415
#
#  2018-10-30 00:00:00
# 	Actual price = 7305.900 (2.014 %)
# 		Portfolio value =  1043977.5329296829
# 			Cash =  814582.7514006974
# 			Stock value =  0
# 			Short value =  229394.78152898545
# 	Decision: Sell
# 		Short at  7305.89990234375
#
# 	Portfolio value =  1043977.5329296829
# 		Cash =  714582.7514006974
# 		Stock value =  0
# 		Short value =  329394.7815289855
#
#  2018-10-31 00:00:00
# 	Actual price = 7434.060 (1.754 %)
# 		Portfolio value =  1038199.2869595804
# 			Cash =  714582.7514006974
# 			Stock value =  0
# 			Short value =  323616.53555888304
# 	Holding Stock...
#
# 	Portfolio value =  1038199.2869595804
# 		Cash =  714582.7514006974
# 		Stock value =  0
# 		Short value =  323616.53555888304
#
#  2018-11-01 00:00:00
# 	Actual price = 7356.990 (-1.037 %)
# 		Portfolio value =  1041554.2597891276
# 			Cash =  714582.7514006974
# 			Stock value =  0
# 			Short value =  326971.50838843023
# 	Decision: Buy
# 		Closing Short at  7356.990234375
#
# 	Portfolio value =  1041554.2597891276
# 		Cash =  814582.7514006974
# 		Stock value =  0
# 		Short value =  226971.50838843023
#
#  2018-11-02 00:00:00
# 	Actual price = 7328.850 (-0.382 %)
# 		Portfolio value =  1042422.4149821941
# 			Cash =  814582.7514006974
# 			Stock value =  0
# 			Short value =  227839.66358149663
# 	Decision: Buy
# 		Closing Short at  7328.85009765625
#
# 	Portfolio value =  1042422.4149821941
# 		Cash =  914582.7514006974
# 		Stock value =  0
# 		Short value =  127839.66358149663
#
#  2018-11-05 00:00:00
# 	Actual price = 7375.960 (0.643 %)
# 		Portfolio value =  1041600.6613655972
# 			Cash =  914582.7514006974
# 			Stock value =  0
# 			Short value =  127017.90996489977
# 	Holding Stock...
#
# 	Portfolio value =  1041600.6613655972
# 		Cash =  914582.7514006974
# 		Stock value =  0
# 		Short value =  127017.90996489977
#
#  2018-11-06 00:00:00
# 	Actual price = 7570.750 (2.641 %)
# 		Portfolio value =  1038246.2744417621
# 			Cash =  914582.7514006974
# 			Stock value =  0
# 			Short value =  123663.52304106468
# 	Holding Stock...
#
# 	Portfolio value =  1038246.2744417621
# 		Cash =  914582.7514006974
# 		Stock value =  0
# 		Short value =  123663.52304106468
#
#  2018-11-07 00:00:00
# 	Actual price = 7530.880 (-0.527 %)
# 		Portfolio value =  1038897.5281689974
# 			Cash =  914582.7514006974
# 			Stock value =  0
# 			Short value =  124314.77676829994
# 	Decision: Buy
# 		Closing Short at  7530.8798828125
#
# 	Portfolio value =  1038897.5281689974
# 		Cash =  1014582.7514006974
# 		Stock value =  0
# 		Short value =  24314.77676829994
#
#  2018-11-08 00:00:00
# 	Actual price = 7406.900 (-1.646 %)
# 		Portfolio value =  1039297.8194491325
# 			Cash =  1014582.7514006974
# 			Stock value =  0
# 			Short value =  24715.068048435194
# 	Decision: Sell
# 		Short at  7406.89990234375
#
# 	Portfolio value =  1039297.8194491325
# 		Cash =  914582.7514006974
# 		Stock value =  0
# 		Short value =  124715.06804843519
#
#  2018-11-09 00:00:00
# 	Actual price = 7200.870 (-2.782 %)
# 		Portfolio value =  1042766.8846470618
# 			Cash =  914582.7514006974
# 			Stock value =  0
# 			Short value =  128184.13324636444
# 	Decision: Buy
# 		Closing Short at  7200.8701171875
#
# 	Portfolio value =  1042766.8846470618
# 		Cash =  1014582.7514006974
# 		Stock value =  0
# 		Short value =  28184.133246364436
#
#  2018-11-12 00:00:00
# 	Actual price = 7200.870 (0.000 %)
# 		Portfolio value =  1042766.8846470618
# 			Cash =  1014582.7514006974
# 			Stock value =  0
# 			Short value =  28184.133246364436
# 	Decision: Sell
# 		Short at  7200.8701171875
#
# 	Portfolio value =  1042766.8846470618
# 		Cash =  914582.7514006974
# 		Stock value =  0
# 		Short value =  128184.13324636444
#
#  2018-11-13 00:00:00
# 	Actual price = 7136.390 (-0.895 %)
# 		Portfolio value =  1043914.7057122414
# 			Cash =  914582.7514006974
# 			Stock value =  0
# 			Short value =  129331.95431154392
# 	Decision: Sell
# 		Short at  7136.39013671875
#
# 	Portfolio value =  1043914.7057122414
# 		Cash =  814582.7514006974
# 		Stock value =  0
# 		Short value =  229331.9543115439
#
#  2018-11-14 00:00:00
# 	Actual price = 7259.030 (1.719 %)
# 		Portfolio value =  1039973.6108851044
# 			Cash =  814582.7514006974
# 			Stock value =  0
# 			Short value =  225390.85948440706
# 	Decision: Buy
# 		Closing Short at  7259.02978515625
#
# 	Portfolio value =  1039973.6108851044
# 		Cash =  914582.7514006974
# 		Stock value =  0
# 		Short value =  125390.85948440706
#
#  2018-11-15 00:00:00
# 	Actual price = 7247.870 (-0.154 %)
# 		Portfolio value =  1040166.3804975152
# 			Cash =  914582.7514006974
# 			Stock value =  0
# 			Short value =  125583.62909681775
# 	Decision: Sell
# 		Short at  7247.8701171875
#
# 	Portfolio value =  1040166.3804975152
# 		Cash =  814582.7514006974
# 		Stock value =  0
# 		Short value =  225583.62909681775
#
#  2018-11-16 00:00:00
# 	Actual price = 7028.480 (-3.027 %)
# 		Portfolio value =  1046994.7069477506
# 			Cash =  814582.7514006974
# 			Stock value =  0
# 			Short value =  232411.95554705322
# 	Decision: Sell
# 		Short at  7028.47998046875
#
# 	Portfolio value =  1046994.7069477506
# 		Cash =  714582.7514006974
# 		Stock value =  0
# 		Short value =  332411.95554705325
#
#  2018-11-19 00:00:00
# 	Actual price = 6908.820 (-1.703 %)
# 		Portfolio value =  1052654.0339502692
# 			Cash =  714582.7514006974
# 			Stock value =  0
# 			Short value =  338071.2825495719
# 	Decision: Buy
# 		Closing Short at  6908.81982421875
#
# 	Portfolio value =  1052654.0339502692
# 		Cash =  814582.7514006974
# 		Stock value =  0
# 		Short value =  238071.2825495719
#
#  2018-11-20 00:00:00
# 	Actual price = 6972.250 (0.918 %)
# 		Portfolio value =  1050468.2911338694
# 			Cash =  814582.7514006974
# 			Stock value =  0
# 			Short value =  235885.53973317205
# 	Holding Stock...
#
# 	Portfolio value =  1050468.2911338694
# 		Cash =  814582.7514006974
# 		Stock value =  0
# 		Short value =  235885.53973317205
#
#  2018-11-21 00:00:00
# 	Actual price = 6938.980 (-0.477 %)
# 		Portfolio value =  1051593.884237109
# 			Cash =  814582.7514006974
# 			Stock value =  0
# 			Short value =  237011.13283641162
# 	Decision: Sell
# 		Short at  6938.97998046875
#
# 	Portfolio value =  1051593.884237109
# 		Cash =  714582.7514006974
# 		Stock value =  0
# 		Short value =  337011.1328364116
#
#  2018-11-23 00:00:00
# 	Actual price = 7081.850 (2.059 %)
# 		Portfolio value =  1044654.9940576653
# 			Cash =  714582.7514006974
# 			Stock value =  0
# 			Short value =  330072.242656968
# 	Decision: Sell
# 		Short at  7081.85009765625
#
# 	Portfolio value =  1044654.9940576653
# 		Cash =  614582.7514006974
# 		Stock value =  0
# 		Short value =  430072.242656968
#
#  2018-11-26 00:00:00
# 	Actual price = 7082.700 (0.012 %)
# 		Portfolio value =  1044603.3686489856
# 			Cash =  614582.7514006974
# 			Stock value =  0
# 			Short value =  430020.6172482882
# 	Decision: Sell
# 		Hit short limit. No transaction excecuted.
#
# 	Portfolio value =  1044603.3686489856
# 		Cash =  614582.7514006974
# 		Stock value =  0
# 		Short value =  430020.6172482882
#
#  2018-11-27 00:00:00
# 	Actual price = 7291.590 (2.949 %)
# 		Portfolio value =  1031920.7965958411
# 			Cash =  614582.7514006974
# 			Stock value =  0
# 			Short value =  417338.04519514367
# 	Holding Stock...
#
# 	Portfolio value =  1031920.7965958411
# 		Cash =  614582.7514006974
# 		Stock value =  0
# 		Short value =  417338.04519514367
#
#  2018-11-28 00:00:00
# 	Actual price = 7273.080 (-0.254 %)
# 		Portfolio value =  1032980.2129328117
# 			Cash =  614582.7514006974
# 			Stock value =  0
# 			Short value =  418397.4615321143
# 	Decision: Buy
# 		Closing Short at  7273.080078125
#
# 	Portfolio value =  1032980.2129328117
# 		Cash =  714582.7514006974
# 		Stock value =  0
# 		Short value =  318397.4615321143
#
#  2018-11-29 00:00:00
# 	Actual price = 7330.540 (0.790 %)
# 		Portfolio value =  1030464.7579253438
# 			Cash =  714582.7514006974
# 			Stock value =  0
# 			Short value =  315882.0065246464
# 	Holding Stock...
#
# 	Portfolio value =  1030464.7579253438
# 		Cash =  714582.7514006974
# 		Stock value =  0
# 		Short value =  315882.0065246464
#
#  2018-11-30 00:00:00
# 	Actual price = 7441.510 (1.514 %)
# 		Portfolio value =  1025682.9356171286
# 			Cash =  714582.7514006974
# 			Stock value =  0
# 			Short value =  311100.1842164312
# 	Decision: Sell
# 		Short at  7441.509765625
#
# 	Portfolio value =  1025682.9356171286
# 		Cash =  614582.7514006974
# 		Stock value =  0
# 		Short value =  411100.1842164312
#
#  2018-12-03 00:00:00
# 	Actual price = 7158.430 (-3.804 %)
# 		Portfolio value =  1041321.438447596
# 			Cash =  614582.7514006974
# 			Stock value =  0
# 			Short value =  426738.68704689865
# 	Decision: Sell
# 		Hit short limit. No transaction excecuted.
#
# 	Portfolio value =  1041321.438447596
# 		Cash =  614582.7514006974
# 		Stock value =  0
# 		Short value =  426738.68704689865
#
#  2018-12-04 00:00:00
# 	Actual price = 7188.260 (0.417 %)
# 		Portfolio value =  1039543.1938195857
# 			Cash =  614582.7514006974
# 			Stock value =  0
# 			Short value =  424960.4424188884
# 	Holding Stock...
#
# 	Portfolio value =  1039543.1938195857
# 		Cash =  614582.7514006974
# 		Stock value =  0
# 		Short value =  424960.4424188884
#
#  2018-12-06 00:00:00
# 	Actual price = 6969.250 (-3.047 %)
# 		Portfolio value =  1052490.7624841365
# 			Cash =  614582.7514006974
# 			Stock value =  0
# 			Short value =  437908.0110834391
# 	Decision: Sell
# 		Hit short limit. No transaction excecuted.
#
# 	Portfolio value =  1052490.7624841365
# 		Cash =  614582.7514006974
# 		Stock value =  0
# 		Short value =  437908.0110834391
#
#  2018-12-07 00:00:00
# 	Actual price = 7020.520 (0.736 %)
# 		Portfolio value =  1049269.2462117774
# 			Cash =  614582.7514006974
# 			Stock value =  0
# 			Short value =  434686.49481108
# 	Decision: Buy
# 		Closing Short at  7020.52001953125
#
# 	Portfolio value =  1049269.2462117774
# 		Cash =  714582.7514006974
# 		Stock value =  0
# 		Short value =  334686.49481108
#
#  2018-12-10 00:00:00
# 	Actual price = 7031.830 (0.161 %)
# 		Portfolio value =  1048730.0662284829
# 			Cash =  714582.7514006974
# 			Stock value =  0
# 			Short value =  334147.3148277854
# 	Decision: Sell
# 		Short at  7031.830078125
#
# 	Portfolio value =  1048730.0662284829
# 		Cash =  614582.7514006974
# 		Stock value =  0
# 		Short value =  434147.3148277854
#
#  2018-12-11 00:00:00
# 	Actual price = 7098.310 (0.945 %)
# 		Portfolio value =  1044625.5721366678
# 			Cash =  614582.7514006974
# 			Stock value =  0
# 			Short value =  430042.8207359704
# 	Decision: Buy
# 		Closing Short at  7098.31005859375
#
# 	Portfolio value =  1044625.5721366678
# 		Cash =  714582.7514006974
# 		Stock value =  0
# 		Short value =  330042.8207359704
#
#  2018-12-12 00:00:00
# 	Actual price = 7070.330 (-0.394 %)
# 		Portfolio value =  1045926.5285054112
# 			Cash =  714582.7514006974
# 			Stock value =  0
# 			Short value =  331343.7771047139
# 	Decision: Sell
# 		Short at  7070.330078125
#
# 	Portfolio value =  1045926.5285054112
# 		Cash =  614582.7514006974
# 		Stock value =  0
# 		Short value =  431343.7771047139
#
#  2018-12-13 00:00:00
# 	Actual price = 6910.660 (-2.258 %)
# 		Portfolio value =  1055667.60514972
# 			Cash =  614582.7514006974
# 			Stock value =  0
# 			Short value =  441084.85374902264
# 	Decision: Sell
# 		Hit short limit. No transaction excecuted.
#
# 	Portfolio value =  1055667.60514972
# 		Cash =  614582.7514006974
# 		Stock value =  0
# 		Short value =  441084.85374902264
#
#  2018-12-14 00:00:00
# 	Actual price = 6753.730 (-2.271 %)
# 		Portfolio value =  1065683.9454223174
# 			Cash =  614582.7514006974
# 			Stock value =  0
# 			Short value =  451101.19402162003
# 	Decision: Sell
# 		Hit short limit. No transaction excecuted.
#
# 	Portfolio value =  1065683.9454223174
# 		Cash =  614582.7514006974
# 		Stock value =  0
# 		Short value =  451101.19402162003
#
#  2018-12-17 00:00:00
# 	Actual price = 6783.910 (0.447 %)
# 		Portfolio value =  1063668.124036198
# 			Cash =  614582.7514006974
# 			Stock value =  0
# 			Short value =  449085.3726355007
# 	Decision: Buy
# 		Closing Short at  6783.91015625
#
# 	Portfolio value =  1063668.124036198
# 		Cash =  714582.7514006974
# 		Stock value =  0
# 		Short value =  349085.3726355007
#
#  2018-12-18 00:00:00
# 	Actual price = 6636.830 (-2.168 %)
# 		Portfolio value =  1071236.5473638894
# 			Cash =  714582.7514006974
# 			Stock value =  0
# 			Short value =  356653.79596319195
# 	Holding Stock...
#
# 	Portfolio value =  1071236.5473638894
# 		Cash =  714582.7514006974
# 		Stock value =  0
# 		Short value =  356653.79596319195
#
#  2018-12-19 00:00:00
# 	Actual price = 6528.410 (-1.634 %)
# 		Portfolio value =  1077062.8795495215
# 			Cash =  714582.7514006974
# 			Stock value =  0
# 			Short value =  362480.12814882415
# 	Decision: Sell
# 		Short at  6528.41015625
#
# 	Portfolio value =  1077062.8795495215
# 		Cash =  614582.7514006974
# 		Stock value =  0
# 		Short value =  462480.12814882415
#
#  2018-12-20 00:00:00
# 	Actual price = 6332.990 (-2.993 %)
# 		Portfolio value =  1090906.6528953277
# 			Cash =  614582.7514006974
# 			Stock value =  0
# 			Short value =  476323.9014946302
# 	Decision: Buy
# 		Closing Short at  6332.990234375
#
# 	Portfolio value =  1090906.6528953277
# 		Cash =  714582.7514006974
# 		Stock value =  0
# 		Short value =  376323.9014946302
#
#  2018-12-21 00:00:00
# 	Actual price = 6192.920 (-2.212 %)
# 		Portfolio value =  1099230.0206146487
# 			Cash =  714582.7514006974
# 			Stock value =  0
# 			Short value =  384647.2692139512
# 	Holding Stock...
#
# 	Portfolio value =  1099230.0206146487
# 		Cash =  714582.7514006974
# 		Stock value =  0
# 		Short value =  384647.2692139512
#
#  2018-12-24 00:00:00
# 	Actual price = 6554.360 (5.836 %)
# 		Portfolio value =  1076780.6932859218
# 			Cash =  714582.7514006974
# 			Stock value =  0
# 			Short value =  362197.9418852245
# 	Holding Stock...
#
# 	Portfolio value =  1076780.6932859218
# 		Cash =  714582.7514006974
# 		Stock value =  0
# 		Short value =  362197.9418852245
#
#  2018-12-26 00:00:00
# 	Actual price = 6579.490 (0.383 %)
# 		Portfolio value =  1075391.9735819642
# 			Cash =  714582.7514006974
# 			Stock value =  0
# 			Short value =  360809.22218126676
# 	Decision: Buy
# 		Closing Short at  6579.490234375
#
# 	Portfolio value =  1075391.9735819642
# 		Cash =  814582.7514006974
# 		Stock value =  0
# 		Short value =  260809.22218126676
#
#  2018-12-27 00:00:00
# 	Actual price = 6584.520 (0.076 %)
# 		Portfolio value =  1075192.5942520145
# 			Cash =  814582.7514006974
# 			Stock value =  0
# 			Short value =  260609.84285131702
# 	Holding Stock...
#
# 	Portfolio value =  1075192.5942520145
# 		Cash =  814582.7514006974
# 		Stock value =  0
# 		Short value =  260609.84285131702
#
#  2018-12-28 00:00:00
# 	Actual price = 6635.280 (0.771 %)
# 		Portfolio value =  1073183.5648157818
# 			Cash =  814582.7514006974
# 			Stock value =  0
# 			Short value =  258600.81341508444
# 	Holding Stock...
#
# 	Portfolio value =  1073183.5648157818
# 		Cash =  814582.7514006974
# 		Stock value =  0
# 		Short value =  258600.81341508444
#
#  2018-12-31 00:00:00
# 	Actual price = 6665.940 (0.462 %)
# 		Portfolio value =  1071988.6278120067
# 			Cash =  814582.7514006974
# 			Stock value =  0
# 			Short value =  257405.8764113094
# 	Decision: Buy
# 		Closing Short at  6665.93994140625
#
# 	Portfolio value =  1071988.6278120067
# 		Cash =  914582.7514006974
# 		Stock value =  0
# 		Short value =  157405.8764113094
#
#  2019-01-02 00:00:00
# 	Actual price = 6463.500 (-3.037 %)
# 		Portfolio value =  1076768.9343670914
# 			Cash =  914582.7514006974
# 			Stock value =  0
# 			Short value =  162186.18296639406
# 	Decision: Sell
# 		Short at  6463.5
#
# 	Portfolio value =  1076768.9343670914
# 		Cash =  814582.7514006974
# 		Stock value =  0
# 		Short value =  262186.18296639406
#
#  2019-01-03 00:00:00
# 	Actual price = 6738.860 (4.260 %)
# 		Portfolio value =  1065599.204113226
# 			Cash =  814582.7514006974
# 			Stock value =  0
# 			Short value =  251016.45271252864
# 	Decision: Sell
# 		Short at  6738.85986328125
#
# 	Portfolio value =  1065599.204113226
# 		Cash =  714582.7514006974
# 		Stock value =  0
# 		Short value =  351016.45271252864
#
#  2019-01-04 00:00:00
# 	Actual price = 6823.470 (1.256 %)
# 		Portfolio value =  1061191.985967905
# 			Cash =  714582.7514006974
# 			Stock value =  0
# 			Short value =  346609.23456720763
# 	Holding Stock...
#
# 	Portfolio value =  1061191.985967905
# 		Cash =  714582.7514006974
# 		Stock value =  0
# 		Short value =  346609.23456720763
#
#  2019-01-07 00:00:00
# 	Actual price = 6897.000 (1.078 %)
# 		Portfolio value =  1057456.921294294
# 			Cash =  714582.7514006974
# 			Stock value =  0
# 			Short value =  342874.1698935967
# 	Holding Stock...
#
# 	Portfolio value =  1057456.921294294
# 		Cash =  714582.7514006974
# 		Stock value =  0
# 		Short value =  342874.1698935967
#
#  2019-01-08 00:00:00
# 	Actual price = 6957.080 (0.871 %)
# 		Portfolio value =  1054470.128933231
# 			Cash =  714582.7514006974
# 			Stock value =  0
# 			Short value =  339887.37753253366
# 	Decision: Buy
# 		Closing Short at  6957.080078125
#
# 	Portfolio value =  1054470.128933231
# 		Cash =  814582.7514006974
# 		Stock value =  0
# 		Short value =  239887.37753253366
#
#  2019-01-09 00:00:00
# 	Actual price = 6986.070 (0.417 %)
# 		Portfolio value =  1053470.5322507622
# 			Cash =  814582.7514006974
# 			Stock value =  0
# 			Short value =  238887.78085006482
# 	Decision: Sell
# 		Short at  6986.06982421875
#
# 	Portfolio value =  1053470.5322507622
# 		Cash =  714582.7514006974
# 		Stock value =  0
# 		Short value =  338887.7808500648
#
#  2019-01-10 00:00:00
# 	Actual price = 6971.480 (-0.209 %)
# 		Portfolio value =  1054178.2720666807
# 			Cash =  714582.7514006974
# 			Stock value =  0
# 			Short value =  339595.5206659834
# 	Decision: Buy
# 		Closing Short at  6971.47998046875
#
# 	Portfolio value =  1054178.2720666807
# 		Cash =  814582.7514006974
# 		Stock value =  0
# 		Short value =  239595.52066598338
#
#  2019-01-11 00:00:00
# 	Actual price = 6905.920 (-0.940 %)
# 		Portfolio value =  1056431.4373081601
# 			Cash =  814582.7514006974
# 			Stock value =  0
# 			Short value =  241848.68590746282
# 	Decision: Sell
# 		Short at  6905.919921875
#
# 	Portfolio value =  1056431.4373081601
# 		Cash =  714582.7514006974
# 		Stock value =  0
# 		Short value =  341848.68590746284
#
#  2019-01-14 00:00:00
# 	Actual price = 7023.830 (1.707 %)
# 		Portfolio value =  1050594.7881107768
# 			Cash =  714582.7514006974
# 			Stock value =  0
# 			Short value =  336012.0367100794
# 	Holding Stock...
#
# 	Portfolio value =  1050594.7881107768
# 		Cash =  714582.7514006974
# 		Stock value =  0
# 		Short value =  336012.0367100794
#
#  2019-01-15 00:00:00
# 	Actual price = 7034.690 (0.155 %)
# 		Portfolio value =  1050075.2646116405
# 			Cash =  714582.7514006974
# 			Stock value =  0
# 			Short value =  335492.5132109432
# 	Decision: Buy
# 		Closing Short at  7034.68994140625
#
# 	Portfolio value =  1050075.2646116405
# 		Cash =  814582.7514006974
# 		Stock value =  0
# 		Short value =  235492.5132109432
#
#  2019-01-16 00:00:00
# 	Actual price = 7084.460 (0.707 %)
# 		Portfolio value =  1048409.1688661856
# 			Cash =  814582.7514006974
# 			Stock value =  0
# 			Short value =  233826.41746548822
# 	Decision: Buy
# 		Closing Short at  7084.4599609375
#
# 	Portfolio value =  1048409.1688661856
# 		Cash =  914582.7514006974
# 		Stock value =  0
# 		Short value =  133826.41746548822
#
#  2019-01-17 00:00:00
# 	Actual price = 7157.230 (1.027 %)
# 		Portfolio value =  1047034.5332459044
# 			Cash =  914582.7514006974
# 			Stock value =  0
# 			Short value =  132451.781845207
# 	Holding Stock...
#
# 	Portfolio value =  1047034.5332459044
# 		Cash =  914582.7514006974
# 		Stock value =  0
# 		Short value =  132451.781845207
#
#  2019-01-18 00:00:00
# 	Actual price = 7020.360 (-1.912 %)
# 		Portfolio value =  1049567.4532376216
# 			Cash =  914582.7514006974
# 			Stock value =  0
# 			Short value =  134984.70183692416
# 	Decision: Sell
# 		Short at  7020.35986328125
#
# 	Portfolio value =  1049567.4532376216
# 		Cash =  814582.7514006974
# 		Stock value =  0
# 		Short value =  234984.70183692416
#
#  2019-01-22 00:00:00
# 	Actual price = 7025.770 (0.077 %)
# 		Portfolio value =  1049386.3650914216
# 			Cash =  814582.7514006974
# 			Stock value =  0
# 			Short value =  234803.6136907243
# 	Decision: Buy
# 		Closing Short at  7025.77001953125
#
# 	Portfolio value =  1049386.3650914216
# 		Cash =  914582.7514006974
# 		Stock value =  0
# 		Short value =  134803.6136907243
#
#  2019-01-23 00:00:00
# 	Actual price = 7073.460 (0.679 %)
# 		Portfolio value =  1048471.3370702383
# 			Cash =  914582.7514006974
# 			Stock value =  0
# 			Short value =  133888.5856695409
# 	Decision: Sell
# 		Short at  7073.4599609375
#
# 	Portfolio value =  1048471.3370702383
# 		Cash =  814582.7514006974
# 		Stock value =  0
# 		Short value =  233888.5856695409
#
#  2019-01-24 00:00:00
# 	Actual price = 7164.860 (1.292 %)
# 		Portfolio value =  1045449.13944594
# 			Cash =  814582.7514006974
# 			Stock value =  0
# 			Short value =  230866.38804524267
# 	Holding Stock...
#
# 	Portfolio value =  1045449.13944594
# 		Cash =  814582.7514006974
# 		Stock value =  0
# 		Short value =  230866.38804524267
#
#  2019-01-25 00:00:00
# 	Actual price = 7085.680 (-1.105 %)
# 		Portfolio value =  1048000.470359383
# 			Cash =  814582.7514006974
# 			Stock value =  0
# 			Short value =  233417.7189586856
# 	Decision: Buy
# 		Closing Short at  7085.68017578125
#
# 	Portfolio value =  1048000.470359383
# 		Cash =  914582.7514006974
# 		Stock value =  0
# 		Short value =  133417.7189586856
#
#  2019-01-28 00:00:00
# 	Actual price = 7028.290 (-0.810 %)
# 		Portfolio value =  1049081.0809629937
# 			Cash =  914582.7514006974
# 			Stock value =  0
# 			Short value =  134498.32956229622
# 	Decision: Sell
# 		Short at  7028.2900390625
#
# 	Portfolio value =  1049081.0809629937
# 		Cash =  814582.7514006974
# 		Stock value =  0
# 		Short value =  234498.32956229622
#
#  2019-01-29 00:00:00
# 	Actual price = 7183.080 (2.202 %)
# 		Portfolio value =  1043916.5238102155
# 			Cash =  814582.7514006974
# 			Stock value =  0
# 			Short value =  229333.7724095182
# 	Decision: Buy
# 		Closing Short at  7183.080078125
#
# 	Portfolio value =  1043916.5238102155
# 		Cash =  914582.7514006974
# 		Stock value =  0
# 		Short value =  129333.77240951819
#
#  2019-01-30 00:00:00
# 	Actual price = 7281.740 (1.374 %)
# 		Portfolio value =  1042140.1145184434
# 			Cash =  914582.7514006974
# 			Stock value =  0
# 			Short value =  127557.36311774599
# 	Decision: Sell
# 		Short at  7281.740234375
#
# 	Portfolio value =  1042140.1145184434
# 		Cash =  814582.7514006974
# 		Stock value =  0
# 		Short value =  227557.363117746
#
#  2019-01-31 00:00:00
# 	Actual price = 7263.870 (-0.245 %)
# 		Portfolio value =  1042698.5629957175
# 			Cash =  814582.7514006974
# 			Stock value =  0
# 			Short value =  228115.81159502015
# 	Decision: Buy
# 		Closing Short at  7263.8701171875
#
# 	Portfolio value =  1042698.5629957175
# 		Cash =  914582.7514006974
# 		Stock value =  0
# 		Short value =  128115.81159502015
#
#  2019-02-01 00:00:00
# 	Actual price = 7347.540 (1.152 %)
# 		Portfolio value =  1041222.8427840162
# 			Cash =  914582.7514006974
# 			Stock value =  0
# 			Short value =  126640.09138331872
# 	Holding Stock...
#
# 	Portfolio value =  1041222.8427840162
# 		Cash =  914582.7514006974
# 		Stock value =  0
# 		Short value =  126640.09138331872
#
#  2019-02-04 00:00:00
# 	Actual price = 7402.080 (0.742 %)
# 		Portfolio value =  1040282.8063236219
# 			Cash =  914582.7514006974
# 			Stock value =  0
# 			Short value =  125700.05492292455
# 	Holding Stock...
#
# 	Portfolio value =  1040282.8063236219
# 		Cash =  914582.7514006974
# 		Stock value =  0
# 		Short value =  125700.05492292455
#
#  2019-02-05 00:00:00
# 	Actual price = 7375.280 (-0.362 %)
# 		Portfolio value =  1040737.921407837
# 			Cash =  914582.7514006974
# 			Stock value =  0
# 			Short value =  126155.17000713959
# 	Holding Stock...
#
# 	Portfolio value =  1040737.921407837
# 		Cash =  914582.7514006974
# 		Stock value =  0
# 		Short value =  126155.17000713959
#
#  2019-02-06 00:00:00
# 	Actual price = 7288.350 (-1.179 %)
# 		Portfolio value =  1042224.8656085576
# 			Cash =  914582.7514006974
# 			Stock value =  0
# 			Short value =  127642.1142078602
# 	Decision: Sell
# 		Short at  7288.35009765625
#
# 	Portfolio value =  1042224.8656085576
# 		Cash =  814582.7514006974
# 		Stock value =  0
# 		Short value =  227642.1142078602
#
#  2019-02-07 00:00:00
# 	Actual price = 7298.200 (0.135 %)
# 		Portfolio value =  1041917.2106488509
# 			Cash =  814582.7514006974
# ...
# 		Stock value =  513415.77700197673
# 		Short value =  0
#
#  2019-10-24 00:00:00
# 	Actual price = 8243.120 (0.700 %)
# 		Portfolio value =  1064863.7814634794
# 			Cash =  547852.8575629271
# 			Stock value =  517010.9239005524
# 			Short value =  0
# 	Holding Stock...
#
# 	Portfolio value =  1064863.7814634794
# 		Cash =  547852.8575629271
# 		Stock value =  517010.9239005524
# 		Short value =  0
#
#  2019-10-25 00:00:00
# 	Actual price = 8325.990 (1.005 %)
# 		Portfolio value =  1070061.4196443816
# 			Cash =  547852.8575629271
# 			Stock value =  522208.56208145455
# 			Short value =  0
# 	Holding Stock...
#
# 	Portfolio value =  1070061.4196443816
# 		Cash =  547852.8575629271
# 		Stock value =  522208.56208145455
# 		Short value =  0
#
#  2019-10-28 00:00:00
# 	Actual price = 8276.850 (-0.590 %)
# 		Portfolio value =  1066979.3051572558
# 			Cash =  547852.8575629271
# 			Stock value =  519126.4475943289
# 			Short value =  0
# 	Decision: Buy
# 		Hit cash limit. No transaction excecuted.
#
# 	Portfolio value =  1066979.3051572558
# 		Cash =  547852.8575629271
# 		Stock value =  519126.4475943289
# 		Short value =  0
#
#  2019-10-29 00:00:00
# 	Actual price = 8303.980 (0.328 %)
# 		Portfolio value =  1068680.9606556925
# 			Cash =  547852.8575629271
# 			Stock value =  520828.10309276544
# 			Short value =  0
# 	Holding Stock...
#
# 	Portfolio value =  1068680.9606556925
# 		Cash =  547852.8575629271
# 		Stock value =  520828.10309276544
# 		Short value =  0
#
#  2019-10-30 00:00:00
# 	Actual price = 8292.360 (-0.140 %)
# 		Portfolio value =  1067952.143479971
# 			Cash =  547852.8575629271
# 			Stock value =  520099.28591704386
# 			Short value =  0
# 	Decision: Buy
# 		Hit cash limit. No transaction excecuted.
#
# 	Portfolio value =  1067952.143479971
# 		Cash =  547852.8575629271
# 		Stock value =  520099.28591704386
# 		Short value =  0
#
#  2019-10-31 00:00:00
# 	Actual price = 8386.400 (1.134 %)
# 		Portfolio value =  1073850.3624538728
# 			Cash =  547852.8575629271
# 			Stock value =  525997.5048909457
# 			Short value =  0
# 	Holding Stock...
#
# 	Portfolio value =  1073850.3624538728
# 		Cash =  547852.8575629271
# 		Stock value =  525997.5048909457
# 		Short value =  0
#
#  2019-11-01 00:00:00
# 	Actual price = 8433.200 (0.558 %)
# 		Portfolio value =  1076785.6600009021
# 			Cash =  547852.8575629271
# 			Stock value =  528932.8024379752
# 			Short value =  0
# 	Decision: Buy
# 		Hit cash limit. No transaction excecuted.
#
# 	Portfolio value =  1076785.6600009021
# 		Cash =  547852.8575629271
# 		Stock value =  528932.8024379752
# 		Short value =  0
#
#  2019-11-04 00:00:00
# 	Actual price = 8434.680 (0.018 %)
# 		Portfolio value =  1076878.4541870707
# 			Cash =  547852.8575629271
# 			Stock value =  529025.5966241437
# 			Short value =  0
# 	Decision: Buy
# 		Hit cash limit. No transaction excecuted.
#
# 	Portfolio value =  1076878.4541870707
# 		Cash =  547852.8575629271
# 		Stock value =  529025.5966241437
# 		Short value =  0
#
#  2019-11-05 00:00:00
# 	Actual price = 8410.630 (-0.285 %)
# 		Portfolio value =  1075370.0433469587
# 			Cash =  547852.8575629271
# 			Stock value =  527517.1857840315
# 			Short value =  0
# 	Decision: Sell
# 		Sell Stock at  8410.6298828125
#
# 	Portfolio value =  1075370.0433469587
# 		Cash =  647852.8575629271
# 		Stock value =  427517.1857840315
# 		Short value =  0
#
#  2019-11-06 00:00:00
# 	Actual price = 8434.520 (0.284 %)
# 		Portfolio value =  1076584.368006547
# 			Cash =  647852.8575629271
# 			Stock value =  428731.51044361986
# 			Short value =  0
# 	Decision: Sell
# 		Sell Stock at  8434.51953125
#
# 	Portfolio value =  1076584.368006547
# 		Cash =  747852.8575629271
# 		Stock value =  328731.51044361986
# 		Short value =  0
#
#  2019-11-07 00:00:00
# 	Actual price = 8475.310 (0.484 %)
# 		Portfolio value =  1078174.1409749286
# 			Cash =  747852.8575629271
# 			Stock value =  330321.2834120017
# 			Short value =  0
# 	Holding Stock...
#
# 	Portfolio value =  1078174.1409749286
# 		Cash =  747852.8575629271
# 		Stock value =  330321.2834120017
# 		Short value =  0
#
#  2019-11-08 00:00:00
# 	Actual price = 8464.280 (-0.130 %)
# 		Portfolio value =  1077744.2792136967
# 			Cash =  747852.8575629271
# 			Stock value =  329891.42165076954
# 			Short value =  0
# 	Decision: Sell
# 		Sell Stock at  8464.2802734375
#
# 	Portfolio value =  1077744.2792136967
# 		Cash =  847852.8575629271
# 		Stock value =  229891.42165076954
# 		Short value =  0
#
#  2019-11-11 00:00:00
# 	Actual price = 8486.090 (0.258 %)
# 		Portfolio value =  1078336.6311872562
# 			Cash =  847852.8575629271
# 			Stock value =  230483.77362432922
# 			Short value =  0
# 	Decision: Buy
# 		Buying Stock at  8486.08984375
#
# 	Portfolio value =  1078336.6311872564
# 		Cash =  747852.8575629271
# 		Stock value =  330483.77362432925
# 		Short value =  0
#
#  2019-11-12 00:00:00
# 	Actual price = 8482.100 (-0.047 %)
# 		Portfolio value =  1078181.2347987927
# 			Cash =  747852.8575629271
# 			Stock value =  330328.37723586574
# 			Short value =  0
# 	Holding Stock...
#
# 	Portfolio value =  1078181.2347987927
# 		Cash =  747852.8575629271
# 		Stock value =  330328.37723586574
# 		Short value =  0
#
#  2019-11-13 00:00:00
# 	Actual price = 8479.020 (-0.036 %)
# 		Portfolio value =  1078061.2836952163
# 			Cash =  747852.8575629271
# 			Stock value =  330208.42613228917
# 			Short value =  0
# 	Decision: Buy
# 		Buying Stock at  8479.01953125
#
# 	Portfolio value =  1078061.2836952163
# 		Cash =  647852.8575629271
# 		Stock value =  430208.42613228917
# 		Short value =  0
#
#  2019-11-14 00:00:00
# 	Actual price = 8540.830 (0.729 %)
# 		Portfolio value =  1081197.426735277
# 			Cash =  647852.8575629271
# 			Stock value =  433344.56917235005
# 			Short value =  0
# 	Decision: Sell
# 		Sell Stock at  8540.830078125
#
# 	Portfolio value =  1081197.426735277
# 		Cash =  747852.8575629271
# 		Stock value =  333344.56917235005
# 		Short value =  0
#
#  2019-11-15 00:00:00
# 	Actual price = 8549.940 (0.107 %)
# 		Portfolio value =  1081552.999459337
# 			Cash =  747852.8575629271
# 			Stock value =  333700.1418964098
# 			Short value =  0
# 	Decision: Buy
# 		Buying Stock at  8549.9404296875
#
# 	Portfolio value =  1081552.999459337
# 		Cash =  647852.8575629271
# 		Stock value =  433700.1418964098
# 		Short value =  0
#
#  2019-11-18 00:00:00
# 	Actual price = 8570.660 (0.242 %)
# 		Portfolio value =  1082604.0182850363
# 			Cash =  647852.8575629271
# 			Stock value =  434751.1607221093
# 			Short value =  0
# 	Decision: Sell
# 		Sell Stock at  8570.66015625
#
# 	Portfolio value =  1082604.0182850363
# 		Cash =  747852.8575629271
# 		Stock value =  334751.1607221093
# 		Short value =  0
#
#  2019-11-19 00:00:00
# 	Actual price = 8526.730 (-0.513 %)
# 		Portfolio value =  1080888.2211804152
# 			Cash =  747852.8575629271
# 			Stock value =  333035.3636174883
# 			Short value =  0
# 	Decision: Buy
# 		Buying Stock at  8526.73046875
#
# 	Portfolio value =  1080888.2211804152
# 		Cash =  647852.8575629271
# 		Stock value =  433035.3636174883
# 		Short value =  0
#
#  2019-11-20 00:00:00
# 	Actual price = 8506.210 (-0.241 %)
# 		Portfolio value =  1079846.074299525
# 			Cash =  647852.8575629271
# 			Stock value =  431993.2167365978
# 			Short value =  0
# 	Holding Stock...
#
# 	Portfolio value =  1079846.074299525
# 		Cash =  647852.8575629271
# 		Stock value =  431993.2167365978
# 		Short value =  0
#
#  2019-11-21 00:00:00
# 	Actual price = 8519.880 (0.161 %)
# 		Portfolio value =  1080540.3098698244
# 			Cash =  647852.8575629271
# 			Stock value =  432687.4523068974
# 			Short value =  0
# 	Decision: Buy
# 		Buying Stock at  8519.8798828125
#
# 	Portfolio value =  1080540.3098698244
# 		Cash =  547852.8575629271
# 		Stock value =  532687.4523068974
# 		Short value =  0
#
#  2019-11-22 00:00:00
# 	Actual price = 8632.490 (1.322 %)
# 		Portfolio value =  1087581.0336948428
# 			Cash =  547852.8575629271
# 			Stock value =  539728.1761319157
# 			Short value =  0
# 	Decision: Buy
# 		Hit cash limit. No transaction excecuted.
#
# 	Portfolio value =  1087581.0336948428
# 		Cash =  547852.8575629271
# 		Stock value =  539728.1761319157
# 		Short value =  0
#
#  2019-11-25 00:00:00
# 	Actual price = 8647.930 (0.179 %)
# 		Portfolio value =  1088546.352814747
# 			Cash =  547852.8575629271
# 			Stock value =  540693.4952518201
# 			Short value =  0
# 	Decision: Buy
# 		Hit cash limit. No transaction excecuted.
#
# 	Portfolio value =  1088546.352814747
# 		Cash =  547852.8575629271
# 		Stock value =  540693.4952518201
# 		Short value =  0
#
#  2019-11-26 00:00:00
# 	Actual price = 8705.180 (0.662 %)
# 		Portfolio value =  1092125.787861254
# 			Cash =  547852.8575629271
# 			Stock value =  544272.9302983271
# 			Short value =  0
# 	Decision: Buy
# 		Hit cash limit. No transaction excecuted.
#
# 	Portfolio value =  1092125.787861254
# 		Cash =  547852.8575629271
# 		Stock value =  544272.9302983271
# 		Short value =  0
#
#  2019-11-27 00:00:00
# 	Actual price = 8665.470 (-0.456 %)
# 		Portfolio value =  1089643.006623261
# 			Cash =  547852.8575629271
# 			Stock value =  541790.1490603338
# 			Short value =  0
# 	Decision: Buy
# 		Hit cash limit. No transaction excecuted.
#
# 	Portfolio value =  1089643.006623261
# 		Cash =  547852.8575629271
# 		Stock value =  541790.1490603338
# 		Short value =  0
#
#  2019-11-29 00:00:00
# 	Actual price = 8567.990 (-1.125 %)
# 		Portfolio value =  1083548.3077472495
# 			Cash =  547852.8575629271
# 			Stock value =  535695.4501843224
# 			Short value =  0
# 	Decision: Sell
# 		Sell Stock at  8567.990234375
#
# 	Portfolio value =  1083548.3077472495
# 		Cash =  647852.8575629271
# 		Stock value =  435695.4501843224
# 		Short value =  0
#
#  2019-12-02 00:00:00
# 	Actual price = 8520.640 (-0.553 %)
# 		Portfolio value =  1081140.4577973557
# 			Cash =  647852.8575629271
# 			Stock value =  433287.6002344286
# 			Short value =  0
# 	Decision: Buy
# 		Buying Stock at  8520.6396484375
#
# 	Portfolio value =  1081140.4577973557
# 		Cash =  547852.8575629271
# 		Stock value =  533287.6002344287
# 		Short value =  0
#
#  2019-12-03 00:00:00
# 	Actual price = 8566.670 (0.540 %)
# 		Portfolio value =  1084021.3886983732
# 			Cash =  547852.8575629271
# 			Stock value =  536168.5311354462
# 			Short value =  0
# 	Holding Stock...
#
# 	Portfolio value =  1084021.3886983732
# 		Cash =  547852.8575629271
# 		Stock value =  536168.5311354462
# 		Short value =  0
#
#  2019-12-04 00:00:00
# 	Actual price = 8570.700 (0.047 %)
# 		Portfolio value =  1084273.6344144759
# 			Cash =  547852.8575629271
# 			Stock value =  536420.7768515488
# 			Short value =  0
# 	Decision: Sell
# 		Sell Stock at  8570.7001953125
#
# 	Portfolio value =  1084273.6344144759
# 		Cash =  647852.8575629271
# 		Stock value =  436420.7768515488
# 		Short value =  0
#
#  2019-12-05 00:00:00
# 	Actual price = 8656.530 (1.001 %)
# 		Portfolio value =  1088644.1092320443
# 			Cash =  647852.8575629271
# 			Stock value =  440791.2516691172
# 			Short value =  0
# 	Holding Stock...
#
# 	Portfolio value =  1088644.1092320443
# 		Cash =  647852.8575629271
# 		Stock value =  440791.2516691172
# 		Short value =  0
#
#  2019-12-06 00:00:00
# 	Actual price = 8621.830 (-0.401 %)
# 		Portfolio value =  1086877.172359901
# 			Cash =  647852.8575629271
# 			Stock value =  439024.31479697407
# 			Short value =  0
# 	Decision: Sell
# 		Sell Stock at  8621.830078125
#
# 	Portfolio value =  1086877.172359901
# 		Cash =  747852.8575629271
# 		Stock value =  339024.31479697407
# 		Short value =  0
#
#  2019-12-09 00:00:00
# 	Actual price = 8616.180 (-0.066 %)
# 		Portfolio value =  1086654.9898542594
# 			Cash =  747852.8575629271
# 			Stock value =  338802.13229133224
# 			Short value =  0
# 	Holding Stock...
#
# 	Portfolio value =  1086654.9898542594
# 		Cash =  747852.8575629271
# 		Stock value =  338802.13229133224
# 		Short value =  0
#
#  2019-12-10 00:00:00
# 	Actual price = 8654.050 (0.440 %)
# 		Portfolio value =  1088144.1041622933
# 			Cash =  747852.8575629271
# 			Stock value =  340291.2465993662
# 			Short value =  0
# 	Decision: Buy
# 		Buying Stock at  8654.0498046875
#
# 	Portfolio value =  1088144.1041622933
# 		Cash =  647852.8575629271
# 		Stock value =  440291.2465993662
# 		Short value =  0
#
#  2019-12-11 00:00:00
# 	Actual price = 8717.320 (0.731 %)
# 		Portfolio value =  1091363.111608108
# 			Cash =  647852.8575629271
# 			Stock value =  443510.2540451809
# 			Short value =  0
# 	Holding Stock...
#
# 	Portfolio value =  1091363.111608108
# 		Cash =  647852.8575629271
# 		Stock value =  443510.2540451809
# 		Short value =  0
#
#  2019-12-12 00:00:00
# 	Actual price = 8734.880 (0.201 %)
# 		Portfolio value =  1092256.4881517063
# 			Cash =  647852.8575629271
# 			Stock value =  444403.6305887793
# 			Short value =  0
# 	Holding Stock...
#
# 	Portfolio value =  1092256.4881517063
# 		Cash =  647852.8575629271
# 		Stock value =  444403.6305887793
# 		Short value =  0
#
#  2019-12-13 00:00:00
# 	Actual price = 8814.230 (0.908 %)
# 		Portfolio value =  1096293.6001616104
# 			Cash =  647852.8575629271
# 			Stock value =  448440.74259868334
# 			Short value =  0
# 	Decision: Sell
# 		Sell Stock at  8814.23046875
#
# 	Portfolio value =  1096293.6001616104
# 		Cash =  747852.8575629271
# 		Stock value =  348440.74259868334
# 		Short value =  0
#
#  2019-12-16 00:00:00
# 	Actual price = 8823.360 (0.104 %)
# 		Portfolio value =  1096654.519150319
# 			Cash =  747852.8575629271
# 			Stock value =  348801.66158739204
# 			Short value =  0
# 	Holding Stock...
#
# 	Portfolio value =  1096654.519150319
# 		Cash =  747852.8575629271
# 		Stock value =  348801.66158739204
# 		Short value =  0
#
#  2019-12-17 00:00:00
# 	Actual price = 8827.740 (0.050 %)
# 		Portfolio value =  1096827.6629800717
# 			Cash =  747852.8575629271
# 			Stock value =  348974.8054171448
# 			Short value =  0
# 	Decision: Buy
# 		Buying Stock at  8827.740234375
#
# 	Portfolio value =  1096827.6629800717
# 		Cash =  647852.8575629271
# 		Stock value =  448974.8054171448
# 		Short value =  0
#
#  2019-12-18 00:00:00
# 	Actual price = 8887.220 (0.674 %)
# 		Portfolio value =  1099852.7625777249
# 			Cash =  647852.8575629271
# 			Stock value =  451999.9050147978
# 			Short value =  0
# 	Decision: Buy
# 		Buying Stock at  8887.2197265625
#
# 	Portfolio value =  1099852.7625777249
# 		Cash =  547852.8575629271
# 		Stock value =  551999.9050147978
# 		Short value =  0
#
#  2019-12-19 00:00:00
# 	Actual price = 8924.960 (0.425 %)
# 		Portfolio value =  1102196.8709075742
# 			Cash =  547852.8575629271
# 			Stock value =  554344.0133446471
# 			Short value =  0
# 	Holding Stock...
#
# 	Portfolio value =  1102196.8709075742
# 		Cash =  547852.8575629271
# 		Stock value =  554344.0133446471
# 		Short value =  0
#
#  2019-12-20 00:00:00
# 	Actual price = 8945.650 (0.232 %)
# 		Portfolio value =  1103481.9876902818
# 			Cash =  547852.8575629271
# 			Stock value =  555629.1301273548
# 			Short value =  0
# 	Holding Stock...
#
# 	Portfolio value =  1103481.9876902818
# 		Cash =  547852.8575629271
# 		Stock value =  555629.1301273548
# 		Short value =  0
#
#  2019-12-23 00:00:00
# 	Actual price = 8952.880 (0.081 %)
# 		Portfolio value =  1103931.0233981395
# 			Cash =  547852.8575629271
# 			Stock value =  556078.1658352126
# 			Short value =  0
# 	Decision: Sell
# 		Sell Stock at  8952.8798828125
#
# 	Portfolio value =  1103931.0233981395
# 		Cash =  647852.8575629271
# 		Stock value =  456078.16583521257
# 		Short value =  0
#
#  2019-12-24 00:00:00
# 	Actual price = 9022.390 (0.776 %)
# 		Portfolio value =  1107471.9942174563
# 			Cash =  647852.8575629271
# 			Stock value =  459619.13665452914
# 			Short value =  0
# 	Decision: Sell
# 		Sell Stock at  9022.3896484375
#
# 	Portfolio value =  1107471.9942174563
# 		Cash =  747852.8575629271
# 		Stock value =  359619.13665452914
# 		Short value =  0
#
#  2019-12-26 00:00:00
# 	Actual price = 9006.620 (-0.175 %)
# 		Portfolio value =  1106843.4439736132
# 			Cash =  747852.8575629271
# 			Stock value =  358990.5864106862
# 			Short value =  0
# 	Holding Stock...
#
# 	Portfolio value =  1106843.4439736132
# 		Cash =  747852.8575629271
# 		Stock value =  358990.5864106862
# 		Short value =  0
#
#  2019-12-27 00:00:00
# 	Actual price = 8945.990 (-0.673 %)
# 		Portfolio value =  1104426.8263188577
# 			Cash =  747852.8575629271
# 			Stock value =  356573.9687559308
# 			Short value =  0
# 	Decision: Sell
# 		Sell Stock at  8945.990234375
#
# 	Portfolio value =  1104426.8263188577
# 		Cash =  847852.8575629271
# 		Stock value =  256573.96875593078
# 		Short value =  0
#
#  2019-12-30 00:00:00
# 	Actual price = 8972.600 (0.297 %)
# 		Portfolio value =  1105189.9920244978
# 			Cash =  847852.8575629271
# 			Stock value =  257337.13446157073
# 			Short value =  0
# 	Holding Stock...
#
# 	Portfolio value =  1105189.9920244978
# 		Cash =  847852.8575629271
# 		Stock value =  257337.13446157073
# 		Short value =  0
#
# Total profit =  105189.99202449783
# Profitability =  10.518999202449786 %
# Profit per day (PPD) =  104.5626163265386

# %% [markdown]
# ## Plot profitability

# %%
# Set up portfolio history list with dates as index
y_dates = y_test[:len(y_test)-1]
portfolio_history = pd.DataFrame(naive_history)
portfolio_history = portfolio_history.set_index(y_dates.index)

rand_portfolio_history = pd.DataFrame(random_history)
rand_portfolio_history = rand_portfolio_history.set_index(y_test.index)

# Plot the real vs predicted stock price values
plt.figure(figsize=(12, 6))
plt.plot(portfolio_history, color='blue', label='Naive Strategy')
plt.plot(rand_portfolio_history, color='green', label='Random Strategy')
plt.title('Portfolio Value when simulating ' + dataset_Name + " dataset from " + split_index + " to " + end_date)
plt.xlabel('Date')
plt.ylabel('Portfolio Value')
plt.legend()
plt.show()

# %% [markdown]
# # Final Values for Project

# %%
# Plot training & validation loss values
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Training', 'Validation'], loc='upper right')
plt.show()

# %%
import matplotlib

fig, (ax1, ax2) = plt.subplots(1, 2)
fig.suptitle('Simulation of ' + dataset_Name + ' dataset from ' + split_index + " to " + end_date)
fig.set_size_inches(18, 6, forward=True)

ax1.plot(real_stock_price, color='red', label = 'Real Stock Price')
ax1.plot(predicted_stock_price, color='blue', label='Predicted Stock Price')
ax1.set_title('Stock Price Prediction')
ax1.set(xlabel = 'Date', ylabel = 'Stock Price')
ax1.legend(loc="upper left")
ax1.grid(True)

ax2.plot(portfolio_history, color='orange', label='Naive Strategy')
ax2.plot(rand_portfolio_history, color='green', label='Random Strategy')
ax2.set_title('Portfolio Value')
ax2.set(xlabel = 'Date', ylabel = 'Portfolio Value')
ax2.get_yaxis().set_major_formatter(
    matplotlib.ticker.FuncFormatter(lambda x, p: format(int(x), ',')))
ax2.legend(loc="upper left")
ax2.grid(True)

plt.show()

print("Nodes = ", HIDDEN_LAYER_NODES)
print("Batch size = ", PARAM_BATCH_SIZE)
print("Epochs = ", PARAM_EPOCHS)
print("Window size = ", PARAM_WINDOW_SIZE)

print("\nMSE = ", MSE)
print("RMSE = ", RMSE)
print("MAE = ", MAE)
print("R2 = ", R2)
print("MDA = ", MDA)

print("\nProfitability = ", naive_profitability, "%")
print("Profit per day (PPD) = ", naive_ppd)
# Out:
# Nodes =  50
# Batch size =  50
# Epochs =  100
# Window size =  10
#
# MSE =  22108.328043503978
# RMSE =  148.68869507633718
# MAE =  117.9729979498012
# R2 =  0.9847749417975108
# MDA =  0.5482587064676617
#
# Profitability =  2.0348345067954243 %
# Profit per day (PPD) =  20.24710952035251
